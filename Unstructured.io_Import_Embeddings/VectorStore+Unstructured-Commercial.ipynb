# %% [markdown]
# <header>
#    <p  style='font-size:36px;font-family:Arial; color:#F0F0F0; background-color: #00233c; padding-left: 20pt; padding-top: 20pt;padding-bottom: 10pt; padding-right: 20pt;'>
#        Tips & Techniques - Building Vectors from PDF Documents Using Unstructured.io
#   <br>
#        <img id="teradata-logo" src="https://storage.googleapis.com/clearscape_analytics_demo_data/DEMO_Logo/teradata.svg" alt="Teradata" style="width: 125px; height: auto; margin-top: 20pt;">
#     </p>
# </header>

# %% [markdown]
# <p style="font-size:24px;font-family:Arial;color:#00233C"><b>Introduction</b></p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# This notebook demonstrates an end-to-end workflow for transforming unstructured PDF documents into searchable knowledge using the commercial version of Unstructured.io. It covers extracting content, generating embeddings, and inserting them into a Teradata table, enabling you to perform semantic search algorithms on your data.
# </p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# The workflow covers three key phases: document parsing with Unstructured.io, embedding generation using HuggingFace models through LangChain, and vector storage in Teradata.
# </p>
#
# ---
#
# <p style="font-size:24px;font-family:Arial;color:#00233C"><b>Workflow Overview</b></p>
#
# <p style="font-size:18px;font-family:Arial;color:#00233C"><b>Document Processing Pipeline</b></p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# We begin by extracting meaningful content from PDF documents using Unstructured.io's intelligent partitioning:
# </p>
#
# <ul style="font-size:16px;font-family:Arial;color:#00233C">
#   <li>Preserves document structure and layout information</li>
#   <li>Handles complex documents with mixed content types</li>
#   <li>Outputs clean, chunked text ready for embedding in a JSON file</li>
# </ul>
#
# <p style="font-size:18px;font-family:Arial;color:#00233C"><b>Embedding Generation</b></p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# Using LangChain's HuggingFace integration, we transform text chunks into high-dimensional vector embeddings:
# </p>
#
# <table style="font-size:16px;font-family:Arial;color:#00233C;border:1px solid black;">
#   <tr>
#     <th style="border:1px solid black;padding:5px;">Component</th>
#     <th style="border:1px solid black;padding:5px;">Technology</th>
#     <th style="border:1px solid black;padding:5px;">Output</th>
#   </tr>
#   <tr>
#     <td style="border:1px solid black;padding:5px;">Embedding Model</td>
#     <td style="border:1px solid black;padding:5px;">HuggingFace Sentence Transformer All MiniLM L6-v2</td>
#     <td style="border:1px solid black;padding:5px;">384-dimension vectors</td>
#   </tr>
#   <tr>
#     <td style="border:1px solid black;padding:5px;">Processing Framework</td>
#     <td style="border:1px solid black;padding:5px;">LangChain</td>
#     <td style="border:1px solid black;padding:5px;">Batch-processed embeddings</td>
#   </tr>
# </table>
#
# <p style="font-size:18px;font-family:Arial;color:#00233C"><b>Teradata Vector Integration</b></p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# The generated embeddings are stored in Teradata's optimized vector column type, enabling:
# </p>
#
# <ul style="font-size:16px;font-family:Arial;color:#00233C">
#   <li>Efficient storage of high-dimensional vectors</li>
#   <li>Native support for vector similarity operations</li>
#   <li>Seamless integration with existing SQL workflows</li>
# </ul>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# This combination allows for both precise answers and scalable performance across different dataset sizes and query requirements.
# </p>

# %% [markdown]
# <p style="font-size:20px;font-family:Arial;color:#00233C"><b>What You Will Do in This Notebook</b></p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# This notebook provides a complete workflow for processing PDF documents into searchable vector embeddings and implementing semantic search in Teradata. You'll learn how to extract meaningful content from unstructured documents, generate AI-powered embeddings, and leverage Teradata's vector processing capabilities. By the end, you'll be able to:
# </p>
#
# <div style="font-size:16px;font-family:Arial;color:#00233C">
# <ol>
# <li>
# <b>Process PDF documents</b> using Unstructured.io's partitioning function
# </li>
# <li>
# <b>Generate embeddings</b> using HuggingFace models through LangChain
# </li>
# <li>
# <b>Design optimized tables</b> for vector storage in Teradata
# </li>
# </ol>
# </div>
#
# ---
#
# <p style="font-size:24px;font-family:Arial;color:#00233C"><b>Notebook Workflow Steps</b></p>
#
# <div style="font-size:16px;font-family:Arial;color:#00233C">
# <ol>
# <li>
# <b>Installation and import of Unstructured.io and Teradata libraries</b>
# <ul>
# <li>Set up the Python environment with required dependencies</li>
# <li>Document processing with Unstructured.io</li>
# <li>Embedding generation with LangChain and HuggingFace</li>
# <li>Teradata libraries</li>
# </ul>
# </li>
#
# <li>
# <b>Unstructured.io partitioning into JSON</b>
# <ul>
# <li>Load and parse PDF documents</li>
# <li>Extract structured elements (titles, paragraphs, tables)</li>
# <li>Output clean, organized JSON content</li>
# </ul>
# </li>
#
# <li>
# <b>Generate embeddings</b>
# <ul>
# <li>Load the JSON file</li>
# <li>Configure HuggingFace sentence transformer model</li>
# <li>Process each element in the JSON file into vector embeddings</li>
# <li>Add the embeddings to that element as an "embeddings" field and save the new JSON file</li>
# </ul>
# </li>
#
# <li>
# <b>Connect to Vantage</b>
# <ul>
# <li>Establish secure connection to Teradata</li>
# <li>Verify vector processing capabilities</li>
# </ul>
# </li>
#
# <li>
# <b>Import Embeddings to a Table</b>
# <ul>
# <li>Read external embeddings and define the clean fucntion</li>
# <li>Create the table</li>
# <li>Insert embeddings into the table</li>
# <li>Verify embeddings in table</li>
# </ul>
# </li>
#
# <li>
# <b>Normalize the Embeddings</b>
# <ul>
# <li>Apply vector normalization for accurate similarity</li>
# <li>Verify data integrity</li>
# </ul>
# </li>
#
# <li>
# <b>Clean up: Drop tables</b>
# </li>
# </ol>
# </div>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <b style = 'font-size:30px;font-family:Arial;color:#00233C'>1. Installation and import of libraries needed </b>

# %% [markdown]
# <b style = 'font-size:18px;font-family:Arial;color:#00233C'>Teradata libraries</b>

# %%
# %pip install teradataml-20.0.0.5-py3-none-any.whl
# %pip install teradatagenai-20.0.0.1-py3-none-any.whl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Processing c:\users\jv255027\downloads\vector store\vector-store-examples\vector-store-examples\unstructured.io_import_embeddings\teradataml-20.0.0.5-py3-none-any.whl
# Requirement already satisfied: teradatasql>=20.0.0.19 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradataml==20.0.0.5) (20.0.0.29)
# Requirement already satisfied: teradatasqlalchemy>=20.0.0.4 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradataml==20.0.0.5) (20.0.0.4)
# Requirement already satisfied: pandas>=0.22 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradataml==20.0.0.5) (2.2.3)
# Requirement already satisfied: psutil in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradataml==20.0.0.5) (7.0.0)
# Requirement already satisfied: requests>=2.25.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradataml==20.0.0.5) (2.32.3)
# Requirement already satisfied: scikit-learn>=0.24.2 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradataml==20.0.0.5) (1.6.1)
# Requirement already satisfied: IPython>=8.10.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradataml==20.0.0.5) (9.1.0)
# Requirement already satisfied: imbalanced-learn>=0.8.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradataml==20.0.0.5) (0.13.0)
# Requirement already satisfied: pyjwt>=2.8.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradataml==20.0.0.5) (2.10.1)
# Requirement already satisfied: cryptography>=42.0.5 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradataml==20.0.0.5) (44.0.2)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradataml==20.0.0.5) (2.0.40)
# Requirement already satisfied: lightgbm>=3.3.3 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradataml==20.0.0.5) (4.6.0)
# Requirement already satisfied: python-dotenv in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradataml==20.0.0.5) (1.1.0)
# Requirement already satisfied: teradatamlwidgets>=20.0.0.5 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradataml==20.0.0.5) (20.0.0.5)
# Requirement already satisfied: cffi>=1.12 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from cryptography>=42.0.5->teradataml==20.0.0.5) (1.17.1)
# Requirement already satisfied: numpy<3,>=1.24.3 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from imbalanced-learn>=0.8.0->teradataml==20.0.0.5) (2.2.5)
# Requirement already satisfied: scipy<2,>=1.10.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from imbalanced-learn>=0.8.0->teradataml==20.0.0.5) (1.15.2)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from imbalanced-learn>=0.8.0->teradataml==20.0.0.5) (0.1.3)
# Requirement already satisfied: joblib<2,>=1.1.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from imbalanced-learn>=0.8.0->teradataml==20.0.0.5) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from imbalanced-learn>=0.8.0->teradataml==20.0.0.5) (3.6.0)
# Requirement already satisfied: colorama in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from IPython>=8.10.0->teradataml==20.0.0.5) (0.4.6)
# Requirement already satisfied: decorator in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from IPython>=8.10.0->teradataml==20.0.0.5) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from IPython>=8.10.0->teradataml==20.0.0.5) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from IPython>=8.10.0->teradataml==20.0.0.5) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from IPython>=8.10.0->teradataml==20.0.0.5) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from IPython>=8.10.0->teradataml==20.0.0.5) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from IPython>=8.10.0->teradataml==20.0.0.5) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from IPython>=8.10.0->teradataml==20.0.0.5) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from IPython>=8.10.0->teradataml==20.0.0.5) (5.14.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas>=0.22->teradataml==20.0.0.5) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas>=0.22->teradataml==20.0.0.5) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas>=0.22->teradataml==20.0.0.5) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests>=2.25.1->teradataml==20.0.0.5) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests>=2.25.1->teradataml==20.0.0.5) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests>=2.25.1->teradataml==20.0.0.5) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests>=2.25.1->teradataml==20.0.0.5) (2025.1.31)
# Requirement already satisfied: greenlet>=1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from sqlalchemy>=2.0->teradataml==20.0.0.5) (3.2.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from sqlalchemy>=2.0->teradataml==20.0.0.5) (4.13.2)
# Requirement already satisfied: ipywidgets>=8.1.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (8.1.6)
# Requirement already satisfied: nbconvert in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (7.16.6)
# Requirement already satisfied: nbformat in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (5.10.4)
# Requirement already satisfied: pycryptodome in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradatasql>=20.0.0.19->teradataml==20.0.0.5) (3.22.0)
# Requirement already satisfied: pycparser in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from cffi>=1.12->cryptography>=42.0.5->teradataml==20.0.0.5) (2.22)
# Requirement already satisfied: comm>=0.1.3 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipywidgets>=8.1.1->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipywidgets>=8.1.1->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.14 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipywidgets>=8.1.1->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (3.0.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jedi>=0.16->IPython>=8.10.0->teradataml==20.0.0.5) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->IPython>=8.10.0->teradataml==20.0.0.5) (0.2.13)
# Requirement already satisfied: six>=1.5 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from python-dateutil>=2.8.2->pandas>=0.22->teradataml==20.0.0.5) (1.17.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from bleach[css]!=5.0.0->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (3.1.6)
# Requirement already satisfied: jupyter-core>=4.7 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (5.7.2)
# Requirement already satisfied: jupyterlab-pygments in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (0.10.2)
# Requirement already satisfied: packaging in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (24.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from nbformat->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from nbformat->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (4.23.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from stack_data->IPython>=8.10.0->teradataml==20.0.0.5) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from stack_data->IPython>=8.10.0->teradataml==20.0.0.5) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from stack_data->IPython>=8.10.0->teradataml==20.0.0.5) (0.2.3)
# Requirement already satisfied: webencodings in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from bleach[css]!=5.0.0->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jsonschema>=2.6->nbformat->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jsonschema>=2.6->nbformat->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jsonschema>=2.6->nbformat->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jsonschema>=2.6->nbformat->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (0.24.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jupyter-core>=4.7->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (4.3.7)
# Requirement already satisfied: pywin32>=300 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jupyter-core>=4.7->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (310)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from nbclient>=0.5.0->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (8.6.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from beautifulsoup4->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (2.7)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (26.4.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (6.4.2)
# Installing collected packages: teradataml
#   Attempting uninstall: teradataml
#     Found existing installation: teradataml 20.0.0.4
#     Uninstalling teradataml-20.0.0.4:
#       Successfully uninstalled teradataml-20.0.0.4
# Successfully installed teradataml-20.0.0.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Processing c:\users\jv255027\downloads\vector store\vector-store-examples\vector-store-examples\unstructured.io_import_embeddings\teradatagenai-20.0.0.1-py3-none-any.whl
# Requirement already satisfied: teradataml>=20.00.00.01 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradatagenai==20.0.0.1) (20.0.0.5)
# Requirement already satisfied: torch>=2.5.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradatagenai==20.0.0.1) (2.7.0)
# Requirement already satisfied: transformers>=4.46.2 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradatagenai==20.0.0.1) (4.51.3)
# Requirement already satisfied: wikipedia>=1.4.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradatagenai==20.0.0.1) (1.4.0)
# Requirement already satisfied: boto3>=1.34.78 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradatagenai==20.0.0.1) (1.38.2)
# Requirement already satisfied: botocore>=1.34.78 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradatagenai==20.0.0.1) (1.38.2)
# Requirement already satisfied: openai>=0.28 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradatagenai==20.0.0.1) (1.76.0)
# Requirement already satisfied: langchain-community>=0.2.5 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradatagenai==20.0.0.1) (0.3.22)
# Requirement already satisfied: vertexai>=1.49.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradatagenai==20.0.0.1) (1.71.1)
# Requirement already satisfied: langchain-aws>=0.1.6 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradatagenai==20.0.0.1) (0.2.22)
# Requirement already satisfied: aiohttp>=3.9.4 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradatagenai==20.0.0.1) (3.11.18)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from aiohttp>=3.9.4->teradatagenai==20.0.0.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from aiohttp>=3.9.4->teradatagenai==20.0.0.1) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from aiohttp>=3.9.4->teradatagenai==20.0.0.1) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from aiohttp>=3.9.4->teradatagenai==20.0.0.1) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from aiohttp>=3.9.4->teradatagenai==20.0.0.1) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from aiohttp>=3.9.4->teradatagenai==20.0.0.1) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from aiohttp>=3.9.4->teradatagenai==20.0.0.1) (1.20.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from boto3>=1.34.78->teradatagenai==20.0.0.1) (1.0.1)
# Requirement already satisfied: s3transfer<0.13.0,>=0.12.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from boto3>=1.34.78->teradatagenai==20.0.0.1) (0.12.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from botocore>=1.34.78->teradatagenai==20.0.0.1) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from botocore>=1.34.78->teradatagenai==20.0.0.1) (2.4.0)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.56 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-aws>=0.1.6->teradatagenai==20.0.0.1) (0.3.56)
# Requirement already satisfied: numpy<3,>=1.26.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-aws>=0.1.6->teradatagenai==20.0.0.1) (2.2.5)
# Requirement already satisfied: pydantic<3,>=2.10.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-aws>=0.1.6->teradatagenai==20.0.0.1) (2.11.3)
# Requirement already satisfied: langchain<1.0.0,>=0.3.24 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-community>=0.2.5->teradatagenai==20.0.0.1) (0.3.24)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-community>=0.2.5->teradatagenai==20.0.0.1) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-community>=0.2.5->teradatagenai==20.0.0.1) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-community>=0.2.5->teradatagenai==20.0.0.1) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-community>=0.2.5->teradatagenai==20.0.0.1) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-community>=0.2.5->teradatagenai==20.0.0.1) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-community>=0.2.5->teradatagenai==20.0.0.1) (2.9.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-community>=0.2.5->teradatagenai==20.0.0.1) (0.3.34)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-community>=0.2.5->teradatagenai==20.0.0.1) (0.4.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from openai>=0.28->teradatagenai==20.0.0.1) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from openai>=0.28->teradatagenai==20.0.0.1) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from openai>=0.28->teradatagenai==20.0.0.1) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from openai>=0.28->teradatagenai==20.0.0.1) (0.9.0)
# Requirement already satisfied: sniffio in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from openai>=0.28->teradatagenai==20.0.0.1) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from openai>=0.28->teradatagenai==20.0.0.1) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from openai>=0.28->teradatagenai==20.0.0.1) (4.13.2)
# Requirement already satisfied: teradatasql>=20.0.0.19 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (20.0.0.29)
# Requirement already satisfied: teradatasqlalchemy>=20.0.0.4 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (20.0.0.4)
# Requirement already satisfied: pandas>=0.22 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (2.2.3)
# Requirement already satisfied: psutil in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (7.0.0)
# Requirement already satisfied: scikit-learn>=0.24.2 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (1.6.1)
# Requirement already satisfied: IPython>=8.10.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (9.1.0)
# Requirement already satisfied: imbalanced-learn>=0.8.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (0.13.0)
# Requirement already satisfied: pyjwt>=2.8.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (2.10.1)
# Requirement already satisfied: cryptography>=42.0.5 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (44.0.2)
# Requirement already satisfied: lightgbm>=3.3.3 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (4.6.0)
# Requirement already satisfied: python-dotenv in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (1.1.0)
# Requirement already satisfied: teradatamlwidgets>=20.0.0.5 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (20.0.0.5)
# Requirement already satisfied: filelock in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from torch>=2.5.1->teradatagenai==20.0.0.1) (3.18.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from torch>=2.5.1->teradatagenai==20.0.0.1) (1.13.3)
# Requirement already satisfied: networkx in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from torch>=2.5.1->teradatagenai==20.0.0.1) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from torch>=2.5.1->teradatagenai==20.0.0.1) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from torch>=2.5.1->teradatagenai==20.0.0.1) (2025.3.2)
# Requirement already satisfied: setuptools in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from torch>=2.5.1->teradatagenai==20.0.0.1) (79.0.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from transformers>=4.46.2->teradatagenai==20.0.0.1) (0.30.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from transformers>=4.46.2->teradatagenai==20.0.0.1) (24.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from transformers>=4.46.2->teradatagenai==20.0.0.1) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from transformers>=4.46.2->teradatagenai==20.0.0.1) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from transformers>=4.46.2->teradatagenai==20.0.0.1) (0.5.3)
# Requirement already satisfied: google-cloud-aiplatform==1.71.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (1.71.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (2.25.0rc0)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (2.39.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (5.29.4)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (2.19.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (3.31.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (1.14.2)
# Requirement already satisfied: shapely<3.0.0dev in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (2.1.0)
# Requirement already satisfied: docstring-parser<1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (0.16)
# Requirement already satisfied: beautifulsoup4 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from wikipedia>=1.4.0->teradatagenai==20.0.0.1) (4.13.4)
# Requirement already satisfied: idna>=2.8 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from anyio<5,>=3.5.0->openai>=0.28->teradatagenai==20.0.0.1) (3.10)
# Requirement already satisfied: cffi>=1.12 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from cryptography>=42.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (1.17.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community>=0.2.5->teradatagenai==20.0.0.1) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community>=0.2.5->teradatagenai==20.0.0.1) (0.9.0)
# Requirement already satisfied: certifi in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpx<1,>=0.23.0->openai>=0.28->teradatagenai==20.0.0.1) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpx<1,>=0.23.0->openai>=0.28->teradatagenai==20.0.0.1) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=0.28->teradatagenai==20.0.0.1) (0.16.0)
# Requirement already satisfied: scipy<2,>=1.10.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from imbalanced-learn>=0.8.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (1.15.2)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from imbalanced-learn>=0.8.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (0.1.3)
# Requirement already satisfied: joblib<2,>=1.1.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from imbalanced-learn>=0.8.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from imbalanced-learn>=0.8.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (3.6.0)
# Requirement already satisfied: colorama in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from IPython>=8.10.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (0.4.6)
# Requirement already satisfied: decorator in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from IPython>=8.10.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from IPython>=8.10.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from IPython>=8.10.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from IPython>=8.10.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from IPython>=8.10.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from IPython>=8.10.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from IPython>=8.10.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from IPython>=8.10.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (5.14.3)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain<1.0.0,>=0.3.24->langchain-community>=0.2.5->teradatagenai==20.0.0.1) (0.3.8)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-core<0.4.0,>=0.3.56->langchain-aws>=0.1.6->teradatagenai==20.0.0.1) (1.33)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langsmith<0.4,>=0.1.125->langchain-community>=0.2.5->teradatagenai==20.0.0.1) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langsmith<0.4,>=0.1.125->langchain-community>=0.2.5->teradatagenai==20.0.0.1) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langsmith<0.4,>=0.1.125->langchain-community>=0.2.5->teradatagenai==20.0.0.1) (0.23.0)
# ...
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from sympy>=1.13.3->torch>=2.5.1->teradatagenai==20.0.0.1) (1.3.0)
# Requirement already satisfied: ipywidgets>=8.1.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (8.1.6)
# Requirement already satisfied: nbconvert in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (7.16.6)
# Requirement already satisfied: nbformat in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (5.10.4)
# Requirement already satisfied: pycryptodome in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from teradatasql>=20.0.0.19->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (3.22.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from beautifulsoup4->wikipedia>=1.4.0->teradatagenai==20.0.0.1) (2.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jinja2->torch>=2.5.1->teradatagenai==20.0.0.1) (3.0.2)
# Requirement already satisfied: pycparser in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from cffi>=1.12->cryptography>=42.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (2.22)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (1.70.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (1.72.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (1.71.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (4.9.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (2.4.3)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (2.7.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (0.14.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (1.7.1)
# Requirement already satisfied: comm>=0.1.3 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipywidgets>=8.1.1->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipywidgets>=8.1.1->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.14 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipywidgets>=8.1.1->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (3.0.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jedi>=0.16->IPython>=8.10.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (0.8.4)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.56->langchain-aws>=0.1.6->teradatagenai==20.0.0.1) (3.0.0)
# Requirement already satisfied: wcwidth in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->IPython>=8.10.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (0.2.13)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community>=0.2.5->teradatagenai==20.0.0.1) (1.1.0)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from bleach[css]!=5.0.0->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (0.7.1)
# Requirement already satisfied: jupyter-core>=4.7 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (5.7.2)
# Requirement already satisfied: jupyterlab-pygments in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from nbformat->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from nbformat->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (4.23.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from stack_data->IPython>=8.10.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from stack_data->IPython>=8.10.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from stack_data->IPython>=8.10.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (0.2.3)
# Requirement already satisfied: webencodings in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from bleach[css]!=5.0.0->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (1.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jsonschema>=2.6->nbformat->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jsonschema>=2.6->nbformat->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jsonschema>=2.6->nbformat->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (0.24.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jupyter-core>=4.7->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (4.3.7)
# Requirement already satisfied: pywin32>=300 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jupyter-core>=4.7->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (310)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from nbclient>=0.5.0->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (8.6.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (0.6.1)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (26.4.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (6.4.2)
# teradatagenai is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# Note: you may need to restart the kernel to use updated packages.
# WARNING: google-cloud-aiplatform 1.71.1 does not provide the extra 'all'
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# <b style = 'font-size:18px;font-family:Arial;color:#00233C'>Unstructured.io Platform and Environment Dependencies</b>

# %%
# %pip install unstructured-client
# %pip install python-dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting unstructured-client
#   Downloading unstructured_client-0.36.0-py3-none-any.whl.metadata (21 kB)
# Collecting aiofiles>=24.1.0 (from unstructured-client)
#   Using cached aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: cryptography>=3.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from unstructured-client) (44.0.2)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from unstructured-client) (0.28.1)
# Requirement already satisfied: nest-asyncio>=1.6.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from unstructured-client) (1.6.0)
# Requirement already satisfied: pydantic>=2.11.2 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from unstructured-client) (2.11.3)
# Collecting pypdf>=4.0 (from unstructured-client)
#   Downloading pypdf-5.6.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from unstructured-client) (1.0.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from cryptography>=3.1->unstructured-client) (1.17.1)
# Requirement already satisfied: anyio in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpx>=0.27.0->unstructured-client) (4.9.0)
# Requirement already satisfied: certifi in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpx>=0.27.0->unstructured-client) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpx>=0.27.0->unstructured-client) (1.0.9)
# Requirement already satisfied: idna in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpx>=0.27.0->unstructured-client) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pydantic>=2.11.2->unstructured-client) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pydantic>=2.11.2->unstructured-client) (2.33.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pydantic>=2.11.2->unstructured-client) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pydantic>=2.11.2->unstructured-client) (0.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.0.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests-toolbelt>=1.0.0->unstructured-client) (2.32.3)
# Requirement already satisfied: pycparser in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from cffi>=1.12->cryptography>=3.1->unstructured-client) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests<3.0.0,>=2.0.1->requests-toolbelt>=1.0.0->unstructured-client) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests<3.0.0,>=2.0.1->requests-toolbelt>=1.0.0->unstructured-client) (2.4.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from anyio->httpx>=0.27.0->unstructured-client) (1.3.1)
# Downloading unstructured_client-0.36.0-py3-none-any.whl (195 kB)
# Using cached aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading pypdf-5.6.0-py3-none-any.whl (304 kB)
# Installing collected packages: pypdf, aiofiles, unstructured-client
# Successfully installed aiofiles-24.1.0 pypdf-5.6.0 unstructured-client-0.36.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: python-dotenv in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (1.1.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# <b style = 'font-size:18px;font-family:Arial;color:#00233C'>Langchain Huggingface models to generate embeddings</b>

# %%
# %pip install langchain
# %pip install langchain-huggingface
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (0.3.24)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.55 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain) (0.3.56)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain) (0.3.34)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain) (2.11.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (4.13.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests<3,>=2->langchain) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests<3,>=2->langchain) (2025.1.31)
# Requirement already satisfied: greenlet>=1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.1)
# Requirement already satisfied: anyio in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.55->langchain) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langchain-huggingface
#   Downloading langchain_huggingface-0.3.0-py3-none-any.whl.metadata (996 bytes)
# Collecting langchain-core<1.0.0,>=0.3.65 (from langchain-huggingface)
#   Downloading langchain_core-0.3.65-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: tokenizers>=0.19.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-huggingface) (0.21.1)
# Requirement already satisfied: huggingface-hub>=0.30.2 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-huggingface) (0.30.2)
# Requirement already satisfied: filelock in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (6.0.2)
# Requirement already satisfied: requests in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (4.13.2)
# Collecting langsmith<0.4,>=0.3.45 (from langchain-core<1.0.0,>=0.3.65->langchain-huggingface)
#   Downloading langsmith-0.3.45-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (1.33)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (2.11.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests->huggingface-hub>=0.30.2->langchain-huggingface) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests->huggingface-hub>=0.30.2->langchain-huggingface) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests->huggingface-hub>=0.30.2->langchain-huggingface) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests->huggingface-hub>=0.30.2->langchain-huggingface) (2025.1.31)
# Requirement already satisfied: colorama in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.30.2->langchain-huggingface) (0.4.6)
# Requirement already satisfied: anyio in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (1.3.1)
# Downloading langchain_huggingface-0.3.0-py3-none-any.whl (27 kB)
# Downloading langchain_core-0.3.65-py3-none-any.whl (438 kB)
# Downloading langsmith-0.3.45-py3-none-any.whl (363 kB)
# Installing collected packages: langsmith, langchain-core, langchain-huggingface
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.3.34
#     Uninstalling langsmith-0.3.34:
#       Successfully uninstalled langsmith-0.3.34
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.56
#     Uninstalling langchain-core-0.3.56:
#       Successfully uninstalled langchain-core-0.3.56
# Successfully installed langchain-core-0.3.65 langchain-huggingface-0.3.0 langsmith-0.3.45
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install sentence_transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting sentence_transformers
#   Using cached sentence_transformers-4.1.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from sentence_transformers) (4.51.3)
# Requirement already satisfied: tqdm in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from sentence_transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from sentence_transformers) (2.7.0)
# Requirement already satisfied: scikit-learn in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from sentence_transformers) (1.6.1)
# Requirement already satisfied: scipy in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from sentence_transformers) (1.15.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from sentence_transformers) (0.30.2)
# Requirement already satisfied: Pillow in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from sentence_transformers) (11.2.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from sentence_transformers) (4.13.2)
# Requirement already satisfied: filelock in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (6.0.2)
# Requirement already satisfied: requests in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2.32.3)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from torch>=1.11.0->sentence_transformers) (1.13.3)
# Requirement already satisfied: networkx in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from torch>=1.11.0->sentence_transformers) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from torch>=1.11.0->sentence_transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from torch>=1.11.0->sentence_transformers) (79.0.1)
# Requirement already satisfied: colorama in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from tqdm->sentence_transformers) (0.4.6)
# Requirement already satisfied: numpy>=1.17 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2.2.5)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.5.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from scikit-learn->sentence_transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from scikit-learn->sentence_transformers) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence_transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jinja2->torch>=1.11.0->sentence_transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jv255027\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (2025.1.31)
# Using cached sentence_transformers-4.1.0-py3-none-any.whl (345 kB)
# Installing collected packages: sentence_transformers
# Successfully installed sentence_transformers-4.1.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# <b style = 'font-size:18px;font-family:Arial;color:#00233C'>Import necessary modules</b>

# %%
# Unstructured libraries
#from unstructured.partition.image import partition_image
#from unstructured.partition.pdf import partition_pdf
import os
import unstructured_client
from unstructured_client.models import operations, shared
from dotenv import load_dotenv

# For the Embeddigns
import sys
from langchain_huggingface.embeddings import HuggingFaceEmbeddings
import pandas as pd
import json

# Teradata Vector Store libraries
from getpass import getpass
from teradataml import create_context, set_auth_token, execute_sql, display, DataFrame
display.max_rows = 100000

import numpy as np
import re

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <b style = 'font-size:30px;font-family:Arial;color:#00233C'>2. Unstructured.io Partitioning into JSON </b>

# %% [markdown]
# ### 🔮 Using Unstructured.io Platform
#
# We can leverage the Unstructured Partition API to structure our file into a standard canonical JSON format
#
# 1. **Use the partition function**
#    - Insert your personal API key
#    - Specify our intput file and the name of our output file
#    - Then, we'll issue a partitioning request from the API, sending it our source document.
#       - We'll need to choose a partition strategy.

# %% [markdown]
# <div style="font-size:15px;font-family:Arial;color:#00233C;background:#fff8e6;padding:12px;border-radius:5px;border:1px solid #ffd700">
# <b>Note:</b> To run the notebook successfully, you'll need to grab your API Key by logging into Unstructured (https://platform.unstructured.io/app/start) then navigate to API Keys in the left-side navigation. Copy your API Key and paste it into the .env file where it currently reads UNSTRUCTURED_API_KEY=your-api-key-here.
# </div>

# %%
# Grab your API Key from the Unstructured Platform
load_dotenv('.env')
client = unstructured_client.UnstructuredClient(
    api_key_auth=os.getenv("UNSTRUCTURED_API_KEY") 
)

input_file = r"DensePassageRetrieval.pdf"
output_file = r"UnstructuredJSON.json"


req = operations.PartitionRequest(
    partition_parameters=shared.PartitionParameters(
        files=shared.Files(
            content=open(input_file, "rb"),
            file_name=input_file,
        ),
        strategy=shared.Strategy.AUTO,   # Select your strategy.
        vlm_model="gpt-4o",             # If the Auto router decides to use VLM, this is the model to use.
        vlm_model_provider="openai",    # If the Auto router decides to use VLM, this is the provider to use.
        languages=['eng'],             
        split_pdf_page=True,            # If True, splits the PDF file into smaller chunks of pages.
        split_pdf_allow_failed=True,    # If True, the partitioning continues even if some pages fail.
        split_pdf_concurrency_level=15  # Set the number of concurrent request to the maximum value: 15.
    ),
)

try:
    res = client.general.partition(
        request=req
    )
    element_dicts = [element for element in res.elements]
    
    # Print the processed data's first element only.
    print(element_dicts[0])

    # Write the processed data to a local file.
    json_elements = json.dumps(element_dicts, indent=2)

    with open(output_file, "w") as file:
        file.write(json_elements)
except Exception as e:
    print(e)
# Out:
# INFO: HTTP Request: GET https://api.unstructuredapp.io/general/docs "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructuredapp.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructuredapp.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructuredapp.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructuredapp.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructuredapp.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructuredapp.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructuredapp.io/general/v0/general "HTTP/1.1 200 OK"
# {'type': 'Title', 'element_id': '612608f1a7e0119bcbe324ba355526a7', 'text': 'Dense Passage Retrieval for Open-Domain Question Answering', 'metadata': {'filetype': 'application/pdf', 'languages': ['eng'], 'page_number': 1, 'filename': 'DensePassageRetrieval.pdf'}}

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <b style = 'font-size:30px;font-family:Arial;color:#00233C'>3. Generate Embeddings </b>

# %% [markdown]
# ### 🧩 Adding embeddings to the JSON file.
#
# 1. **Load the JSON file and add embeddings to each element.**
#    - Process each element in the JSON file.
#    - Save the updated JSON back into the original file.

# %%
if __name__ == "__main__":
    embeddings = HuggingFaceEmbeddings(
        model_name="sentence-transformers/all-MiniLM-L6-v2"
    )
    
    # Get the JSON file's path.
    if len(sys.argv) < 2:
        print("Error: Specify the path to the input JSON file.")
        print("For example, 'python embeddings.py myfile.json'")
        sys.exit(1)

    file_path = r"UnstructuredJSON.json"
    
    try:
        # Get the JSON file's contents.
        with open(file_path, 'r') as file:
            file_elements = json.load(file)

        for element in file_elements:
            # Get the element's "text" field.
            text = element["text"]
            # Generate the embeddings for that "text" field.
            query_result = embeddings.embed_query(text)
            # Add the embeddings to that element as an "embeddings" field.
            element["embeddings"] = query_result


        # Save the updated JSON back into the original file.
        with open(file_path, 'w') as file:
            json.dump(file_elements, file, indent=2)

        print(f"Done! Updated JSON saved to '{file_path}'.")

    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
    except IOError:
        print(f"Error: Unable to access file '{file_path}'.")
# Out:
# INFO: Use pytorch device_name: cpu
# INFO: Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# Done! Updated JSON saved to 'UnstructuredJSON.json'.

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <b style = 'font-size:30px;font-family:Arial;color:#00233C'>4. Connections </b>

# %% [markdown]
# #### Connection to Vantage

# %%
# Connect to Vantage using create_context.
hostname = getpass(prompt = 'hostname: ')
username = getpass(prompt = 'username: ')
password = getpass(prompt = 'password: ')

context=create_context(host=hostname, username=username, password=password)

# %% [markdown]
# #### Connection to the Vector Store

# %%
# Connect to Vector Store using VSManager
base_url = 'https://vectorstoreaws.staging.innovationlabs.teradata.com/api/accounts/45bc9b91-8bbf-4646-ba9c-cda9b9c8a77d'

pat = getpass("Enter pat token: ")
# Replace XXXX.pem with the path to your PEM file
set_auth_token(base_url=base_url, pat_token=pat, pem_file='XXXX.pem')
# Out:
# Authentication token is generated, authenticated and set for the session.
# True

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <b style = 'font-size:30px;font-family:Arial;color:#00233C'>5. Import Embeddings to a Table </b>

# %% [markdown]
# ### 🚚 Read in external embeddings and clean the input data.
#
# 1. **Define function to clean the input data**
#    - This function removes any non-ASCII characters from the text, ensuring that only clean, compatible strings are inserted into the database.
# 2. **Create `manual_vector_table` to store text and ambeddings**
#    - This table is designed to store the filename, text chunks, the embedding vector, and a message field.
#    - The Embedding column is set up to hold the vector type data for each text chunk.
# 3. **Open the JSON file and insert the text and embeddings**
#    - We open the processed JSON file, which contains a text field and an embeddings field. For each element, we:
#       - Clean the text using the clean_data function.
#       - Insert both the cleaned text and the embedding string into the manual_vector_table using an SQL INSERT statement.

# %%
#Clean data function
import re
def clean_data(data):
    # Remove non-ASCII characters
    return re.sub(r'[^\x00-\x7F]+', '', data)

# %% [markdown]
# ### ⛏️ Create the table to store the embeddings

# %%
#Create a multiset table to store the vector data
create_normalized_table_query = '''
CREATE MULTISET TABLE manual_vector_table, FALLBACK,
    NO BEFORE JOURNAL,
    NO AFTER JOURNAL,
    CHECKSUM = DEFAULT,
    DEFAULT MERGEBLOCKRATIO,
    MAP = TD_MAP2
    (
        TD_ID INTEGER GENERATED ALWAYS AS IDENTITY (START WITH 1 INCREMENT BY 1),
        TD_FILENAME VARCHAR(1024) CHARACTER SET LATIN NOT CASESPECIFIC,
        CHUNKS VARCHAR(32000) CHARACTER SET LATIN NOT CASESPECIFIC,
        Embedding VECTOR,
        Message VARCHAR(32000) CHARACTER SET LATIN NOT CASESPECIFIC)
    PRIMARY INDEX (TD_ID);
'''

#Execute the query to create the table
execute_sql(create_normalized_table_query)
# Out:
# TeradataCursor uRowsHandle=23 bClosed=False

# %% [markdown]
# ### ⛳ Insert embeddings into the table

# %%
# Open the JSON file and insert the text and embeddings into 'manual_vector_table' table
with open('UnstructuredJSON.json', 'r', encoding='utf-8') as f:
    elements = json.load(f)

for element in elements:
    text = element.get('text', '')
    embeddings = element.get('embeddings', [])
    if text and embeddings:
        cleaned_text = clean_data(str(text)).replace("'", "''")
        # Convert embeddings list to comma-separated string
        embedding_str = ','.join(map(str, embeddings))
        insert_query = f"""
        INSERT INTO manual_vector_table (TD_FILENAME, CHUNKS, Embedding, Message)
        VALUES ('DensePassageRetrieval', '{cleaned_text}', '{embedding_str}', 'Inserted by {username}');
        """
        execute_sql(insert_query)
        print(f"Inserted element: {cleaned_text[:50]}... Embedding: {embedding_str[:50]}...")
# Out:
# Inserted element: Dense Passage Retrieval for Open-Domain Question A... Embedding: 0.006719804834574461,-0.07860788702964783,0.026910...
# Inserted element: Vladimir Karpukhin, Barlas Oguz, Sewon Min, Patric... Embedding: -0.07869625836610794,0.07724092900753021,-0.014868...
# Inserted element: Facebook AI University of Washington Princeton Uni... Embedding: -0.07269953936338425,0.013929847627878189,0.015195...
# Inserted element: 0 2 0 2 p e S 0 3 ] L C . s c [ 3 v 6 0 9 4 0 . 4 ... Embedding: -0.016017088666558266,0.08001799136400223,-0.08393...
# Inserted element: Abstract... Embedding: -0.07030738145112991,0.08017941564321518,0.0270034...
# Inserted element: Open-domain question answering relies on ef- cient... Embedding: -0.003576873103156686,-0.09808897227048874,-0.0369...
# Inserted element: 1 Introduction... Embedding: -0.06705295294523239,0.04412911459803581,0.0160494...
# Inserted element: Open-domain question answering (QA) (Voorhees, 199... Embedding: -0.009778820909559727,-0.0032571149058640003,-0.04...
# Inserted element: Equal contribution... Embedding: -0.06476214528083801,0.09830563515424728,0.0685358...
# Inserted element: 1The code and trained models have been released at... Embedding: -0.15302874147891998,-0.07985217124223709,-0.08097...
# Inserted element: 2For instance, the exact match score on SQuAD v1.1... Embedding: -0.014116717502474785,-0.051878031343221664,-0.032...
# Inserted element: Retrieval in open-domain QA is usually imple- ment... Embedding: -0.005995696410536766,-0.05035160109400749,-0.0702...
# Inserted element: However, it is generally believed that learn- ing ... Embedding: -0.012990327551960945,-0.06046333163976669,-0.0328...
# Inserted element: QA datasets, it also suffers from two weaknesses. ... Embedding: -0.04696206375956535,0.03193769231438637,-0.016345...
# Inserted element: In this paper, we address the question: can we tra... Embedding: -0.019280487671494484,-0.06952635198831558,0.03893...
# Inserted element: Our contributions are twofold. First, we demon- st... Embedding: -0.0018820485565811396,-0.07961999624967575,-0.031...
# Inserted element: 2 Background... Embedding: -0.023455951362848282,0.032440755516290665,-0.0546...
# Inserted element: The problem of open-domain QA studied in this pape... Embedding: -0.02941030077636242,-0.00515192374587059,-0.01356...
# Inserted element: the extractive QA setting, in which the answer is ... Embedding: -0.09773004055023193,0.061891742050647736,0.010436...
# Inserted element: 3 Dense Passage Retriever (DPR)... Embedding: -0.0810992643237114,-0.08818607777357101,0.0034673...
# Inserted element: We focus our research in this work on improv- ing ... Embedding: -0.01428326964378357,-0.004632278811186552,0.01905...
# Inserted element: 3.1 Overview... Embedding: -0.07737492769956589,-0.044428907334804535,-0.0183...
# Inserted element: Our dense passage retriever (DPR) uses a dense enc... Embedding: -0.07486622780561447,-0.07802286744117737,-0.01481...
# Inserted element: 3The ideal size and boundary of a text passage are... Embedding: -0.03462878242135048,0.04869382083415985,0.0200129...
# Inserted element: 4Exceptions include (Seo et al., 2019) and (Robert... Embedding: -0.02125431038439274,0.015048841014504433,0.013823...
# Inserted element: At run-time, DPR applies a different encoder EQ() ... Embedding: -0.062485307455062866,0.030893689021468163,-0.0850...
# Inserted element: sim(q, p) Eq(q)Ep(p)... Embedding: -0.013403479941189289,0.06963975727558136,-0.00397...
# Inserted element: Although more expressive model forms for measur- i... Embedding: -0.06687076389789581,-0.08593454957008362,0.014123...
# Inserted element: Encoders Although in principle the question and pa... Embedding: -0.11553166806697845,-0.07340019196271896,-0.00872...
# Inserted element: Inference During inference time, we apply the pass... Embedding: -0.03127904236316681,-0.06532640755176544,-0.02388...
# Inserted element: 3.2 Training... Embedding: -0.004483100958168507,-0.056211329996585846,0.0097...
# Inserted element: Training the encoders so that the dot-product sim-... Embedding: -0.07395472377538681,-0.10901372879743576,-0.03405...
# Inserted element: (1)... Embedding: -0.03755893185734749,0.04267497360706329,0.0378313...
# Inserted element: larity) than the irrelevant ones, by learning a be... Embedding: 0.034845512360334396,-0.12423913925886154,0.021534...
# Inserted element:  Let D = p Pi 1 be the training data that consists... Embedding: -0.03922585770487785,-0.02554485946893692,0.027919...
# Inserted element: L(gi,pi Pi) e sim(q; lo, esim(qip im(i; ;) + Y... Embedding: -0.08626963943243027,0.04127034544944763,0.0287981...
# Inserted element: Positive and negative passages For retrieval probl... Embedding: -0.05718020722270012,0.022601494565606117,0.003691...
# Inserted element: In-batch negatives Assume that we have B questions... Embedding: -0.046035122126340866,0.01401466503739357,-0.01857...
# Inserted element: (2)... Embedding: -0.02343929000198841,0.03415648266673088,0.0079048...
# Inserted element: negative passages for each question.... Embedding: 0.03929625451564789,0.1321200430393219,0.027463104...
# Inserted element: The trick of in-batch negatives has been used in t... Embedding: -0.05457700416445732,-0.03753479942679405,-0.00918...
# Inserted element: 4 Experimental Setup... Embedding: 0.05232923477888107,0.0017713095294311643,-0.00276...
# Inserted element: In this section, we describe the data we used for ... Embedding: -0.040615472942590714,-0.012753679417073727,-0.018...
# Inserted element: 4.1 Wikipedia Data Pre-processing... Embedding: 0.028287511318922043,-0.003153950208798051,-0.0092...
# Inserted element: Following (Lee et al., 2019), we use the English W... Embedding: -0.07517264783382416,0.08143799751996994,0.1067142...
# Inserted element: 4.2 Question Answering Datasets... Embedding: -0.030969390645623207,-0.02751610055565834,0.03401...
# Inserted element: We use the same ve QA datasets and train- ing/dev/... Embedding: -0.0564415343105793,0.001136028440669179,-0.001022...
# Inserted element: Natural Questions (NQ) (Kwiatkowski et al., 2019) ... Embedding: -0.06830557435750961,0.00498442305251956,0.0068510...
# Inserted element: TriviaQA (Joshi et al., 2017) contains a set of tr... Embedding: -0.08729065209627151,0.011450611054897308,-0.05585...
# Inserted element: WebQuestions (WQ) (Berant et al., 2013) consists o... Embedding: -0.05190565809607506,-0.015111064538359642,0.00520...
# Inserted element: CuratedTREC (TREC) (Baudis and Sediv`y, 2015) sour... Embedding: -0.045032430440187454,-0.09949337691068649,-0.0485...
# Inserted element: 5However, Wang et al. (2019) also propose splittin... Embedding: -0.07869978249073029,0.03680405020713806,0.0246598...
# Inserted element: Dataset Train Dev Test Natural Questions 79,168 58... Embedding: -0.010780506767332554,-0.08418327569961548,-0.0082...
# Inserted element: Table 1: Number of questions in each QA dataset. T... Embedding: -0.03313785418868065,-0.018825571984052658,-0.0754...
# Inserted element: as well as various Web sources and is intended for... Embedding: -0.015128649771213531,-0.0517234280705452,-0.01479...
# Inserted element: Selection of positive passages Because only pairs ... Embedding: -0.06920520216226578,0.029264269396662712,-0.02221...
# Inserted element: 5 Experiments: Passage Retrieval... Embedding: -0.004575429018586874,0.00507646519690752,0.045289...
# Inserted element: In this section, we evaluate the retrieval perfor-... Embedding: -0.04326610639691353,-0.04234396293759346,-0.00713...
# Inserted element: 6We use the unltered TriviaQA version and discard ... Embedding: -0.011544610373675823,-0.003428171155974269,-0.004...
# Inserted element: 7The improvement of using gold contexts over passa... Embedding: -0.05051532760262489,0.05490785464644432,0.0314819...
# Inserted element: Training Retriever Top-20 Top-100 NQ TriviaQA WQ T... Embedding: -0.07398372143507004,-0.08970938622951508,-0.05473...
# Inserted element: Table 2: Top-20 & Top-100 retrieval accuracy on te... Embedding: -0.002845828188583255,-0.0741361603140831,-0.03291...
# Inserted element: traditional retrieval methods, the effects of diff... Embedding: 0.005268237087875605,-0.007637583184987307,-0.0410...
# Inserted element: The DPR model used in our main experiments is trai... Embedding: -0.07916371524333954,-0.05864720046520233,0.000565...
# Inserted element: While it is good to have the exibility to adapt th... Embedding: -0.07771935313940048,-0.09884350746870041,-0.02360...
# Inserted element: 5.1 Main Results... Embedding: -0.047479040920734406,-0.039167944341897964,0.1168...
# Inserted element: Table 2 compares different passage retrieval sys- ... Embedding: -0.021713806316256523,-0.07277410477399826,-0.0385...
# Inserted element: 8SQuAD is limited to a small set of Wikipedia docu... Embedding: -0.056652918457984924,0.025667207315564156,0.05929...
# Inserted element: 9Lucene implementation. BM25 parameters b = 0.4 (d... Embedding: 0.00792404543608427,-0.030388738960027695,-0.02560...
# Inserted element: 90 3 3 3 BM25 # Train: 1k # Train: 10k Top-k accur... Embedding: 0.0036390440072864294,0.002703503705561161,-0.0855...
# Inserted element: Figure 1: Retriever top-k accuracy with different ... Embedding: -0.020712831988930702,-0.09333248436450958,0.03299...
# Inserted element: tiple datasets, TREC, the smallest dataset of the ... Embedding: 0.024199631065130234,-0.10945948213338852,-0.03812...
# Inserted element: We conjecture that the lower performance on SQuAD ... Embedding: -0.006454002112150192,-0.023190893232822418,-0.024...
# Inserted element: 5.2 Ablation Study on Model Training... Embedding: 0.01606179215013981,-0.08954185992479324,0.0364453...
# Inserted element: To understand further how different model training... Embedding: 0.0025563633535057306,-0.0940842404961586,0.049530...
# Inserted element: Sample efciency We explore how many train- ing exa... Embedding: 0.03919554874300957,-0.06314798444509506,0.0356648...
# Inserted element: In-batch negative training We test different train... Embedding: 0.003992541693150997,0.018585054203867912,0.002080...
# Inserted element: The middle bock is the in-batch negative training ... Embedding: -0.04868259280920029,-0.011713801883161068,0.00563...
# Inserted element: Finally, we explore in-batch negative training wit... Embedding: 0.014783509075641632,0.022164735943078995,-0.01442...
# Inserted element: Impact of gold passages We use passages that match... Embedding: -0.02822229452431202,0.04592100903391838,0.0507507...
# Inserted element: Type #N 1B Top-5 Top-20 Top-100 Random X 47.0 64.3... Embedding: -0.023536449298262596,-0.06741282343864441,-8.1761...
# Inserted element: Table 3: Comparison of different training schemes,... Embedding: -0.06263654679059982,-0.05060797929763794,-0.03592...
# Inserted element: Our experiments on Natural Questions show that swi... Embedding: 0.021453458815813065,-0.06756888329982758,0.039078...
# Inserted element: Similarity and loss Besides dot product, cosine an... Embedding: -0.059747364372015,-0.06347326189279556,-0.0144299...
# Inserted element: Cross-dataset generalization One interesting quest... Embedding: -0.058187369257211685,-0.13216151297092438,-0.0022...
# Inserted element: 5.3 Qualitative Analysis... Embedding: 0.024873558431863785,0.025158001109957695,0.039461...
# Inserted element: Although DPR performs better than BM25 in gen- era... Embedding: -0.04969233646988869,-0.03502768278121948,0.034646...
# Inserted element: 5.4 Run-time Efciency... Embedding: -0.0019730010535568,0.009883382357656956,0.0062710...
# Inserted element: The main reason that we require a retrieval compo-... Embedding: -0.04647619277238846,-0.05129094049334526,-0.06208...
# Inserted element: On the other hand, the time required for building ... Embedding: 0.006867547053843737,-0.10387388616800308,0.029034...
# Inserted element: 6 Experiments: Question Answering... Embedding: -0.016888005658984184,0.015092880465090275,0.03099...
# Inserted element: In this section, we experiment with how different ... Embedding: -0.05922545865178108,0.020481832325458527,-0.02499...
# Inserted element: 6.1 End-to-end QA System... Embedding: -0.05583002790808678,0.0052159870974719524,-0.0505...
# Inserted element: We implement an end-to-end question answering syst... Embedding: -0.06441328674554825,-0.017790596932172775,-0.0181...
# Inserted element: 10FAISS conguration: we used HNSW index type on CP... Embedding: -0.010633192025125027,0.01314612478017807,-0.06221...
# Inserted element: score is chosen as the nal answer. The passage sel... Embedding: 0.029465194791555405,-0.005659940652549267,-0.0017...
# Inserted element: Specically, let Pi  RLh (1  i  k) be a BERT (base,... Embedding: -0.1122308298945427,-0.06036163493990898,0.0672146...
# Inserted element: softmax nd softmax (P;Wena) o Prelected softmax (P... Embedding: -0.08030395209789276,-0.07928148657083511,0.065192...
# Inserted element: where P = [P[CLS] ,...,P[CLS] ]  Rhk and 1 k wstar... Embedding: -0.007858777418732643,-0.004586673341691494,-0.032...
# Inserted element: During training, we sample one positive and m1 neg... Embedding: 0.006646499037742615,-0.03618556633591652,-0.02125...
# Inserted element: 6.2 Results... Embedding: -0.03947903960943222,0.010102004744112492,0.047882...
# Inserted element: Table 4 summarizes our nal end-to-end QA re- sults... Embedding: -0.08964146673679352,0.012195458635687828,0.034785...
# Inserted element: (3)... Embedding: -0.041856616735458374,0.026411594823002815,-0.0212...
# Inserted element: (4)... Embedding: 0.03585866093635559,0.07288187742233276,0.00277040...
# Inserted element: (5)... Embedding: -0.04548659920692444,0.04581340774893761,0.0387571...
# Inserted element: Training Model NQ TriviaQA WQ TREC SQuAD Single BM... Embedding: -0.08602380752563477,-0.08056032657623291,-0.05690...
# Inserted element: Table 4: End-to-end QA (Exact Match) Accuracy. The... Embedding: -0.005255109164863825,-0.09500385820865631,-0.0851...
# Inserted element: see that higher retriever accuracy typically leads... Embedding: -0.09572651982307434,-0.07565928250551224,-0.01807...
# Inserted element: To compare our pipeline training approach with joi... Embedding: -0.06881602108478546,-0.08059746026992798,0.044172...
# Inserted element: trained, following Lee et al. (2019). This approac... Embedding: -0.10646063089370728,-0.05954050272703171,-0.00670...
# Inserted element: One thing worth noticing is that our reader does c... Embedding: -0.048276014626026154,-0.0317695327103138,-0.01475...
# Inserted element: 7 Related Work... Embedding: -0.09203139692544937,0.0151843735948205,-0.0129102...
# Inserted element: Passage retrieval has been an important compo- nen... Embedding: -0.06717489659786224,0.0014412845484912395,-0.0376...
# Inserted element: been used as the standard method applied broadly t... Embedding: -0.07701804488897324,0.017957625910639763,-0.04436...
# Inserted element: The use of dense vector representations for re- tr... Embedding: -0.0687209814786911,-0.08223668485879898,-0.043026...
# Inserted element: Dense retrieval for open-domain QA has been explor... Embedding: -0.020705249160528183,-0.0794484093785286,-0.03105...
# Inserted element: effective solution that shows stronger empirical p... Embedding: -0.028940187767148018,-0.02444496378302574,0.08025...
# Inserted element: DPR has also been used as an important mod- ule in... Embedding: -0.14123891294002533,-0.05147251486778259,-0.00109...
# Inserted element: 8 Conclusion... Embedding: -0.012562049552798271,0.12263616919517517,0.063848...
# Inserted element: In this work, we demonstrated that dense retrieval... Embedding: 0.004412736743688583,-0.1400170624256134,-0.031639...
# Inserted element: Acknowledgments... Embedding: -0.09931075572967529,0.01861116662621498,-0.034592...
# Inserted element: We thank the anonymous reviewers for their helpful... Embedding: -0.1515931636095047,0.0568285770714283,0.005302159...
# Inserted element: References... Embedding: -0.07505083084106445,-0.002889539347961545,-0.0798...
# Inserted element: Akari Asai, Kazuma Hashimoto, Hannaneh Hajishirzi,... Embedding: -0.023038599640130997,-0.023266753181815147,-0.034...
# Inserted element: Petr Baudis and Jan Sediv`y. 2015. Modeling of the... Embedding: -0.031083181500434875,0.04602434113621712,0.008017...
# Inserted element: Jonathan Berant, Andrew Chou, Roy Frostig, and Per... Embedding: -0.0017936392687261105,-0.05085432529449463,0.0435...
# Inserted element: question-answer pairs. In Empirical Methods in Nat... Embedding: -0.00985571276396513,0.041795048862695694,0.064742...
# Inserted element: Jane Bromley, Isabelle Guyon, Yann LeCun, Eduard S... Embedding: -0.04566051438450813,-0.06000378727912903,0.035172...
# Inserted element: Chris Burges, Tal Shaked, Erin Renshaw, Ari Lazier... Embedding: -0.052688684314489365,-0.13046033680438995,0.02736...
# Inserted element: Danqi Chen, Adam Fisch, Jason Weston, and Antoine ... Embedding: -0.016088323667645454,-0.08259530365467072,0.00189...
# Inserted element: Rajarshi Das, Shehzaad Dhuliawala, Manzil Zaheer, ... Embedding: -0.019458390772342682,-0.05319720134139061,-0.0277...
# Inserted element: Scott Deerwester, Susan T Dumais, George W Fur- na... Embedding: 0.07246192544698715,-0.03848249092698097,-0.040498...
# Inserted element: Jacob Devlin, Ming-Wei Chang, Kenton Lee, and Kris... Embedding: -0.11637531220912933,-0.06372774392366409,0.112936...
# Inserted element: David A Ferrucci. 2012. Introduction to This is Wa... Embedding: -0.1043938621878624,0.10582678765058517,-0.0352475...
# Inserted element: Daniel Gillick, Sayali Kulkarni, Larry Lansing, Al... Embedding: -0.06782004982233047,-0.08891472220420837,0.050870...
# Inserted element: Ruiqi Guo, Sanjiv Kumar, Krzysztof Choromanski, an... Embedding: -0.04521240293979645,-0.03164967894554138,0.066695...
# Inserted element: Kelvin Guu, Kenton Lee, Zora Tung, Panupong Pa- su... Embedding: -0.03111952170729637,-0.08000601083040237,-0.02309...
# Inserted element: Matthew Henderson, Rami Al-Rfou, Brian Strope, Yun... Embedding: -0.04985123500227928,-0.04595909267663956,0.078675...
# Inserted element: Po-Sen Huang, Xiaodong He, Jianfeng Gao, Li Deng, ... Embedding: -0.016201050952076912,-0.0391300804913044,0.028731...
# Inserted element: clickthrough data. In ACM International Confer- en... Embedding: 0.022389540448784828,-0.016268784180283546,-0.0771...
# Inserted element: Samuel Humeau, Kurt Shuster, Marie-Anne Lachaux, a... Embedding: 0.007260921876877546,-0.10636042803525925,0.037107...
# Inserted element: Gautier Izacard and Edouard Grave. 2020. Leveragin... Embedding: 0.0050193145871162415,-0.0026388270780444145,0.066...
# Inserted element: Jeff Johnson, Matthijs Douze, and Herve Jegou. 201... Embedding: -0.06974169611930847,-0.039690449833869934,-0.0461...
# Inserted element: Mandar Joshi, Eunsol Choi, Daniel Weld, and Luke Z... Embedding: 0.014872102998197079,-0.07260487228631973,0.055116...
# Inserted element: Omar Khattab and Matei Zaharia. 2020. ColBERT: Efc... Embedding: -0.018390268087387085,0.021679729223251343,0.00999...
# Inserted element: Brian Kulis. 2013. Metric learning: A survey. Foun... Embedding: -0.040445342659950256,-0.1099652424454689,0.035613...
# Inserted element: Tom Kwiatkowski, Jennimaria Palomaki, Olivia Red- ... Embedding: 0.011167537420988083,-0.04813266918063164,0.005504...
# Inserted element: Kenton Lee, Ming-Wei Chang, and Kristina Toutanova... Embedding: 0.04066292941570282,-0.08922434598207474,0.0339088...
# Inserted element: Mike Lewis, Yinhan Liu, Naman Goyal, Mar- jan Ghaz... Embedding: -0.017570553347468376,-0.094413161277771,0.0432614...
# Inserted element: Patrick Lewis, Ethan Perez, Aleksandara Piktus, Fa... Embedding: -0.12800130248069763,-0.006831561215221882,-0.0152...
# Inserted element: Yankai Lin, Haozhe Ji, Zhiyuan Liu, and Maosong Su... Embedding: 0.00964857917279005,-0.11228519678115845,0.0342997...
# Inserted element: Sewon Min, Danqi Chen, Hannaneh Hajishirzi, and Lu... Embedding: -0.02064998261630535,0.013610570691525936,0.068378...
# Inserted element: Sewon Min, Danqi Chen, Luke Zettlemoyer, and Han- ... Embedding: 0.024521920830011368,0.08552251756191254,0.0220168...
# Inserted element: Dan Moldovan, Marius Pasca, Sanda Harabagiu, and M... Embedding: 0.019525395706295967,-0.03328141197562218,-0.09291...
# Inserted element: Stephen Mussmann and Stefano Ermon. 2016. Learn- i... Embedding: -0.015484082512557507,-0.07527464628219604,0.06385...
# Inserted element: Yixin Nie, Songhe Wang, and Mohit Bansal. 2019. Re... Embedding: 0.019451647996902466,0.012253194116055965,0.105123...
# Inserted element: Rodrigo Nogueira and Kyunghyun Cho. 2019. Passage ... Embedding: -0.042518746107816696,-0.0316014401614666,0.052740...
# Inserted element: Colin Raffel, Noam Shazeer, Adam Roberts, Katherin... Embedding: -0.01875285804271698,-0.06500624120235443,-0.00671...
# Inserted element: Pranav Rajpurkar, Jian Zhang, Konstantin Lopyrev, ... Embedding: 0.028870251029729843,0.00026019051438197494,0.0808...
# Inserted element: Parikshit Ram and Alexander G Gray. 2012. Maximum ... Embedding: 0.008444291539490223,-0.008519267663359642,0.02306...
# Inserted element: Adam Roberts, Colin Raffel, and Noam Shazeer. 2020... Embedding: 0.00961300078779459,-0.07658060640096664,-0.034240...
# Inserted element: Stephen Robertson and Hugo Zaragoza. 2009. The pro... Embedding: 0.012443413026630878,-0.009445908479392529,0.01994...
# Inserted element: Minjoon Seo, Jinhyuk Lee, Tom Kwiatkowski, Ankur P... Embedding: -0.020408496260643005,-0.05341175198554993,0.00520...
# Inserted element: Anshumali Shrivastava and Ping Li. 2014. Asymmet- ... Embedding: -0.10764938592910767,-0.1350143998861313,0.0510859...
# Inserted element: Ellen M Voorhees. 1999. The TREC-8 question an- sw... Embedding: -0.03377504646778107,-0.017514141276478767,0.01645...
# Inserted element: Shuohang Wang, Mo Yu, Xiaoxiao Guo, Zhiguo Wang, T... Embedding: -0.0045708720572292805,-0.06453032791614532,0.0155...
# Inserted element: Zhiguo Wang, Patrick Ng, Xiaofei Ma, Ramesh Nalla-... Embedding: -0.0548987090587616,-0.08943331241607666,0.0798334...
# Inserted element: Tomer Wolfson, Mor Geva, Ankit Gupta, Matt Gard- n... Embedding: -0.04933345690369606,-0.04715606942772865,-0.03304...
# Inserted element: Lee Xiong, Chenyan Xiong, Ye Li, Kwok-Fung Tang, J... Embedding: 0.012962795794010162,-0.08312199264764786,0.001938...
# Inserted element: Wenhan Xiong, Hankang Wang, and William Yang Wang.... Embedding: 0.03114638477563858,-0.09825760871171951,0.0889082...
# Inserted element: Wei Yang, Yuqing Xie, Aileen Lin, Xingyu Li, Luche... Embedding: -0.03099841997027397,-0.09779815375804901,0.082609...
# Inserted element: Wei Yang, Yuqing Xie, Luchen Tan, Kun Xiong, Ming ... Embedding: -0.06077875569462776,-0.08849907666444778,0.045970...
# Inserted element: Wen-tau Yih, Kristina Toutanova, John C Platt, and... Embedding: -0.011479873210191727,-0.11888712644577026,0.00014...
# Inserted element: A Distant Supervision... Embedding: -0.024211889132857323,-0.013817687518894672,0.0128...
# Inserted element: When training our nal DPR model using Natural Ques... Embedding: -0.0036397299263626337,0.0002131180663127452,-0.00...
# Inserted element: B Alternative Similarity Functions & Triplet Loss... Embedding: -0.10454386472702026,-0.029716145247220993,-0.0053...
# Inserted element: In addition to dot product (DP) and negative log- ... Embedding: -0.04321279749274254,-0.10516908019781113,-0.01510...
# Inserted element: Note that the retrieval accuracy for our baseline ... Embedding: -0.009258870035409927,-0.07335155457258224,-0.0099...
# Inserted element: C Qualitative Analysis... Embedding: 0.02734949067234993,0.04687582328915596,-0.0232851...
# Inserted element: Although DPR performs better than BM25 in gen- era... Embedding: -0.024160264059901237,-0.061376236379146576,0.0462...
# Inserted element: Top-1 Top-5 Top-20 Top-100 Gold 44.9 66.8 78.1 85.... Embedding: -0.030156897380948067,-0.030658207833766937,-0.011...
# Inserted element: Table 5: Retrieval accuracy on the development set... Embedding: 0.009490936994552612,-0.03227214887738228,-0.01272...
# Inserted element: Sim Loss Retrieval Accuracy Top-1 Top-5 Top-20 Top... Embedding: -0.0597941018640995,-0.02085644006729126,0.0069806...
# Inserted element: Table 6: Retrieval Top-k accuracy on the developme... Embedding: 0.028026770800352097,-0.012748331762850285,-0.0278...
# Inserted element: the correct answer, presumably by matching body of... Embedding: -0.005370293278247118,0.013698926195502281,0.05494...
# Inserted element: D Joint Training of Retriever and Reader... Embedding: -0.0207359679043293,-0.06644164025783539,0.0242231...
# Inserted element: We x the passage encoder in our joint-training sch... Embedding: -0.032175108790397644,-0.004804423078894615,-0.012...
# Inserted element: Question Passage received by BM25 Passage retrieve... Embedding: 0.0662216991186142,-0.01194151770323515,-0.0082356...
# Inserted element: Table 7: Examples of passages returned from BM25 a... Embedding: -0.03461272642016411,-0.005417072679847479,0.00558...
# Inserted element: from the top 5 positive and top 30 negative passag... Embedding: -0.0438699834048748,0.03369603306055069,-0.0160528...
# Inserted element: (from the set of top 100 passages retrieved from t... Embedding: -0.10758163034915924,-0.04582158476114273,0.018235...

# %% [markdown]
# ### 🔎 View embeddings table

# %%
#View the data in the table
query = '''
SELECT * FROM manual_vector_table;
'''
view_table_query = DataFrame.from_query(query)
view_table_query.head(7)
# Out:
#                  TD_FILENAME                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    CHUNKS                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Embedding               Message
# TD_ID
# 3      DensePassageRetrieval                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Facebook AI University of Washington Princeton University {vladk, barlaso, plewis, ledell, edunov, scottyih}@fb.com sewon@cs.washington.edu danqic@cs.princeton.edu  -0.0726995,0.0139298,0.0151958,-0.0126643,0.0389015,-0.0123666,-0.0445955,0.0174049,-0.00723439,0.0708059,-0.0810606,0.0078213,-0.0117672,-0.00563176,-0.056721,0.0322114,-0.0666324,-0.00873865,-0.102761,-0.0623458,-0.0239661,-0.0710487,0.0812523,0.0026058,0.0992401,-0.0134314,0.025281,-0.0549839,-0.0519703,-0.0122377,-0.0201532,0.0050372,0.0522103,0.044367,0.00340098,0.0606971,0.0218732,-0.0265853,0.0197702,0.0907183,-0.0089695,0.0156797,0.0443042,0.0796915,-0.0270233,-0.0202743,-0.0730391,0.0221031,0.00855158,0.0473266,-0.0482327,-0.0641392,-0.0634462,-0.00153093,0.022955,-0.0276778,0.00478713,-0.0425063,0.0441129,-0.0865652,0.0903969,-0.0617759,-0.027333,0.0563657,-0.00964617,0.0347966,-0.0304509,0.0999693,-0.0605797,0.00803025,0.0785326,0.054446,-0.141273,0.0791192,0.125719,-0.000671191,0.0485317,0.00901649,0.0680933,0.0161869,0.0597085,0.0211119,-0.0639796,0.0176985,-0.0213921,-0.0431571,-0.0331445,-0.00307077,0.041488,0.00752886,0.0362586,-0.0304417,0.042163,-0.00077586,-0.0488826,0.0410069,0.0583967,-0.  Inserted by jv255027
# 5      DensePassageRetrieval                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Abstract  -0.0703074,0.0801794,0.0270034,0.0737213,-0.0420153,0.0238428,0.0908376,0.00657621,0.0198842,-0.0525052,-0.0403595,-0.045335,-0.0283148,0.0471992,0.0288397,0.0269414,0.0212424,0.0350477,-0.0686665,0.00366536,-0.0225484,-0.0171944,-0.0395115,0.09404,-0.0151519,0.0800732,-0.000811056,-0.0544979,0.110169,-0.080082,-0.0742674,0.0646266,0.11671,0.0394853,0.0277309,0.0528089,-0.0378925,0.00843916,0.00615645,-0.0142495,-0.062488,-0.099286,0.0153839,-0.0413821,0.0311901,0.0472025,0.0364259,0.0179786,0.022274,-0.0212057,-0.0844268,-0.00588295,-0.0787048,-0.0283128,0.00696183,0.0096319,0.00444356,-0.00849835,-0.069544,-0.0828148,0.0556824,-0.0283274,-0.0371266,0.0775779,0.145314,0.0739408,0.0294233,0.00187529,0.0021405,-0.0238546,0.0452101,-0.0139842,0.0315633,0.0517463,0.0150771,-0.00173428,0.0172872,-0.0400522,-0.0177304,-0.0832971,0.0548231,-0.00853285,-0.00504184,0.0298536,0.0455185,0.0533715,0.0289,-0.0329976,-0.0774625,0.0412692,-0.0405982,-0.0287934,-0.00641202,-0.0108407,-0.0314121,-0.00277382,-0.0309802,-0.112  Inserted by jv255027
# 6      DensePassageRetrieval  Open-domain question answering relies on ef- cient passage retrieval to select candidate contexts, where traditional sparse vector space models, such as TF-IDF or BM25, are the de facto method. In this work, we show that retrieval can be practically implemented us- ing dense representations alone, where em- beddings are learned from a small number of questions and passages by a simple dual- encoder framework. When evaluated on a wide range of open-domain QA datasets, our dense retriever outperforms a strong Lucene- BM25 system greatly by 9%-19% absolute in terms of top-20 passage retrieval accuracy, and helps our end-to-end QA system establish new state-of-the-art on multiple open-domain QA benchmarks.1  -0.00357687,-0.098089,-0.0369103,-0.00398468,0.0352554,0.0348392,-0.00921226,-0.00142209,0.0384983,-0.0358102,-0.0667503,-0.0344209,0.00344737,0.0583707,-0.0421205,0.0299377,0.0833959,0.0179095,-0.0408222,-0.0402595,-0.00892963,0.0765905,0.0951616,-0.0109205,0.00124453,-0.0347838,-0.00886394,-0.0286417,0.0119755,-0.0225297,0.0827375,0.105546,-0.0399124,0.0214271,-0.0117335,0.0416955,-0.0496575,-0.00145719,-0.0660651,-0.0482746,-0.0215428,-0.0118837,0.000148344,0.108167,0.0821204,-0.0356091,-0.0771505,-0.0419309,0.145817,-0.0134932,-0.0484255,0.0824093,-0.0173305,0.0601516,-0.0233921,-0.0284042,0.00960159,0.0226161,-0.0410531,-0.0666031,-0.0638868,-0.120764,0.00055486,0.0335424,0.0288156,-0.0689493,-0.0168115,0.0578674,-0.096062,-0.0406351,-0.0611138,0.0742847,-0.0390684,0.0884922,0.0149224,0.0839525,-0.0117136,-0.0139656,0.0447698,0.0500263,0.0179081,-0.0370583,0.0428149,0.000479296,0.0793261,0.0248086,0.0443574,-0.0205271,-0.0269504,0.0191918,0.0175396,-0.086327,0.115236,-0.0435643,0.0289433,-0.0179538,0.038  Inserted by jv255027
# 7      DensePassageRetrieval                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1 Introduction  -0.067053,0.0441291,0.0160494,0.03354,-0.0411062,0.0337517,0.109698,0.0581157,-0.0916687,0.0150234,0.0196772,0.0523577,0.0245594,-0.110144,-0.0658405,-0.0202881,0.00413536,-0.136909,-0.00910799,-0.00811985,-0.00414451,0.010759,-0.0127994,0.025952,-0.0388696,0.0406247,-0.00154576,0.0692372,0.0720736,-0.0109602,0.0240006,0.0315372,0.0545386,0.0408337,-0.00400053,0.0164184,0.0863907,0.000219239,-0.0434712,0.0337521,-0.00593147,-0.0429277,-0.0499179,0.0203119,0.0215571,-0.0336351,0.0182567,0.0321324,-0.0261081,-0.0645302,-0.0933298,0.00867052,-0.0339995,-0.0209752,0.0369134,-0.0036753,-0.0441681,-0.0102235,-0.0268285,-0.0782958,0.0858966,-0.0465874,-0.038368,0.0204411,0.122216,-0.0528911,0.036583,0.0222978,-0.0294393,0.0790121,-0.122373,-0.00311404,-0.0566355,0.0257073,-0.0405956,-0.0794806,-0.0630386,0.0111156,0.0469213,-0.112602,-0.00704524,-0.0244204,0.0168665,0.00261548,-0.0799142,0.0426457,-0.0160794,-0.0233931,0.013393,-0.00214111,0.047047,-0.0744472,0.0302631,0.0262625,0.0260447,0.0440763,-0.0250327,-0.067  Inserted by jv255027
# 4      DensePassageRetrieval                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       0 2 0 2 p e S 0 3 ] L C . s c [ 3 v 6 0 9 4 0 . 4 0 0 2 : v i X r a  -0.0160171,0.080018,-0.0839371,-0.0168063,0.0373861,0.0770971,0.0184419,0.0566068,-0.0254416,0.0560187,0.00964519,-0.0748477,-0.052806,0.028619,-0.010453,-0.0204012,-0.159439,0.0600414,-0.0540232,0.135784,0.0603782,0.0129965,0.0109377,-0.0213301,0.0927204,0.0837592,0.0350794,0.0955314,0.020654,-0.0854649,0.0345871,0.0199995,0.0542129,-0.0382195,0.0192277,-0.015948,-0.0523418,-0.016789,-0.0293462,0.0555183,0.00899881,-0.0608179,0.110382,0.0582326,0.0772638,0.0299989,-0.00595148,0.0481235,0.0404962,-0.0543235,0.0361774,0.0281845,-0.0661399,0.040076,-0.0117367,-0.0527859,-0.0420792,-0.0262968,0.0593599,-0.0585536,0.0746361,0.0574836,0.0108573,0.071276,0.066842,0.0044652,-0.00603801,-0.0321685,-0.0473844,0.0687148,-0.0925419,0.0255356,-0.0529745,-0.111586,-0.00662297,-0.0529366,-0.00511951,-0.0999277,0.0304517,-0.0339461,-0.0299723,-0.0313971,-0.0576269,0.0228033,-0.0679483,-0.0245869,-0.0202268,0.0178977,0.0732843,-0.0177939,-0.01101,-0.0120756,-0.0527476,-0.0982781,-0.0486586,0.0565602,0.0747702,-0.109699,0.051  Inserted by jv255027
# 2      DensePassageRetrieval                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Vladimir Karpukhin, Barlas Oguz, Sewon Min, Patrick Lewis, Ledell Wu, Sergey Edunov, Danqi Chen, Wen-tau Yih  -0.0786963,0.0772409,-0.014869,-0.0084891,-0.0984012,0.0344331,0.0230035,0.0723782,-0.00180247,0.0294389,0.0067428,0.0111893,0.0126232,-0.00553797,-0.067975,-0.0233089,-0.0954632,0.0190879,-0.0057421,-0.102084,-0.0530566,-0.123068,0.0445323,0.0400684,0.0515548,-0.0334468,-0.0633823,-0.0307297,-0.00214802,-0.050904,-0.110907,-0.00453628,0.0891365,0.000578363,-0.0312693,0.0635706,-0.00779282,0.04635,-0.00532421,0.0604804,0.0224387,-0.039324,0.0204652,-0.0161818,0.0705347,0.0150754,-0.0505254,-0.0144277,-0.164104,0.0723621,-0.0435155,-0.0205274,0.0237594,0.0843803,0.0890165,-0.0945998,-0.0422416,-0.102982,0.0312494,-0.0654638,0.0564474,-0.0134728,-0.121963,0.0279698,-0.0129361,0.0274592,0.00386597,-0.0165906,-0.0221237,0.0951592,0.0598989,-0.0372425,-0.0670083,-0.000452997,0.0114917,-0.0141692,0.00574278,0.0243508,-0.0653452,-0.0588097,0.0621475,0.100465,0.0101221,0.0134128,0.0163387,0.0413921,-0.0879065,-0.0583087,-0.0600711,-0.0700024,0.0461264,0.0498507,0.0264983,-0.00692056,-0.0186082,0.0560909,1.5148e-05,-0  Inserted by jv255027
# 1      DensePassageRetrieval                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Dense Passage Retrieval for Open-Domain Question Answering  0.0067198,-0.0786079,0.0269106,-0.0148532,0.0834384,0.00276998,0.0536404,0.0251592,0.0376837,-0.0192677,-0.0277906,-0.0186446,-0.0622877,0.0477905,-0.0404043,0.0233351,0.093698,0.0188043,-0.055049,-0.0270339,0.0295242,0.100278,0.06644,0.0162685,0.00326895,-0.0644235,0.0510956,-0.0443832,0.045024,-0.03022,0.0517287,0.0627205,-0.0278688,0.0317071,0.00442458,0.0632781,-0.0329051,-0.016729,-0.055154,-0.0278626,-0.0141135,-0.013958,0.0787482,0.0187432,0.0814736,-0.04798,-0.0660003,-0.0516636,0.121255,-0.0417391,-0.0516737,0.044613,-0.0292071,0.0157639,-0.00226096,-0.0658454,-0.0143563,-0.0357949,0.016367,-0.0668471,-0.0588372,-0.100668,-0.0636789,0.0402407,0.031804,-0.0555359,-0.0303321,0.0149208,-0.0845852,0.0358271,-0.0710768,0.0913976,0.0495133,0.0347212,-0.00582817,0.0776187,-0.0198824,-0.0356862,-0.00882413,0.0107236,0.0283025,-0.09786,0.0572983,0.0091785,0.0480596,0.0360592,0.020798,0.0120861,-0.0571554,4.74262e-06,0.01503,-0.0503021,0.0735143,-0.0579026,0.014727,0.0408209,0.0263135,-0.0659117,0.0183123,0.08  Inserted by jv255027

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <b style = 'font-size:30px;font-family:Arial;color:#00233C'>6. Normalize the embeddings </b>

# %% [markdown]
# ### 🎚️ Apply the vector normalization function from Teradata
#
# - Create a table with data
# - Store the normalized vector embeddings in the table

# %%
#Normalize the embeddings
normalize_query = '''
CREATE TABLE manual_vector_table_normalized AS (
SELECT *
FROM TD_Vectornormalize(
    ON manual_vector_table AS InputTable
    USING
        IDColumns('TD_ID')
        TargetColumns('Embedding')
        Accumulate('TD_FILENAME', 'Message', 'CHUNKS')
        Approach('UNITVECTOR')
        EmbeddingSize(384)
) AS DT) WITH DATA;
'''

#Execute the query to normalize the embeddings
execute_sql(normalize_query)
# Out:
# TeradataCursor uRowsHandle=231 bClosed=False

# %% [markdown]
# ### 🔎 Inspect the normalized embedding table

# %%
#View the normalized data
view_normalized_query = '''
SELECT TOP 20 *
FROM manual_vector_table_normalized;
'''
#Execute the query to view the normalized data
#Test dataframe
test_df = DataFrame.from_query(view_normalized_query)
test_df.head(5)
# Out:
#    TD_ID                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Embedding            TD_FILENAME               Message                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       CHUNKS
# 0     34  0.0348455,-0.124239,0.0215344,-0.0170954,0.0659255,0.057714,0.00301108,-0.0235443,0.0829967,-0.0535196,0.0388099,0.020814,0.0428845,0.0325052,-0.0285829,0.0125573,0.0805029,-0.0534497,-0.139959,-0.0462808,0.0108242,-0.0370436,0.0490993,-0.039553,0.0584226,-0.080365,-0.0484919,0.0813079,0.0559889,-0.0115403,0.00769398,0.0936754,-0.0108652,0.0225935,-0.035328,0.0497562,-0.0129674,0.0287394,0.00797291,0.0448199,0.0374838,0.0680295,0.0236882,0.0368947,0.0294521,-0.0224948,-0.065843,-0.0209105,-0.0497344,0.00997089,-0.0488887,0.0282627,-0.102472,0.0333335,-0.0583444,-0.13559,-0.101318,-0.0437132,-0.00127013,-0.0134182,-0.0200624,-0.0572374,0.0410777,0.0404785,0.0858565,-0.0454853,0.0349289,0.023663,-0.0190417,0.148043,0.00753894,0.0768549,-0.111085,0.120857,0.0674602,0.0137763,-0.0416141,-0.0982934,0.047699,-0.0282964,-0.0141105,0.0219859,0.0381874,-0.0196458,0.0944242,0.00827028,0.0504103,-0.0574617,-0.0622965,0.0389833,-0.0146286,-0.0565871,0.0526571,0.0282068,0.000551305,-0.00312465,0.0440541,0.000297649,0.0189  DensePassageRetrieval  Inserted by jv255027                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   larity) than the irrelevant ones, by learning a better embedding function.
# 1     40  0.0392963,0.13212,0.0274631,-0.0245659,-0.0238336,0.0156914,0.0245382,0.0100369,0.0772125,-0.0289403,0.0465914,-0.0471739,0.0012117,0.0407367,-0.00194977,-0.0546379,0.00570696,-0.0335631,-0.0899332,-0.024143,0.024535,0.0118839,-0.0335782,-0.00387712,0.0109065,-0.0150192,-0.0152897,-0.0344896,0.0512558,-0.0627351,-0.0560777,-0.00568499,-0.0297681,0.052061,0.0623891,0.00806444,0.0226059,0.0666656,0.00310185,0.0177721,-0.0312477,-0.0129281,-0.0472661,-0.0454298,-0.00170082,-0.0467318,-0.053186,0.011961,0.0073059,-0.073532,-0.077273,0.0153865,-0.090704,0.0951235,-0.0256873,0.00721415,-0.0457518,0.0764712,-0.00717096,0.0255312,0.00774468,-0.0413808,-0.07889,0.0919822,0.0947727,0.0127683,-0.0114438,-0.0284403,-0.0587054,0.156092,-0.0986718,-0.0193096,0.0263887,-0.0307548,-0.0894993,0.0218981,-0.0448912,-0.0388983,-0.0175403,-0.0425035,0.0532369,0.0144881,0.0115082,0.0376394,0.0474525,-0.0417522,0.00478836,-0.00640012,-0.0574771,0.078017,-0.0129428,-0.0505481,0.0450141,-0.0035846,0.0501899,0.061574,-0.102381,0.01866  DensePassageRetrieval  Inserted by jv255027                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         negative passages for each question.
# 2     38  -0.0460351,0.0140147,-0.0185757,-0.00307021,-0.0794298,0.0905031,0.032684,-0.00939971,0.00934856,-0.0470565,0.0133853,-0.0258132,0.0855151,0.0310994,-0.0612779,0.0453158,0.117971,-0.009719,-0.0695882,-0.0449724,-0.0929973,-0.0385185,0.00746712,-0.0290759,0.007458,-0.0110122,0.0121873,-0.00882472,0.0500073,-0.0492659,0.0219481,0.0914851,0.0224823,0.020202,0.0348381,0.0193203,-0.0476951,0.0278877,-0.00379836,0.0120031,0.0554799,0.0287124,-0.0259465,0.0348426,0.0550437,-0.0180572,-0.058108,-0.0115644,-0.0515424,-0.0394588,-0.0754266,0.063523,-0.0164056,0.0785608,-0.0520625,0.0110074,0.0689651,0.0378724,-0.0982873,0.0520939,-0.0565343,-0.115342,-0.0196606,-0.0361038,0.0936292,-0.0272727,0.00615744,0.058272,0.0296196,0.110453,-0.020591,0.00114359,-0.0706715,0.0190952,-0.0874491,0.0858611,0.0228156,-0.0146684,-0.0280083,-0.0230484,0.0196568,-0.075155,0.0453326,-0.0258145,0.0876472,-0.0557191,0.035528,-0.00529972,0.0302262,0.0386268,-0.0585221,-0.053287,0.0230177,-0.0271918,0.0759039,-0.0186422,-0.0370203,0.0820826,  DensePassageRetrieval  Inserted by jv255027                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              In-batch negatives Assume that we have B questions in a mini-batch and each one is asso- ciated with a relevant passage. Let Q and P be the (Bd) matrix of question and passage embeddings in a batch of size B. S = QPT is a (B  B) ma- trix of similarity scores, where each row of which corresponds to a question, paired with B passages. In this way, we reuse computation and effectively train on B2 (qi, pj) question/passage pairs in each batch. Any (qi, pj) pair is a positive example when i = j, and negative otherwise. This creates B train- ing instances in each batch, where there are B  1
# 3     19  -0.09773,0.0618917,0.0104367,0.0140303,0.00256807,0.0463941,-0.00104509,0.0343519,0.0597571,0.0338469,-0.0198961,-0.0145354,0.0384058,0.0485654,0.0221381,0.0372051,0.0377382,0.0464204,-0.0524628,-0.024427,0.0360815,0.0449461,0.0353008,-0.0016002,0.000636547,0.0630853,-0.0375789,-0.06164,0.0550256,0.0243397,0.083819,0.0405572,0.041451,0.00624734,0.0470764,0.0681086,-0.0415704,0.0101741,0.0387364,-0.0287643,-0.041953,-0.0020722,0.000863871,0.0562454,0.0617961,-0.0148571,-0.0714098,0.0725537,-0.00980896,-0.026179,-0.0710329,0.0427882,-0.0289659,0.138177,-0.0113252,-0.0532541,-0.00382774,-0.0128564,-0.0468569,-0.0454614,-0.0829173,-0.096184,-0.0580174,-0.00588269,0.0329452,-0.048911,0.0149468,0.038005,-0.0569714,0.0179136,-0.0870173,0.0500871,-0.0340193,0.123988,-0.0145206,0.0492534,-0.0184391,0.00795989,0.0178081,0.0108323,0.0562981,0.000213146,0.0657175,0.0469906,0.0226704,0.0302084,0.00465514,0.000634208,0.0189615,0.0372109,-0.0275537,-0.0973223,0.0788867,-0.0302855,0.0538484,-0.0419479,0.0471342,0.000630239,0  DensePassageRetrieval  Inserted by jv255027  the extractive QA setting, in which the answer is restricted to a span appearing in one or more pas- sages in the corpus. Assume that our collection contains D documents, d,ds, - - ,dp. We first split each of the documents into text passages of equal lengths as the basic retrieval units and get M total passages in our corpus C = {p, pa, where each passage p; can be viewed as a sequence of tokens w (@) (@) . () 1, s W i . Given a question , (@) () (i) the task is to find a span w s Wes We from one of the passages p; that can answer the question. Notice that to cover a wide variety of domains, the corpus size can easily range from millions of docu- ments (e.g., Wikipedia) to billions (e.g., the Web). As a result, any open-domain QA system needs to include an efficient retriever component that can se- lect a small set of relevant texts, before applying the reader to extract the answer (Chen et al., 2017). Formally speaking, a retriever R : (,C)  Cr is a function that takes as input a question  and a corpus C and returns a much smaller filter set of texts Cx C C, where [Cx| = k < |C|. For a fixed k, a retriever can be evaluated in isolation on top-k retrieval accuracy, which is the fraction of ques- tions for which C contains a span that answers the question.
# 4     17  -0.023456,0.0324408,-0.0546858,-0.013958,0.0890375,-0.0386119,0.0267054,0.0185928,0.0132347,-0.0380252,-0.00392112,-0.0158348,0.00237103,-0.0307863,0.0409842,0.0449263,-0.0343729,0.023202,-0.0933566,0.0151527,-0.0935769,-0.0886394,0.0542959,-0.0612367,-0.0586399,0.0835357,0.0163662,0.0391307,0.0564726,-0.0575576,0.00185713,-0.00211729,0.0390203,0.0427559,-0.0956983,-0.100878,-0.0144006,0.0881996,-0.0464727,-0.0152004,0.0162089,-0.0569354,-0.00374234,-0.00193846,-0.0236623,0.0298671,0.0443642,0.0428584,0.0861181,-0.0264321,0.0245565,-0.112435,-0.000850091,0.0245675,0.0093383,0.0824908,-0.021207,0.0812704,0.0392057,0.0137496,0.0770084,0.0848215,-0.04863,-0.00374837,0.129789,-0.0240414,-0.0561409,-0.0277476,-0.0360198,-0.0726511,0.0723781,0.0202921,0.0171364,-0.0940283,0.0468616,-0.0549288,0.00480605,-0.0337843,-0.0324003,-0.129681,0.0241056,-0.115629,-0.0165307,0.0230637,-0.0216574,0.0258587,-0.00918691,-0.0207566,-0.102219,-0.0327227,0.00632106,0.0461208,0.0500548,-0.00119587,-0.0240946,0.0383429,-0.0149701,-0  DensePassageRetrieval  Inserted by jv255027                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 2 Background

# %% [markdown]
# ### 🗑️ Drop tables
#
# Drop all tables so that the next user can run the notebook from scratch

# %%
#Execute the query to drop the table
execute_sql('''DROP TABLE manual_vector_table;''')
execute_sql('''DROP TABLE manual_vector_table_normalized;''')
# Out:
# TeradataCursor uRowsHandle=249 bClosed=False

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <b style = 'font-size:30px;font-family:Arial;color:#00233C'>Extra: Generate table for Getting Started SQL Notebook </b>

# %% [markdown]
# In case you want to use the capabilities of the Getting Started SQL Notebook with your own PDFs and the Unstructured partitioning function, you can follow this steps:
#
# 1. **Generate new JSON file**
#     - First generate the JSON file using the code provided above in the section `"Unstructured.io Partitioning into JSON"`.
# 2. **Create the table `pdf_elements`**
#     - Once you have your JSON file, you can create the table here that only has the columns `id` and `text`
# 3. **Insert text elements into the table**
#     - Finally, just insert only the text chunks from your processed JSON into the table.
#
# This will save the new table into your database, for you to use functions like `AI_TextEmbeddings` that are shown in the Getting Started SQL Notebook

# %%
#Create a table to store the PDF elements
execute_sql("""
CREATE MULTISET TABLE pdf_elements (
    id INTEGER GENERATED ALWAYS AS IDENTITY NOT NULL,
    text VARCHAR(10000),
    PRIMARY KEY (id)
);
""")
# Out:
# TeradataCursor uRowsHandle=252 bClosed=False

# %%
# Open the JSON file and insert each 'text' element into 'manual_vectorstore' table
with open('UnstructuredJSON.json', 'r', encoding='utf-8') as f:
    elements = json.load(f)

for element in elements:
    text = element.get('text', '')
    if text:
        cleaned_text = clean_data(str(text)).replace("'", "''")
        insert_query = f"""
        INSERT INTO pdf_elements (text)
        VALUES ('{cleaned_text}');
        """
        execute_sql(insert_query)

        print(f"Inserted element: {cleaned_text[:50]}...")
# Out:
# Inserted element: Dense Passage Retrieval for Open-Domain Question A...
# Inserted element: Vladimir Karpukhin, Barlas Oguz, Sewon Min, Patric...
# Inserted element: Facebook AI University of Washington Princeton Uni...
# Inserted element: 0 2 0 2 p e S 0 3 ] L C . s c [ 3 v 6 0 9 4 0 . 4 ...
# Inserted element: Abstract...
# Inserted element: Open-domain question answering relies on ef- cient...
# Inserted element: 1 Introduction...
# Inserted element: Open-domain question answering (QA) (Voorhees, 199...
# Inserted element: Equal contribution...
# Inserted element: 1The code and trained models have been released at...
# Inserted element: 2For instance, the exact match score on SQuAD v1.1...
# Inserted element: Retrieval in open-domain QA is usually imple- ment...
# Inserted element: However, it is generally believed that learn- ing ...
# Inserted element: QA datasets, it also suffers from two weaknesses. ...
# Inserted element: In this paper, we address the question: can we tra...
# Inserted element: Our contributions are twofold. First, we demon- st...
# Inserted element: 2 Background...
# Inserted element: The problem of open-domain QA studied in this pape...
# Inserted element: the extractive QA setting, in which the answer is ...
# Inserted element: 3 Dense Passage Retriever (DPR)...
# Inserted element: We focus our research in this work on improv- ing ...
# Inserted element: 3.1 Overview...
# Inserted element: Our dense passage retriever (DPR) uses a dense enc...
# Inserted element: 3The ideal size and boundary of a text passage are...
# Inserted element: 4Exceptions include (Seo et al., 2019) and (Robert...
# Inserted element: At run-time, DPR applies a different encoder EQ() ...
# Inserted element: sim(q, p) Eq(q)Ep(p)...
# Inserted element: Although more expressive model forms for measur- i...
# Inserted element: Encoders Although in principle the question and pa...
# Inserted element: Inference During inference time, we apply the pass...
# Inserted element: 3.2 Training...
# Inserted element: Training the encoders so that the dot-product sim-...
# Inserted element: (1)...
# Inserted element: larity) than the irrelevant ones, by learning a be...
# Inserted element:  Let D = p Pi 1 be the training data that consists...
# Inserted element: L(gi,pi Pi) e sim(q; lo, esim(qip im(i; ;) + Y...
# Inserted element: Positive and negative passages For retrieval probl...
# Inserted element: In-batch negatives Assume that we have B questions...
# Inserted element: (2)...
# Inserted element: negative passages for each question....
# Inserted element: The trick of in-batch negatives has been used in t...
# Inserted element: 4 Experimental Setup...
# Inserted element: In this section, we describe the data we used for ...
# Inserted element: 4.1 Wikipedia Data Pre-processing...
# Inserted element: Following (Lee et al., 2019), we use the English W...
# Inserted element: 4.2 Question Answering Datasets...
# Inserted element: We use the same ve QA datasets and train- ing/dev/...
# Inserted element: Natural Questions (NQ) (Kwiatkowski et al., 2019) ...
# Inserted element: TriviaQA (Joshi et al., 2017) contains a set of tr...
# Inserted element: WebQuestions (WQ) (Berant et al., 2013) consists o...
# Inserted element: CuratedTREC (TREC) (Baudis and Sediv`y, 2015) sour...
# Inserted element: 5However, Wang et al. (2019) also propose splittin...
# Inserted element: Dataset Train Dev Test Natural Questions 79,168 58...
# Inserted element: Table 1: Number of questions in each QA dataset. T...
# Inserted element: as well as various Web sources and is intended for...
# Inserted element: Selection of positive passages Because only pairs ...
# Inserted element: 5 Experiments: Passage Retrieval...
# Inserted element: In this section, we evaluate the retrieval perfor-...
# Inserted element: 6We use the unltered TriviaQA version and discard ...
# Inserted element: 7The improvement of using gold contexts over passa...
# Inserted element: Training Retriever Top-20 Top-100 NQ TriviaQA WQ T...
# Inserted element: Table 2: Top-20 & Top-100 retrieval accuracy on te...
# Inserted element: traditional retrieval methods, the effects of diff...
# Inserted element: The DPR model used in our main experiments is trai...
# Inserted element: While it is good to have the exibility to adapt th...
# Inserted element: 5.1 Main Results...
# Inserted element: Table 2 compares different passage retrieval sys- ...
# Inserted element: 8SQuAD is limited to a small set of Wikipedia docu...
# Inserted element: 9Lucene implementation. BM25 parameters b = 0.4 (d...
# Inserted element: 90 3 3 3 BM25 # Train: 1k # Train: 10k Top-k accur...
# Inserted element: Figure 1: Retriever top-k accuracy with different ...
# Inserted element: tiple datasets, TREC, the smallest dataset of the ...
# Inserted element: We conjecture that the lower performance on SQuAD ...
# Inserted element: 5.2 Ablation Study on Model Training...
# Inserted element: To understand further how different model training...
# Inserted element: Sample efciency We explore how many train- ing exa...
# Inserted element: In-batch negative training We test different train...
# Inserted element: The middle bock is the in-batch negative training ...
# Inserted element: Finally, we explore in-batch negative training wit...
# Inserted element: Impact of gold passages We use passages that match...
# Inserted element: Type #N 1B Top-5 Top-20 Top-100 Random X 47.0 64.3...
# Inserted element: Table 3: Comparison of different training schemes,...
# Inserted element: Our experiments on Natural Questions show that swi...
# Inserted element: Similarity and loss Besides dot product, cosine an...
# Inserted element: Cross-dataset generalization One interesting quest...
# Inserted element: 5.3 Qualitative Analysis...
# Inserted element: Although DPR performs better than BM25 in gen- era...
# Inserted element: 5.4 Run-time Efciency...
# Inserted element: The main reason that we require a retrieval compo-...
# Inserted element: On the other hand, the time required for building ...
# Inserted element: 6 Experiments: Question Answering...
# Inserted element: In this section, we experiment with how different ...
# Inserted element: 6.1 End-to-end QA System...
# Inserted element: We implement an end-to-end question answering syst...
# Inserted element: 10FAISS conguration: we used HNSW index type on CP...
# Inserted element: score is chosen as the nal answer. The passage sel...
# Inserted element: Specically, let Pi  RLh (1  i  k) be a BERT (base,...
# Inserted element: softmax nd softmax (P;Wena) o Prelected softmax (P...
# Inserted element: where P = [P[CLS] ,...,P[CLS] ]  Rhk and 1 k wstar...
# Inserted element: During training, we sample one positive and m1 neg...
# Inserted element: 6.2 Results...
# Inserted element: Table 4 summarizes our nal end-to-end QA re- sults...
# Inserted element: (3)...
# Inserted element: (4)...
# Inserted element: (5)...
# Inserted element: Training Model NQ TriviaQA WQ TREC SQuAD Single BM...
# Inserted element: Table 4: End-to-end QA (Exact Match) Accuracy. The...
# Inserted element: see that higher retriever accuracy typically leads...
# Inserted element: To compare our pipeline training approach with joi...
# Inserted element: trained, following Lee et al. (2019). This approac...
# Inserted element: One thing worth noticing is that our reader does c...
# Inserted element: 7 Related Work...
# Inserted element: Passage retrieval has been an important compo- nen...
# Inserted element: been used as the standard method applied broadly t...
# Inserted element: The use of dense vector representations for re- tr...
# Inserted element: Dense retrieval for open-domain QA has been explor...
# Inserted element: effective solution that shows stronger empirical p...
# Inserted element: DPR has also been used as an important mod- ule in...
# Inserted element: 8 Conclusion...
# Inserted element: In this work, we demonstrated that dense retrieval...
# Inserted element: Acknowledgments...
# Inserted element: We thank the anonymous reviewers for their helpful...
# Inserted element: References...
# Inserted element: Akari Asai, Kazuma Hashimoto, Hannaneh Hajishirzi,...
# Inserted element: Petr Baudis and Jan Sediv`y. 2015. Modeling of the...
# Inserted element: Jonathan Berant, Andrew Chou, Roy Frostig, and Per...
# Inserted element: question-answer pairs. In Empirical Methods in Nat...
# Inserted element: Jane Bromley, Isabelle Guyon, Yann LeCun, Eduard S...
# Inserted element: Chris Burges, Tal Shaked, Erin Renshaw, Ari Lazier...
# Inserted element: Danqi Chen, Adam Fisch, Jason Weston, and Antoine ...
# Inserted element: Rajarshi Das, Shehzaad Dhuliawala, Manzil Zaheer, ...
# Inserted element: Scott Deerwester, Susan T Dumais, George W Fur- na...
# Inserted element: Jacob Devlin, Ming-Wei Chang, Kenton Lee, and Kris...
# Inserted element: David A Ferrucci. 2012. Introduction to This is Wa...
# Inserted element: Daniel Gillick, Sayali Kulkarni, Larry Lansing, Al...
# Inserted element: Ruiqi Guo, Sanjiv Kumar, Krzysztof Choromanski, an...
# Inserted element: Kelvin Guu, Kenton Lee, Zora Tung, Panupong Pa- su...
# Inserted element: Matthew Henderson, Rami Al-Rfou, Brian Strope, Yun...
# Inserted element: Po-Sen Huang, Xiaodong He, Jianfeng Gao, Li Deng, ...
# Inserted element: clickthrough data. In ACM International Confer- en...
# Inserted element: Samuel Humeau, Kurt Shuster, Marie-Anne Lachaux, a...
# Inserted element: Gautier Izacard and Edouard Grave. 2020. Leveragin...
# Inserted element: Jeff Johnson, Matthijs Douze, and Herve Jegou. 201...
# Inserted element: Mandar Joshi, Eunsol Choi, Daniel Weld, and Luke Z...
# Inserted element: Omar Khattab and Matei Zaharia. 2020. ColBERT: Efc...
# Inserted element: Brian Kulis. 2013. Metric learning: A survey. Foun...
# Inserted element: Tom Kwiatkowski, Jennimaria Palomaki, Olivia Red- ...
# Inserted element: Kenton Lee, Ming-Wei Chang, and Kristina Toutanova...
# Inserted element: Mike Lewis, Yinhan Liu, Naman Goyal, Mar- jan Ghaz...
# Inserted element: Patrick Lewis, Ethan Perez, Aleksandara Piktus, Fa...
# Inserted element: Yankai Lin, Haozhe Ji, Zhiyuan Liu, and Maosong Su...
# Inserted element: Sewon Min, Danqi Chen, Hannaneh Hajishirzi, and Lu...
# Inserted element: Sewon Min, Danqi Chen, Luke Zettlemoyer, and Han- ...
# Inserted element: Dan Moldovan, Marius Pasca, Sanda Harabagiu, and M...
# Inserted element: Stephen Mussmann and Stefano Ermon. 2016. Learn- i...
# Inserted element: Yixin Nie, Songhe Wang, and Mohit Bansal. 2019. Re...
# Inserted element: Rodrigo Nogueira and Kyunghyun Cho. 2019. Passage ...
# Inserted element: Colin Raffel, Noam Shazeer, Adam Roberts, Katherin...
# Inserted element: Pranav Rajpurkar, Jian Zhang, Konstantin Lopyrev, ...
# Inserted element: Parikshit Ram and Alexander G Gray. 2012. Maximum ...
# Inserted element: Adam Roberts, Colin Raffel, and Noam Shazeer. 2020...
# Inserted element: Stephen Robertson and Hugo Zaragoza. 2009. The pro...
# Inserted element: Minjoon Seo, Jinhyuk Lee, Tom Kwiatkowski, Ankur P...
# Inserted element: Anshumali Shrivastava and Ping Li. 2014. Asymmet- ...
# Inserted element: Ellen M Voorhees. 1999. The TREC-8 question an- sw...
# Inserted element: Shuohang Wang, Mo Yu, Xiaoxiao Guo, Zhiguo Wang, T...
# Inserted element: Zhiguo Wang, Patrick Ng, Xiaofei Ma, Ramesh Nalla-...
# Inserted element: Tomer Wolfson, Mor Geva, Ankit Gupta, Matt Gard- n...
# Inserted element: Lee Xiong, Chenyan Xiong, Ye Li, Kwok-Fung Tang, J...
# Inserted element: Wenhan Xiong, Hankang Wang, and William Yang Wang....
# Inserted element: Wei Yang, Yuqing Xie, Aileen Lin, Xingyu Li, Luche...
# Inserted element: Wei Yang, Yuqing Xie, Luchen Tan, Kun Xiong, Ming ...
# Inserted element: Wen-tau Yih, Kristina Toutanova, John C Platt, and...
# Inserted element: A Distant Supervision...
# Inserted element: When training our nal DPR model using Natural Ques...
# Inserted element: B Alternative Similarity Functions & Triplet Loss...
# Inserted element: In addition to dot product (DP) and negative log- ...
# Inserted element: Note that the retrieval accuracy for our baseline ...
# Inserted element: C Qualitative Analysis...
# Inserted element: Although DPR performs better than BM25 in gen- era...
# Inserted element: Top-1 Top-5 Top-20 Top-100 Gold 44.9 66.8 78.1 85....
# Inserted element: Table 5: Retrieval accuracy on the development set...
# Inserted element: Sim Loss Retrieval Accuracy Top-1 Top-5 Top-20 Top...
# Inserted element: Table 6: Retrieval Top-k accuracy on the developme...
# Inserted element: the correct answer, presumably by matching body of...
# Inserted element: D Joint Training of Retriever and Reader...
# Inserted element: We x the passage encoder in our joint-training sch...
# Inserted element: Question Passage received by BM25 Passage retrieve...
# Inserted element: Table 7: Examples of passages returned from BM25 a...
# Inserted element: from the top 5 positive and top 30 negative passag...
# Inserted element: (from the set of top 100 passages retrieved from t...

# %% [markdown]
# ### 🗑️ Drop Table

# %%
#Execute the query to drop the table
execute_sql('''DROP TABLE pdf_elements;''')
# Out:
# TeradataCursor uRowsHandle=251 bClosed=False
