# %% [markdown]
# <header>
#    <p  style='font-size:36px;font-family:Arial; color:#F0F0F0; background-color: #00233c; padding-left: 20pt; padding-top: 20pt;padding-bottom: 10pt; padding-right: 20pt;'>
#        Vector Store - Getting Started
#   <br>
#        <img id="teradata-logo" src="https://storage.googleapis.com/clearscape_analytics_demo_data/DEMO_Logo/teradata.svg" alt="Teradata" style="width: 125px; height: auto; margin-top: 20pt;">
#     </p>
# </header>

# %% [markdown]
# <p style="font-size:24px;font-family:Arial;color:#00233C"><b>Introduction</b></p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# Vector stores are specialized databases designed for efficient storage, indexing, and searching of high-dimensional vector embeddings. These embeddings, generated by AI models, enable similarity search and power applications in machine learning, NLP, recommendation systems, and image/video retrieval.
# </p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# This notebook provides an in-depth exploration of vector stores in the Teradata Database, covering key concepts, vector embedding mechanisms, and efficient search techniques.
# </p>
#
# ---
#
# <p style="font-size:24px;font-family:Arial;color:#00233C"><b>Key Concepts</b></p>
#
# <p style="font-size:18px;font-family:Arial;color:#00233C"><b>What is a Vector Store?</b></p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# A vector store contains a vectorized representation of data, typically created using embeddings from AI models. It allows for high-speed similarity searches beyond traditional keyword matching.
# </p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# Vector embeddings are numerical representations of data (text, images, audio, etc.) mapped into a multi-dimensional space.
# </p>
#
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# Each embedding is a vector that captures semantic or content-based relationships. For example:
# </p>
#
# <table style="font-size:16px;font-family:Arial;color:#00233C;border:1px solid black;">
#   <tr>
#     <th style="border:1px solid black;padding:5px;">Data Type</th>
#     <th style="border:1px solid black;padding:5px;">Example</th>
#     <th style="border:1px solid black;padding:5px;">Vector Representation</th>
#   </tr>
#   <tr>
#     <td style="border:1px solid black;padding:5px;">Text</td>
#     <td style="border:1px solid black;padding:5px;">"King"</td>
#     <td style="border:1px solid black;padding:5px;">[0.12, 0.45, 0.67, ...]</td>
#   </tr>
#   <tr>
#     <td style="border:1px solid black;padding:5px;">Image</td>
#     <td style="border:1px solid black;padding:5px;">A picture of a cat</td>
#     <td style="border:1px solid black;padding:5px;">[0.23, 0.78, 0.55, ...]</td>
#   </tr>
# </table>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# <b>Embedding Generation is carried out by AI_TextEmbedding Function </b>
# <ul style="font-size:16px;font-family:Arial;color:#00233C">
#   <li>Enables text embedding generation using LLMs hosted by AzureOpenAI, AWS Bedrock.</b> (Performs a full-table scan)</li>
#     <li> Accepts different parameters, model endpoint, key, model args etc.</li>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# <b>Supported models</b>
# <ul style="font-size:15px;font-family:Arial;color:#00233C">
# <li>Azure OpenAI</li>
# <ul style="font-size:14px;font-family:Arial;color:#00233C">
# <li>text-embedding-ada-002</li>
#
# <li>text-embedding-3-small</li>
#
# <li>text-embedding-3-large</li>
# </ul>
#
# <li>Amazon Bedrock</li>
# <ul style="font-size:15px;font-family:Arial;color:#00233C">
# <li>amazon.titan-embed-text-v1</li>
#
# <li>amazon.titan-embed-image-v1</li>
#
# <li>amazon.titan-embed-text-v2:0 (supported only on systems running curl v8.9.0)</li>
# </ul>
# </ul>
# </p>
#
# ---
#
# <p style="font-size:18px;font-family:Arial;color:#00233C"><b>Vector Search</b></p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# Unlike traditional search methods, vector search understands the meaning behind a query. It provides relevant results by analyzing semantic relationships rather than exact keyword matches.
# </p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# Common types of embeddings include:
# </p>
#
# <ul style="font-size:16px;font-family:Arial;color:#00233C">
# <li>Word Embeddings</li>
# <li>Sentence Embeddings</li>
# <li>Document Embeddings</li>
# <li>Image Embeddings</li>
# <li>Audio Embeddings</li>
# </ul>
#
# ---
#
# <p style="font-size:24px;font-family:Arial;color:#00233C"><b>Vector Store in the Teradata Database</b></p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# A vector in Teradata is a specialized column type called <b>Vector</b>.
# </p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# The <b>vector store</b> in Teradata consists of schemas and tables that enable vector search functionality.
# </p>
#
# <hr>
#
# <p style="font-size:20px;font-family:Arial;color:#00233C"><b>Vector Search Algorithms</b></p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# Teradata supports three main search algorithms:
# </p>
#
# <p style="font-size:18px;font-family:Arial;color:#00233C"><b>1. VectorDistance</b></p>
# <ul style="font-size:16px;font-family:Arial;color:#00233C">
#   <li><b>Flat index</b> (performs a full-table scan)</li>
#   <li><b>Scalable and parallel search</b></li>
#   <li><b>Exact search approach</b></li>
#   <li>Suitable for <b>smaller datasets (<10K documents)</b></li>
# </ul>
#
# <p style="font-size:18px;font-family:Arial;color:#00233C"><b>2. Kmeans</b></p>
# <ul style="font-size:16px;font-family:Arial;color:#00233C">
#   <li><b>IVF (Inverted Vector File) index</b> (organizes data into clusters)</li>
#   <li><b>Scalable and parallel training/search</b></li>
#   <li><b>Approximate search approach</b></li>
#   <li>Suitable for <b>larger datasets (>10K documents)</b></li>
# </ul>
#
# <p style="font-size:18px;font-family:Arial;color:#00233C"><b>3. HNSW</b></p>
# <ul style="font-size:16px;font-family:Arial;color:#00233C">
#   <li><b>HNSW (Hierarchical Navigable Small World) index</b></li>
#   <li><b>Graph-based Approximate Nearest Neighbors (ANN) search</b></li>
#   <li><b>Scalable and parallel training/search</b></li>
#   <li><b>Approximate search approach</b></li>
#   <li>Suitable for <b>larger datasets (>10K documents)</b></li>
# </ul>
#
# <hr>
#
#
# <p style="font-size:20px;font-family:Arial;color:#00233C"><b>Types of Vector Store</b></p>
#
# <table style="font-size:15px; font-family:Arial; color:#00233C; width:100%; border:1px solid #ddd; border-collapse:collapse;">
#   <tr>
#     <th style="padding:10px; text-align:left; border:1px solid #ddd;">Type</th>
#     <th style="padding:10px; text-align:left; border:1px solid #ddd;">Description</th>
#     <th style="padding:10px; text-align:left; border:1px solid #ddd;">Use Case</th>
#   </tr>
#   <tr>
#     <td style="padding:10px; border:1px solid #ddd;"><b>1. Content-Based</b></td>
#     <td style="padding:10px; border:1px solid #ddd;">Built on the <b>contents of a table</b> (or file/PDF converted to a table). Queries return the <b>top relevant rows</b> based on similarity.</td>
#     <td style="padding:10px; border:1px solid #ddd;">Can be combined with <b>LLM-generated textual responses</b> for more accurate answers.</td>
#   </tr>
#   <tr>
#     <td style="padding:10px; border:1px solid #ddd;"><b>2. Metadata-Based</b></td>
#     <td style="padding:10px; border:1px solid #ddd;">Built on the <b>metadata</b> of tables. Queries return the <b>top matching tables</b> based on similarity. Used in <b>SQL generation</b> for data retrieval.</td>
#     <td style="padding:10px; border:1px solid #ddd;">Helps form textual responses by retrieving data from relevant tables for more precise answers.</td>
#   </tr>
# </table>
#
#
# </ul>

# %% [markdown]
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>What You Will Do in This Notebook</b></p>
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
# This notebook is designed to guide you through a comprehensive set of exercises focused on working with vector store management, ask and pattern managemnet API. By the end of this tutorial, you will have gained hands-on experience with creating and managing vector store objects and patterns as well as asking questions and performing similarity searches. Here's what you'll learn:
# </p>
#
# <div style = 'font-size:16px;font-family:Arial;color:#00233C'>
# <ol>
# <li>
# <b>Understanding Vector Store management</b>
# </li>
# <li>
# <b>Creating a new Vector Store</b>
# </li>
# <li>
# <b>Using existing Vector Store</b>
# </li>
# <li>
# <b>Access Management in Vector Store</b>
# </li>
# <li>
# <b>Building a Vector Store from PDF Documents</b>
# </li>
# <li>
# <b>Pattern Management for Vector Store</b>
# </li>
# <li>
# <b>Working with metadata-based Vector Store</b>
#
#
# </ol>
# </div>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <b style = 'font-size:20px;font-family:Arial;color:#00233C'>Import necessary modules</b>

# %%
#Install the required packages
# %pip install teradataml-20.0.0.5-py3-none-any.whl
# Out:
# Processing c:\users\jv255027\downloads\vector store\vectorstore-aprildrop\teradataml-20.0.0.5-py3-none-any.whl
# Requirement already satisfied: teradatasql>=20.0.0.19 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml==20.0.0.5) (20.0.0.29)
# Requirement already satisfied: teradatasqlalchemy>=20.0.0.4 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml==20.0.0.5) (20.0.0.4)
# Requirement already satisfied: pandas>=0.22 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml==20.0.0.5) (2.2.3)
# Requirement already satisfied: psutil in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from teradataml==20.0.0.5) (6.0.0)
# Requirement already satisfied: requests>=2.25.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml==20.0.0.5) (2.32.3)
# Requirement already satisfied: scikit-learn>=0.24.2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml==20.0.0.5) (1.6.1)
# Requirement already satisfied: IPython>=8.10.0 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from teradataml==20.0.0.5) (8.26.0)
# Requirement already satisfied: imbalanced-learn>=0.8.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml==20.0.0.5) (0.13.0)
# Requirement already satisfied: pyjwt>=2.8.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml==20.0.0.5) (2.10.1)
# Requirement already satisfied: cryptography>=42.0.5 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml==20.0.0.5) (44.0.2)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml==20.0.0.5) (2.0.40)
# Requirement already satisfied: lightgbm>=3.3.3 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml==20.0.0.5) (4.6.0)
# Requirement already satisfied: python-dotenv in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml==20.0.0.5) (1.1.0)
# Requirement already satisfied: teradatamlwidgets>=20.0.0.5 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml==20.0.0.5) (20.0.0.5)
# Requirement already satisfied: cffi>=1.12 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from cryptography>=42.0.5->teradataml==20.0.0.5) (1.17.1)
# Requirement already satisfied: numpy<3,>=1.24.3 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from imbalanced-learn>=0.8.0->teradataml==20.0.0.5) (1.26.4)
# Requirement already satisfied: scipy<2,>=1.10.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from imbalanced-learn>=0.8.0->teradataml==20.0.0.5) (1.15.2)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from imbalanced-learn>=0.8.0->teradataml==20.0.0.5) (0.1.3)
# Requirement already satisfied: joblib<2,>=1.1.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from imbalanced-learn>=0.8.0->teradataml==20.0.0.5) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from imbalanced-learn>=0.8.0->teradataml==20.0.0.5) (3.6.0)
# Requirement already satisfied: decorator in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from IPython>=8.10.0->teradataml==20.0.0.5) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from IPython>=8.10.0->teradataml==20.0.0.5) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from IPython>=8.10.0->teradataml==20.0.0.5) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from IPython>=8.10.0->teradataml==20.0.0.5) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from IPython>=8.10.0->teradataml==20.0.0.5) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from IPython>=8.10.0->teradataml==20.0.0.5) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from IPython>=8.10.0->teradataml==20.0.0.5) (5.14.3)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from IPython>=8.10.0->teradataml==20.0.0.5) (4.12.2)
# Requirement already satisfied: colorama in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from IPython>=8.10.0->teradataml==20.0.0.5) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from pandas>=0.22->teradataml==20.0.0.5) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from pandas>=0.22->teradataml==20.0.0.5) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from pandas>=0.22->teradataml==20.0.0.5) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from requests>=2.25.1->teradataml==20.0.0.5) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from requests>=2.25.1->teradataml==20.0.0.5) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from requests>=2.25.1->teradataml==20.0.0.5) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from requests>=2.25.1->teradataml==20.0.0.5) (2025.1.31)
# Requirement already satisfied: greenlet>=1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from sqlalchemy>=2.0->teradataml==20.0.0.5) (3.2.1)
# Requirement already satisfied: ipywidgets>=8.1.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (8.1.6)
# Requirement already satisfied: nbconvert in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (7.16.6)
# Requirement already satisfied: nbformat in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (5.10.4)
# Requirement already satisfied: pycryptodome in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradatasql>=20.0.0.19->teradataml==20.0.0.5) (3.22.0)
# Requirement already satisfied: pycparser in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from cffi>=1.12->cryptography>=42.0.5->teradataml==20.0.0.5) (2.22)
# Requirement already satisfied: comm>=0.1.3 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from ipywidgets>=8.1.1->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from ipywidgets>=8.1.1->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.14 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from ipywidgets>=8.1.1->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (3.0.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from jedi>=0.16->IPython>=8.10.0->teradataml==20.0.0.5) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython>=8.10.0->teradataml==20.0.0.5) (0.2.13)
# Requirement already satisfied: six>=1.5 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas>=0.22->teradataml==20.0.0.5) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (3.1.6)
# Requirement already satisfied: jupyter-core>=4.7 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (5.7.2)
# Requirement already satisfied: jupyterlab-pygments in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (0.10.2)
# Requirement already satisfied: packaging in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (24.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nbformat->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nbformat->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (4.23.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from stack-data->IPython>=8.10.0->teradataml==20.0.0.5) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from stack-data->IPython>=8.10.0->teradataml==20.0.0.5) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from stack-data->IPython>=8.10.0->teradataml==20.0.0.5) (0.2.3)
# Requirement already satisfied: webencodings in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from jsonschema>=2.6->nbformat->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from jsonschema>=2.6->nbformat->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from jsonschema>=2.6->nbformat->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from jsonschema>=2.6->nbformat->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (0.24.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from jupyter-core>=4.7->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (4.2.2)
# Requirement already satisfied: pywin32>=300 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from jupyter-core>=4.7->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (306)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from nbclient>=0.5.0->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (8.6.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from beautifulsoup4->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (2.7)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (26.1.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (6.4.1)
# Installing collected packages: teradataml
#   Attempting uninstall: teradataml
#     Found existing installation: teradataml 20.0.0.4
#     Uninstalling teradataml-20.0.0.4:
#       Successfully uninstalled teradataml-20.0.0.4
# Successfully installed teradataml-20.0.0.5
# Note: you may need to restart the kernel to use updated packages.

# %%
from getpass import getpass
# Required imports
from teradatagenai import VSManager, VectorStore, VSPattern, VSApi
from teradataml import create_context, set_auth_token, display, DataFrame, in_schema
display.max_rows = 100000

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <b style = 'font-size:20px;font-family:Arial;color:#00233C'>Connect to Vantage</b>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>You will be prompted to provide the password. Enter your password, press the Enter key, then use down arrow to go to next cell. Begin running steps with Shift + Enter keys.</p>

# %%
# Connect to Vantage using create_context.
hostname = getpass(prompt = 'hostname: ')
username = getpass(prompt = 'username: ')
password = getpass(prompt = 'password: ')

context=create_context(host=hostname, username=username, password=password)

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <b style = 'font-size:20px;font-family:Arial;color:#00233C'>Authenticate to CCP</b>

# %%
base_url = 'https://vectorstoreaws.staging.innovationlabs.teradata.com/api/accounts/45bc9b91-8bbf-4646-ba9c-cda9b9c8a77d'
#https://vectorstoreaws.staging.innovationlabs.teradata.com/api/accounts/45bc9b91-8bbf-4646-ba9c-cda9b9c8a77d/open-analytics
pat = getpass("Enter pat token: ")
set_auth_token(base_url=base_url, pat_token=pat, pem_file='VectorStorePEM.pem')
# Out:
# Authentication token is generated, authenticated and set for the session.
# True

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <b style = 'font-size:30px;font-family:Arial;color:#00233C'>1. Understanding Vector Store management </b>

# %% [markdown]
# ### 🔧 VSManager handles Vector Store Management
# ###     Below are the methods

# %% [markdown]
# ##### 🏥 **health()** - Service Health Check
#    - **What It Does:** Ensures that the Vector Store service is up and running smoothly. It’s like a quick check-up to make sure everything is operational.
#    - **What You Get:** A clean report in the form of a DataFrame, indicating the health status of the service.

# %%
VSManager.health()
# Out:
# Database connection established in 379.88 milliseconds.
#   status platform  version  sessions_count
# 0     up      aws  1.0.319              19

# %% [markdown]
# #### 📋 **list()** - List All Vector Stores
#    - **What It Does:** Retrieves a list of all vector stores available in your environment. It’s like checking your inventory of vector stores.
#    - **What You Get:** A DataFrame with the details of each vector store.

# %%
VSManager.list()
# Out:
#                      vs_name      store_type                                                   description database_name                         vs_status permission
# 0             vs_pdf_emily_1   content-based                                                          None      XZ186023                             READY  NO ACCESS
# 1               ms_marco_mrr   content-based     Collection of datasets focused on deep learning in search           oaf                             READY  NO ACCESS
# 2      cricket_test_example1  metadata-based                                                          None      KS250118                             READY  NO ACCESS
# 3               vs_rodrigo_1   content-based                                                          None      RC255079                             READY  NO ACCESS
# 4             amazon_reviews   content-based  Amazon reviews about the book "The Prophet" by Kahlil Gibran           oaf                             READY  NO ACCESS
# 5     retail_comments_kms_1k   content-based                                                          None      KS250119                             READY  NO ACCESS
# 6                  vs_pdf_fa   content-based                                                          None      FA186006                             READY  NO ACCESS
# 7               vs_pdf1_rc_1   content-based                                                          None      RC255079                             READY  NO ACCESS
# 8    TravelInsurance_chatbot   content-based                                                          None      CH255039                             READY  NO ACCESS
# 9                 tm122469_1   content-based                                                          None      TM122469                             READY  NO ACCESS
# 10              kms__sql_pdf   content-based                                                          None      KS250119                             READY  NO ACCESS
# 11         vs_Rao_Enablement   content-based                                                          None      RN255043                             READY  NO ACCESS
# 12                realestate   content-based                                                          None      df120645                             READY  NO ACCESS
# 13                vs_ex_ak_1   content-based                                                          None      AK186064                             READY  NO ACCESS
# 14  TravelInsurance_chatbot2   content-based                                                          None      CH255039  CREATING (GENERATING EMBEDDINGS)  NO ACCESS
# 15                   kms_pdf   content-based                                                          None      KS250119                     UPDATE FAILED  NO ACCESS
# 16                 pog_slack   content-based                                                          None      mb255142  CREATING (GENERATING EMBEDDINGS)  NO ACCESS
# 17                vs_ex_us_3   content-based                                                          None      US186007                             READY  NO ACCESS
# 18                   jira_vs   content-based                                                          None      mb255142                     CREATE FAILED  NO ACCESS
# 19     cricket_test_examples  metadata-based                                                          None      KA255049                     CREATE FAILED  NO ACCESS
# 20                vs_example   content-based                                                          None      KS250118                             READY  NO ACCESS
# 21               vs_pdf1_kum   content-based                                                          None      KA255049                             READY  NO ACCESS
# 22          TravelInsurance2   content-based                                                          None      CH255039                             READY  NO ACCESS
# 23           vs_example_jess   content-based                                                          None      VJ255014                             READY  NO ACCESS
# 24                   vs_pdf1   content-based                                                          None      FA186006                             READY  NO ACCESS
# 25              vs_pdf1_ak_1   content-based                                                          None      AK186064                             READY  NO ACCESS
# 26          TravelInsurance3   content-based                                                          None      CH255039                             READY  NO ACCESS
# 27                 meta_test  metadata-based                                                          None      DF120645                             READY  NO ACCESS
# 28             vs_ex_emily_1   content-based                                                          None      XZ186023                             READY  NO ACCESS
# 29                pog_thread   content-based                                                          None      mb255142  CREATING (GENERATING EMBEDDINGS)  NO ACCESS
# 30      cricket_test_example  metadata-based                                                          None      US186007                    DESTROY FAILED  NO ACCESS
# 31               update_test   content-based                                      KMeans clustering method      DF120645                             READY  NO ACCESS
# 32                    vs_pdf   content-based                                                          None           oaf                             READY  NO ACCESS
# 33                vs_us_pdf1   content-based                                                          None      US186007                     CREATE FAILED  NO ACCESS
# 34                  vs_japan   content-based                                                          None      HX250007                             READY  NO ACCESS
# 35                tm122469_4   content-based                                                          None      TM122469                             READY  NO ACCESS
# 36             vs_pdf1_kumar   content-based                                                          None      KA255049                             READY  NO ACCESS

# %% [markdown]
# #### 🧩 **list_patterns()** - Explore Patterns in Vector Store
#    - **What It Does:** Fetches a list of all the patterns stored within the Vector Store. Perfect for creating metadata based Vector Store.
#    - **What You Get:** A DataFrame containing all the patterns stored

# %%
VSManager.list_patterns()
# Out:
#         PatternName           PatternString
# 0  df120645_include             df120645.%%
# 1   cricket_include  SEMANTIC_DATA.CRICKET%
# 2   cricket_exclude    SEMANTIC_DATA.%Test%

# %% [markdown]
# #### 🖥 **list_sessions()** - Active Sessions Overview
#    - **What It Does:** Lists all active sessions within the Vector Data Store. Useful for managing your active interactions with the system.
#    -  Note: This is available only for admin users.
#    - **What You Get:** A DataFrame with details about each active session.

# %%
sessions = VSManager.list_sessions()

# %%
sessions.session_details
# Out:
#                               session_id  username          vs_names
# 0   83897f97-9674-4678-a569-305d6fe9c0bf  KS250119           kms_pdf
# 1   3bfdc42d-f688-48b1-8a5a-aaa0082537fc  KS250119           kms_pdf
# 2   c71cdeb6-6551-4df4-8b3c-a8d9091086b9  CH255039  TravelInsurance3
# 3   03b2b7e6-ef04-463c-a846-8f71bfcd1d35  JV255027    vs_example_jvg
# 4   7014c63f-3707-42e3-8a21-a8b2b176a01c  AK186064        vs_ex_ak_1
# 5   820722a8-bc47-4c67-af46-c9aadac6e5ca  CH255039  TravelInsurance3
# 6   ac6cc648-5083-4317-92d1-b0bce59dac5c  MB255142           jira_vs
# 7   04ced548-cc50-41e1-845d-3e8fe8e7b763  MB255142           jira_vs
# 8   9a783b4f-b43b-4492-bea0-02c45719e728  VJ255014
# 9   aa0e918b-bf34-4deb-9916-4f2e0e5d914d  VJ255014
# 10  56a6ab8a-14b7-434f-b2dd-8e5df0db53f8  TM122469        tm122469_1
# 11  5fe826f5-06c6-4d01-abba-420c3f9fd90d  VJ255014   vs_example_jess
# 12  c1225c0a-5190-464f-bc88-5fd6afc52340  JV255027
# 13  9ab88ee1-2756-4205-b9af-3d48a8b0ec35  JV255027
# 14  bdceca47-7adb-42f2-bc05-709d9f7fdacb  VJ255014
# 15  ac17d882-a324-4323-a27b-5bcfb7dcf860  JV255027
# 16  99c2da9d-b08a-4c23-91ea-5d2918f5bc1f  JV255027
# 17  eae9fd34-dcf9-4a21-8824-808eb4a53040  KS250119           kms_pdf
# 18  60dbf6a3-07d4-4e6d-aaf7-426089661450  CH255039  TravelInsurance2

# %%
sessions.current_session_id
# Out:
# '9ab88ee1-2756-4205-b9af-3d48a8b0ec35'

# %%
sessions.total_active_sessions
# Out:
# 19

# %% [markdown]
# #### 🔌 **disconnect()** - End Active Sessions
#    - **What It Does:** Ends any active session by providing the session id - Applicable only for **admin**.
#    - If no session ID is provided, it terminates all active sessions created within the current python session. This is useful when you’re done working and want to disconnect from the system.
#    - **What You Get:** No return value, but all active sessions are closed.

# %%
VSManager.disconnect()
# Out:
# Database connection closed.

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <b style = 'font-size:30px;font-family:Arial;color:#00233C'>2. Getting Started with Vector Store </b>

# %% [markdown]
# ### 🛠 Steps to Create a Vector Store
#
# 1. **Initialize a VectorStore Instance**
#    - Create an instance of `VectorStore`
#
# 2. **Create the Vector Store**
#    - Use the `create()` method on the vector store instance to create a new vector store.
#
# By following these steps, we will successfully create vector store - `vs_example`.

# %%
vs = VectorStore(name="vs_example_jvg", log=True)
# Out:
# Vector Store vs_example_jvg does not exist. Call create() to create the same.

# %%
# Create an input DataFrame as amazon_reviews_25 is in 'oaf' database.
input_data = DataFrame(in_schema('oaf', 'amazon_reviews_25'))

# %%
#View data
input_data.head(5)
#input_data.info()
# Out:
#                               aid                         rev_name helpful                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                rev_text  rating                                      prodsummary  unixrevtime      revtime
# rev_id
# A1340OFLZBW5NG         000100039X                  Amazon Customer  [0, 0]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    I LOVE this book... his writing seems to just flow from page to page. I get something different from this book each time I read it..     5.0  Perhaps the greatest book that I have ever read   1231977600  01 15, 2009
# A1BM81XB4QHOA3         000100039X  "Ahoro Blethends ""Seriously"""  [0, 0]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              This book provides a reflection that you can apply to your own life.And, a way for you to try and assess whether you are truly doing the right thing and making the most of your short time on this plane.     5.0                  Must Read for Life Afficianados   1390003200  01 18, 2014
# A19N3FCQCLJYUA         000100039X                  Amazon Customer  [1, 1]  I discovered The Prophet fifty years ago in college and have read it dozens of times since then.  Now, in addition to my beat up hard copy, I have a portable e-copy.  If you were looking for an example of an intelligently designed (pun intended) book of spiritual guidance, this would be it.  It doesn"t care how you picture, name or define &#34;God&#34; or whether you give him a gender and a personality.  It just cuts to the heart of how to live and how to relate to others.  If Jesus and the Buddha teamed up to write a book, it might come out like this.When I first read it, I found some passages difficult to grasp.  Looking back, I now think that it was not because they were hard to understand, but because I did not want to hear gently spoken, intelligently phrased ideas that contradicted my own.  Now, if I could have only one book, this would probably be it.     5.0            A book everyone &#34;should&#34; read   1358899200  01 23, 2013
# A12387207U8U24         000100039X                             Alex  [0, 0]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          As you read, Gibran"s poetry brings spiritual and visual beauty to life within you. Gibran is justly famous for rich metaphors that brilliantly highlight the pursuit of Truth and Goodness amidst all the darkness and light of human nature.     5.0                                       Graet Work   1206662400  03 28, 2008
# A10000012B7CGYKOMPQ4L  000100039X                             Adam  [0, 0]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Spiritually and mentally inspiring! A book that allows you to question your morals and will help you discover who you really are!     5.0                                       Wonderful!   1355616000  12 16, 2012

# %%
# Python
vs.create(embeddings_model= 'amazon.titan-embed-text-v1',
          search_algorithm= 'HNSW',
          seed=10,
          top_k=10,
          ef_construction=32,
          num_connpernode=32,
          maxnum_connpernode=32,
          metric='EUCLIDEAN',
          apply_heuristics=False,
          ef_search=32,
          object_names= input_data,
          key_columns= ['rev_id', 'aid'],
          data_columns= ['rev_text'],
          vector_column= 'VectorIndex')
# Out:
# Vector store vs_example_jvg creation started.
# Use the 'status()' api to check the status of the operation.

# %% [markdown]
# ### ✅ Checking the Status of the Vector Store
#
# Though the create, update, destroy APIs are synchronous and will complete only after the operation is complete, user can ensure the same using the **status** API.
#
#  **Check the `status`**
#    - The `status` function allows you to confirm whether the particular operation is successful.

# %% [markdown]
# #### In this example, we can see the status of creation using **status()**

# %%
vs.status()
# Out:
#           vs_name status
# 0  vs_example_jvg  READY

# %% [markdown]
# #### Use the `list` function to retrieve all available vector stores and confirm if `vs_example` has been created.

# %%
VSManager.list()
# Out:
#                      vs_name      store_type                                                   description database_name                         vs_status permission
# 0             vs_pdf_emily_1   content-based                                                          None      XZ186023                             READY  NO ACCESS
# 1               ms_marco_mrr   content-based     Collection of datasets focused on deep learning in search           oaf                             READY  NO ACCESS
# 2      cricket_test_example1  metadata-based                                                          None      KS250118                             READY  NO ACCESS
# 3               vs_rodrigo_1   content-based                                                          None      RC255079                             READY  NO ACCESS
# 4             amazon_reviews   content-based  Amazon reviews about the book "The Prophet" by Kahlil Gibran           oaf                             READY  NO ACCESS
# 5     retail_comments_kms_1k   content-based                                                          None      KS250119                             READY  NO ACCESS
# 6                  vs_pdf_fa   content-based                                                          None      FA186006                             READY  NO ACCESS
# 7               vs_pdf1_rc_1   content-based                                                          None      RC255079                             READY  NO ACCESS
# 8    TravelInsurance_chatbot   content-based                                                          None      CH255039                             READY  NO ACCESS
# 9                 tm122469_1   content-based                                                          None      TM122469                             READY  NO ACCESS
# 10              kms__sql_pdf   content-based                                                          None      KS250119                             READY  NO ACCESS
# 11         vs_Rao_Enablement   content-based                                                          None      RN255043                             READY  NO ACCESS
# 12                realestate   content-based                                                          None      df120645                             READY  NO ACCESS
# 13                vs_ex_ak_1   content-based                                                          None      AK186064                             READY  NO ACCESS
# 14            vs_example_jvg   content-based                                                          None      JV255027                             READY      ADMIN
# 15                   kms_pdf   content-based                                                          None      KS250119                     UPDATE FAILED  NO ACCESS
# 16                 pog_slack   content-based                                                          None      mb255142  CREATING (GENERATING EMBEDDINGS)  NO ACCESS
# 17                vs_ex_us_3   content-based                                                          None      US186007                             READY  NO ACCESS
# 18                   jira_vs   content-based                                                          None      mb255142                     CREATE FAILED  NO ACCESS
# 19     cricket_test_examples  metadata-based                                                          None      KA255049                     CREATE FAILED  NO ACCESS
# 20                vs_example   content-based                                                          None      KS250118                             READY  NO ACCESS
# 21               vs_pdf1_kum   content-based                                                          None      KA255049                             READY  NO ACCESS
# 22  TravelInsurance_chatbot2   content-based                                                          None      CH255039  CREATING (GENERATING EMBEDDINGS)  NO ACCESS
# 23           vs_example_jess   content-based                                                          None      VJ255014                             READY  NO ACCESS
# 24                   vs_pdf1   content-based                                                          None      FA186006                             READY  NO ACCESS
# 25              vs_pdf1_ak_1   content-based                                                          None      AK186064                             READY  NO ACCESS
# 26          TravelInsurance3   content-based                                                          None      CH255039                             READY  NO ACCESS
# 27                 meta_test  metadata-based                                                          None      DF120645                             READY  NO ACCESS
# 28               update_test   content-based                                      KMeans clustering method      DF120645                             READY  NO ACCESS
# 29             vs_ex_emily_1   content-based                                                          None      XZ186023                             READY  NO ACCESS
# 30                pog_thread   content-based                                                          None      mb255142  CREATING (GENERATING EMBEDDINGS)  NO ACCESS
# 31      cricket_test_example  metadata-based                                                          None      US186007                    DESTROY FAILED  NO ACCESS
# 32          TravelInsurance2   content-based                                                          None      CH255039                             READY  NO ACCESS
# 33                    vs_pdf   content-based                                                          None           oaf                             READY  NO ACCESS
# 34                vs_us_pdf1   content-based                                                          None      US186007                     CREATE FAILED  NO ACCESS
# 35                  vs_japan   content-based                                                          None      HX250007                             READY  NO ACCESS
# 36                tm122469_4   content-based                                                          None      TM122469                             READY  NO ACCESS
# 37             vs_pdf1_kumar   content-based                                                          None      KA255049                             READY  NO ACCESS

# %% [markdown]
# ### 🔍 Performing a Similarity Search in `vs_example`
#
# \**similarity search** allows us to find the most relevant vectors based on a given input. By passing a question to the vector store `vs_example`, we can retrieve the closest matches based on the selected search algorithm.
#
# #### 🛠 How It Works
#
# 1. **Input a question**
#    - Pass a question or input text to `question` argument of `similarity_search()`.
#
# 2. **Perform the Similarity Search**
#    - The vector store searches for the most relevant matches using the specified **`search_algorithm`**.
#
# 3. **Retrieve Top Matches**
#    - The result contains the **top_k** most relevant entries along with their similarity scores, helping us understand how closely they match the input.
#
# This process enables efficient retrieval of information based on vector embeddings, making it useful for applications such as **semantic search, recommendation systems, and document retrieval**. 🚀

# %%
question = 'Which book are all the reviews talking about?'
response = vs.similarity_search(question=question)

# %%
response.similar_objects
# Out:
#       score DataBaseName          TableName          rev_id         aid                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      rev_text  index_label
# 0  0.067933          oaf  amazon_reviews_25   AENNW2G826191  000100039X                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Its a thin book, very readable and has interesting 1-2 page thoughts on various entities like anger, children, religion, speech, silence and its COOL.........reading. Ofcourse if one needs to imbibe the thoughts of the  author, it has to be consumed slowly and perhaps revisited but leaves you  pretty heady and clear about certain things.            2
# 1  0.061536          oaf  amazon_reviews_25  A2XQ5LZHTD4AFT  000100039X                                                                                                                                                                                 A timeless classic.  It is a very demanding and assuming title, but Gibran backs it up with some excellent style and content.  If he had the means to publish it a century or two earlier, he could have inspired a new religion.From the mouth of an old man about to sail away to a far away destination, we hear the wisdom of life and all important aspects of it.  It is a messege.  A guide book.  A Sufi sermon. Much is put in perspective without any hint of a dogma.  There is much that hints at his birth place, Lebanon where many of the old prophets walked the Earth and where this book project first germinated most likely.Probably becuase it was written in English originally, the writing flows, it is pleasant to read, and the charcoal drawings of the author decorating the pages is a plus.  I loved the cover.            4
# 2  0.060741          oaf  amazon_reviews_25  A2X4HE21JTAL98  000100039X                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Anything I"ve read by Gibran is, in my mind, flawless. This, the most famous of his works, is no exception. It is simple, yet deep; honest and profound; moving and inspirational. Gibran"s work is one of a kind, and can be far more encouraging and moving than any self-help program or therapy or anything like that. The poetic style, the aphorisms, the parables, the almost biblical feel, are all just what over-worked, over-stressed, modern and spiritually starved worldly people need.            5
# 3  0.060270          oaf  amazon_reviews_25  A2WVHIRDMLM82E  000100039X                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     This book has so much you can take out of it to use in your real life. Amazing, and one of my favorite reads of all time.            6
# 4  0.058509          oaf  amazon_reviews_25  A1BM81XB4QHOA3  000100039X                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    This book provides a reflection that you can apply to your own life.And, a way for you to try and assess whether you are truly doing the right thing and making the most of your short time on this plane.            8
# 5  0.056746          oaf  amazon_reviews_25  A3FI0744PG1WYG  000100039X                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               This is a timeless classic.  Over the years I"ve given it as a gift more times than I can count, and will continue to do so.  Addresses real life issues in a beautiful way and makes us reexamine our own attitude about how we see what happens in our lives.  So easy to read over and over.            9
# 6  0.059826          oaf  amazon_reviews_25  A1TT4CY55WLHAR  000100039X                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      I have the 1972 version, bought in 1974. The 1972 version originally had a dust jacket but my dust jacket is long gone. This particular rendition has had many re-printings, for a reason: it"s very popular. The textured paper, old-style typography, and leather cover are better than a plain-old paperback. The size is diminutive, which is perfect for this book.            7
# 7  0.062716          oaf  amazon_reviews_25   ARDQ9KNB8K22N  000100039X  Cool book, I really like the quality of the production.  Black clothbound with gold embossing and nice paper, looks to be cotton rag.  I am proud to include it in my collection.  Intrigueing story full of the sort of passion that does not cloud the mind or divert truth but instead is revealing and living. Very readable, the stories are short and highly economic so that one is likely to read for only a minute or two until something insightful is revealed. It is full of timeless truths which are of lasting value to the reader and inform life.  The language and delivery is familiar yet of a quality that is penetrating in a similar way as it might be listening to a surmon by Jesus.  I give it 5 stars. I considered giving only 4 stars because the format is fairly predictable but I have decided that this quality is actually a strength as one can pick up the book at any point and continue until the end...and then start over for that matter.  Excellent for busy people or commuters!            3
# 8  0.068101          oaf  amazon_reviews_25  A1KQ80Y692CDOI  000100039X                                                                                                                                                                                                                                                                                       I read this about a year ago and can"t recall a great deal of the book. From what I do recall it was like a poem all the way through. While the writing was beautiful, I found it ambiguous and befuddled with meaning that I could not identify with. When Gibran speaks of God, I cannot identify because I have since abandoned those philosophies. It is thus difficult to revisit them in this book. I have the feeling a may have missed something great about this book. Indeed, I pulled wisdom from parts, but rather than go back and read it again, for now, perhaps I will move on to another of the many books out there that are enlightening and worth reading. Someday, I would like to read this again and dig deeper.            1
# 9  0.069139          oaf  amazon_reviews_25  A2I35JB67U20C0  000100039X                                                                                    When I was in college in the 70"s this book had a revival and I did not read it then.  Recently a friend (who is 90) and I were talking about work and she said: &quot;work is love made visible,&quot; and told me it was from the Prophet.  I though that was so beautiful I got the book and was not disappointed.You see, if you have ideas and you do not realize them, then they are nothing, and if your ideas do not come from love and joy, then they are bitter and what they produce will be bitter, but if they flow from love and joy, then their realization will be love and joy, thus work is love made visible.He says it WAY better that I do and says much more in just a few paragraphs.  But as you can see from the example, what he says is not religious, but positive ways of looking at things.  Since I rediscoverd the book I have given away many copies and everyone I have given it to sincerly thanked me.            0

# %%
# In case user wants to output it in a json format which is faster, that can be done by passing return_type='json'

# %%
question = 'Which book are all the reviews talking about?'
response = vs.similarity_search(question=question, return_type='json')

# %%
response.similar_objects
# Out:
# [{'score': 0.0691391564911609,
#   'DataBaseName': 'oaf',
#   'TableName': 'amazon_reviews_25',
#   'rev_id': 'A2I35JB67U20C0',
#   'aid': '000100039X',
#   'rev_text': 'When I was in college in the 70"s this book had a revival and I did not read it then.  Recently a friend (who is 90) and I were talking about work and she said: &quot;work is love made visible,&quot; and told me it was from the Prophet.  I though that was so beautiful I got the book and was not disappointed.You see, if you have ideas and you do not realize them, then they are nothing, and if your ideas do not come from love and joy, then they are bitter and what they produce will be bitter, but if they flow from love and joy, then their realization will be love and joy, thus work is love made visible.He says it WAY better that I do and says much more in just a few paragraphs.  But as you can see from the example, what he says is not religious, but positive ways of looking at things.  Since I rediscoverd the book I have given away many copies and everyone I have given it to sincerly thanked me.'},
#  {'score': 0.06810094034237654,
#   'DataBaseName': 'oaf',
#   'TableName': 'amazon_reviews_25',
#   'rev_id': 'A1KQ80Y692CDOI',
#   'aid': '000100039X',
#   'rev_text': 'I read this about a year ago and can"t recall a great deal of the book. From what I do recall it was like a poem all the way through. While the writing was beautiful, I found it ambiguous and befuddled with meaning that I could not identify with. When Gibran speaks of God, I cannot identify because I have since abandoned those philosophies. It is thus difficult to revisit them in this book. I have the feeling a may have missed something great about this book. Indeed, I pulled wisdom from parts, but rather than go back and read it again, for now, perhaps I will move on to another of the many books out there that are enlightening and worth reading. Someday, I would like to read this again and dig deeper.'},
#  {'score': 0.06793269507818059,
#   'DataBaseName': 'oaf',
#   'TableName': 'amazon_reviews_25',
#   'rev_id': 'AENNW2G826191',
#   'aid': '000100039X',
#   'rev_text': 'Its a thin book, very readable and has interesting 1-2 page thoughts on various entities like anger, children, religion, speech, silence and its COOL.........reading. Ofcourse if one needs to imbibe the thoughts of the  author, it has to be consumed slowly and perhaps revisited but leaves you  pretty heady and clear about certain things.'},
#  {'score': 0.06271566145039231,
#   'DataBaseName': 'oaf',
#   'TableName': 'amazon_reviews_25',
#   'rev_id': 'ARDQ9KNB8K22N',
#   'aid': '000100039X',
#   'rev_text': 'Cool book, I really like the quality of the production.  Black clothbound with gold embossing and nice paper, looks to be cotton rag.  I am proud to include it in my collection.  Intrigueing story full of the sort of passion that does not cloud the mind or divert truth but instead is revealing and living. Very readable, the stories are short and highly economic so that one is likely to read for only a minute or two until something insightful is revealed. It is full of timeless truths which are of lasting value to the reader and inform life.  The language and delivery is familiar yet of a quality that is penetrating in a similar way as it might be listening to a surmon by Jesus.  I give it 5 stars. I considered giving only 4 stars because the format is fairly predictable but I have decided that this quality is actually a strength as one can pick up the book at any point and continue until the end...and then start over for that matter.  Excellent for busy people or commuters!'},
#  {'score': 0.0615360671161099,
#   'DataBaseName': 'oaf',
#   'TableName': 'amazon_reviews_25',
#   'rev_id': 'A2XQ5LZHTD4AFT',
#   'aid': '000100039X',
#   'rev_text': 'A timeless classic.  It is a very demanding and assuming title, but Gibran backs it up with some excellent style and content.  If he had the means to publish it a century or two earlier, he could have inspired a new religion.From the mouth of an old man about to sail away to a far away destination, we hear the wisdom of life and all important aspects of it.  It is a messege.  A guide book.  A Sufi sermon. Much is put in perspective without any hint of a dogma.  There is much that hints at his birth place, Lebanon where many of the old prophets walked the Earth and where this book project first germinated most likely.Probably becuase it was written in English originally, the writing flows, it is pleasant to read, and the charcoal drawings of the author decorating the pages is a plus.  I loved the cover.'},
#  {'score': 0.06074138404657596,
#   'DataBaseName': 'oaf',
#   'TableName': 'amazon_reviews_25',
#   'rev_id': 'A2X4HE21JTAL98',
#   'aid': '000100039X',
#   'rev_text': 'Anything I"ve read by Gibran is, in my mind, flawless. This, the most famous of his works, is no exception. It is simple, yet deep; honest and profound; moving and inspirational. Gibran"s work is one of a kind, and can be far more encouraging and moving than any self-help program or therapy or anything like that. The poetic style, the aphorisms, the parables, the almost biblical feel, are all just what over-worked, over-stressed, modern and spiritually starved worldly people need.'},
#  {'score': 0.06026991951339996,
#   'DataBaseName': 'oaf',
#   'TableName': 'amazon_reviews_25',
#   'rev_id': 'A2WVHIRDMLM82E',
#   'aid': '000100039X',
#   'rev_text': 'This book has so much you can take out of it to use in your real life. Amazing, and one of my favorite reads of all time.'},
#  {'score': 0.059826005644274684,
#   'DataBaseName': 'oaf',
#   'TableName': 'amazon_reviews_25',
#   'rev_id': 'A1TT4CY55WLHAR',
#   'aid': '000100039X',
#   'rev_text': 'I have the 1972 version, bought in 1974. The 1972 version originally had a dust jacket but my dust jacket is long gone. This particular rendition has had many re-printings, for a reason: it"s very popular. The textured paper, old-style typography, and leather cover are better than a plain-old paperback. The size is diminutive, which is perfect for this book.'},
#  {'score': 0.05850900615512858,
#   'DataBaseName': 'oaf',
#   'TableName': 'amazon_reviews_25',
#   'rev_id': 'A1BM81XB4QHOA3',
#   'aid': '000100039X',
#   'rev_text': 'This book provides a reflection that you can apply to your own life.And, a way for you to try and assess whether you are truly doing the right thing and making the most of your short time on this plane.'},
#  {'score': 0.05674568011114069,
#   'DataBaseName': 'oaf',
#   'TableName': 'amazon_reviews_25',
#   'rev_id': 'A3FI0744PG1WYG',
#   'aid': '000100039X',
#   'rev_text': 'This is a timeless classic.  Over the years I"ve given it as a gift more times than I can count, and will continue to do so.  Addresses real life issues in a beautiful way and makes us reexamine our own attitude about how we see what happens in our lives.  So easy to read over and over.'}]

# %% [markdown]
# ### 📝 Generating a Natural Language Response
#
# Once the **`similarity_search()`** method retrieves relevant results from the vector store, we can generate a natural language response by proving a prompt..
#
# #### 🛠 Steps to Prepare the Response
# 1.  **Input a question**
#    - Pass a question or input text to `question` argument of `prepare_response()`.
#
# 1. **Retrieve Similarity Results**
#    - The `similarity_search()` method returns the most relevant matches along with their similarity scores.
#
# 3. **Input a prompt**
#    - By passing `prompt`, we ask the model to format the output in a particular way
#
# #### As we can see below, by passing the question and the prompt, the response is formated in a conversational manner as suggested in the prompt.

# %%
question='Did any one feel the book is thin?'
prompt='Format the response in a conversational way.'
response = vs.prepare_response(question=question, similarity_results=response, prompt=prompt)

# %%
print(response)
# Out:
# Based on the reviews, it seems that some readers felt the book "The Prophet" by Kahlil Gibran was a thin book, but that this was not seen as a negative aspect. Here are a few relevant comments:
#
# "Its a thin book, very readable and has interesting 1-2 page thoughts on various entities like anger, children, religion, speech, silence and its COOL.........reading."
#
# "Excellent for busy people or commuters!"
#
# "The size is diminutive, which is perfect for this book."
#
# So while the book is described as "thin" or "diminutive" in size, the reviewers seem to view this as a positive attribute that makes the book easy to read and portable. The concise, poetic nature of the content in just a few pages per topic is also highlighted as a strength. Overall, the thinness of the book does not appear to be viewed negatively by these readers, but rather as fitting well with the style and purpose of "The Prophet."

# %% [markdown]
# ### ⚡ ask:
# #### Unified Similarity Search & Response Generation
# To improve efficiency, we can **combine similarity search and response generation** into a single operation. This method performs a similarity search in the vector store using the **input query** and then prepares a natural language response based on the retrieved results.
#
# #### 🔍 How It Works
#
# 1.  **Input a question**
#    - Pass a question or input text to `question` argument of `ask()`.
#
# 3. **Input a prompt**
#    - By passing `prompt`, we ask the model to format the output in a particular way
#
# **Faster Execution**
#    - By combining both steps into a single function call, response time is reduced, making the system more efficient.

# %%
custom_prompt = """List good reviews about the books. Do not assume information. Only provide information that is present in the data.
Format results like this:
Review ID: 
Author ID: 
Review: 
"""
question ='Are there any reviews saying that the books are inspiring?'
response = vs.ask(question=question, prompt=custom_prompt)

# %%
print(response)
# Out:
# Yes, there are several reviews that describe the book as inspiring:
#
# Review ID: A10000012B7CGYKOMPQ4L
# Author ID: 000100039X
# Review: Spiritually and mentally inspiring! A book that allows you to question your morals and will help you discover who you really are!
#
# Review ID: A2S166WSCFIFP5
# Author ID: 000100039X
# Review: This is one my must have books. It is a masterpiece of spirituality. I'll be the first to admit, its literary quality isn't much. It is rather simplistically written, but the message behind it is so powerful that you have to read it. It will take you to enlightenment.
#
# Review ID: A1MOSTXNIO5MPJ
# Author ID: 000100039X
# Review: I first read THE PROPHET in college back in the 60's. The book had a revival as did anything metaphysical in the turbulent 60's. It had a profound effect on me and became a book I always took with me. After graduation I joined the Peace Corps and during stressful training in country (Liberia) at times of illness and the night before I left, this book gave me great comfort.

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
#
# <b style="font-size:30px; font-family:Arial; color:#00233C;">3. Initializing and Using the Existing Vector</b>

# %% [markdown]
# ### 🔄 Using an Existing Vector Store
#
# If you have an existing vector store that you want to reuse, you can initialize it by providing the **name** of the store. This allows you to interact with and perform operations on the existing store without creating a new one.
#
# #### 🛠 Steps to Initialize existing Vector Store
#
# 1. **Provide the Name of the Vector Store**
#    - Specify the name (e.g., `vs_update`) of the existing vector store that you want to access.
#    - In this case, for object_names we will pass in the teradataml DataFrame.
#
#
# 2. **Initialize the Vector Store Instance**
#    - By using the provided name, you can initialize the vector store instance and begin interacting with it.

# %%
# Initialize existing VS
updated_vs = VectorStore("vs_example_jvg")
# Out:
# Vector store vs_example_jvg is initialized for the session.

# %% [markdown]
# ### ✨ Updating Arguments of an Existing Vector Store
#
# You can **update** specific parameters of an existing vector store without having to recreate it. For instance, you may want to modify the **search algorithm** or other configuration settings to better suit your needs. This can be done using the `update()` API, which allows you to change the arguments of the vector store.
#
# #### 🛠 Steps to Update an Existing Vector Store
#
# 1. **Access the Existing Vector Store**
#    - First, ensure that the vector store (e.g., `vs_update`) is already initialized.
#
# 2. **Use the `update()` API**
#    - Call the `update()` method on the vector store instance and provide the new argument(s) you want to modify, such as the `search_algorithm`.

# %%
updated_vs.update(search_algorithm="KMEANS")
# Out:
# Vector store vs_example_jvg update started.
# Use the 'status()' api to check the status of the operation.

# %%
updated_vs.status()
# Out:
#           vs_name    status  retry_after
# 0  vs_example_jvg  UPDATING           60

# %% [markdown]
# ### 🔍 Performing Similarity Search, Preparing Response, and Asking on the Updated Vector Store
#
# Once you've updated the vector store, you can seamlessly perform a **similarity search**, prepare a **natural language response**, and ask the updated vector store to retrieve the most relevant information.
#
# #### 🛠 Steps to Perform on the Updated Vector Store
#
# 1. **Similarity Search**
#    - Use the `similarity_search()` method to find the most relevant matches for your input question based on the updated configuration.

# %%
question = 'Which book are all the reviews talking about?'
response = updated_vs.similarity_search(question=question)

# %%
response.similar_objects
# Out:
#       score DataBaseName          TableName          rev_id         aid                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      rev_text  index_label
# 0  0.079705          oaf  amazon_reviews_25   ARDQ9KNB8K22N  000100039X  Cool book, I really like the quality of the production.  Black clothbound with gold embossing and nice paper, looks to be cotton rag.  I am proud to include it in my collection.  Intrigueing story full of the sort of passion that does not cloud the mind or divert truth but instead is revealing and living. Very readable, the stories are short and highly economic so that one is likely to read for only a minute or two until something insightful is revealed. It is full of timeless truths which are of lasting value to the reader and inform life.  The language and delivery is familiar yet of a quality that is penetrating in a similar way as it might be listening to a surmon by Jesus.  I give it 5 stars. I considered giving only 4 stars because the format is fairly predictable but I have decided that this quality is actually a strength as one can pick up the book at any point and continue until the end...and then start over for that matter.  Excellent for busy people or commuters!            2
# 1  0.074058          oaf  amazon_reviews_25  A3FI0744PG1WYG  000100039X                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               This is a timeless classic.  Over the years I"ve given it as a gift more times than I can count, and will continue to do so.  Addresses real life issues in a beautiful way and makes us reexamine our own attitude about how we see what happens in our lives.  So easy to read over and over.            4
# 2  0.073995          oaf  amazon_reviews_25  A1TT4CY55WLHAR  000100039X                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      I have the 1972 version, bought in 1974. The 1972 version originally had a dust jacket but my dust jacket is long gone. This particular rendition has had many re-printings, for a reason: it"s very popular. The textured paper, old-style typography, and leather cover are better than a plain-old paperback. The size is diminutive, which is perfect for this book.            5
# 3  0.062757          oaf  amazon_reviews_25  A26GKZPS079GFF  000100039X                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         I would have to say that this is the best book I"ve ever read.. I could feel every word deep in my heart everytime, of the many times I"ve read it!  I would never get enough of it! its a treasure..            6
# 4  0.041248          oaf  amazon_reviews_25  A3V1MKC2BVWY48  000100039X                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Reading this made my mind feel like a still pool of water, cool and quiet in a mossy grotto.  It"s direct and simple wisdom has a depth of complexity that takes a quiet day to sink in, leaving you at peace.  It is best to set time aside for it, relax, absorb, and let it softly clear your mind.            8
# 5  0.055994          oaf  amazon_reviews_25  A1340OFLZBW5NG  000100039X                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          I LOVE this book... his writing seems to just flow from page to page. I get something different from this book each time I read it..            7
# 6  0.078411          oaf  amazon_reviews_25  A1BM81XB4QHOA3  000100039X                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    This book provides a reflection that you can apply to your own life.And, a way for you to try and assess whether you are truly doing the right thing and making the most of your short time on this plane.            3
# 7  0.088779          oaf  amazon_reviews_25  A2WVHIRDMLM82E  000100039X                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     This book has so much you can take out of it to use in your real life. Amazing, and one of my favorite reads of all time.            1
# 8  0.089033          oaf  amazon_reviews_25   AENNW2G826191  000100039X                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Its a thin book, very readable and has interesting 1-2 page thoughts on various entities like anger, children, religion, speech, silence and its COOL.........reading. Ofcourse if one needs to imbibe the thoughts of the  author, it has to be consumed slowly and perhaps revisited but leaves you  pretty heady and clear about certain things.            0

# %% [markdown]
# 2. **Prepare the Response**
#    - After retrieving the search results, use the `prepare_response()` function to generate a user-friendly, natural language response based on the most relevant matches.

# %%
question = 'Which book are all the reviews talking about?'
response = updated_vs.prepare_response(question=question, similarity_results=response)

# %%
print(response)
# Out:
# Based on the review texts, it appears that all the reviews are discussing the book "The Prophet" by Kahlil Gibran. The reviews mention characteristics of the book such as it being a "timeless classic", having a "leather cover", being "very readable", and containing "timeless truths" and "simple wisdom". These details strongly suggest that the book being reviewed is Kahlil Gibran's "The Prophet".

# %% [markdown]
# 3. **Ask the Updated Vector Store**
#    - Combine these operations using the `ask()` method, which performs the search and generates the response in one call, ensuring faster and more efficient retrieval of information.

# %%
custom_prompt = """List good reviews about the books. Do not assume information. Only provide information that is present in the data.
Format results like this:
review_id: 
Book Title: 
Author: 
Review: 
"""
question="Are there any reviews saying that the books are inspiring?"
response = updated_vs.ask(question=question, prompt=custom_prompt)

# %%
print(response)
# Out:
# Yes, there are several reviews that mention the book being inspiring or impactful:
#
# review_id: ARDQ9KNB8K22N
# Book Title: Not provided
# Author: Not provided
# Review: "Intrigueing story full of the sort of passion that does not cloud the mind or divert truth but instead is revealing and living. Very readable, the stories are short and highly economic so that one is likely to read for only a minute or two until something insightful is revealed. It is full of timeless truths which are of lasting value to the reader and inform life."
#
# review_id: A1BM81XB4QHOA3
# Book Title: Not provided
# Author: Not provided
# Review: "This book provides a reflection that you can apply to your own life.And, a way for you to try and assess whether you are truly doing the right thing and making the most of your short time on this plane."
#
# review_id: A26GKZPS079GFF
# Book Title: Not provided
# Author: Not provided
# Review: "I would have to say that this is the best book I"ve ever read.. I could feel every word deep in my heart everytime, of the many times I"ve read it!  I would never get enough of it! its a treasure.."
#
# review_id: A3FI0744PG1WYG
# Book Title: Not provided
# Author: Not provided
# Review: "This is a timeless classic.  Over the years I"ve given it as a gift more times than I can count, and will continue to do so.  Addresses real life issues in a beautiful way and makes us reexamine our own attitude about how we see what happens in our lives.  So easy to read over and over."
#
# review_id: A1340OFLZBW5NG
# Book Title: Not provided
# Author: Not provided
# Review: "I LOVE this book... his writing seems to just flow from page to page. I get something different from this book each time I read it.."
#
# review_id: A2WVHIRDMLM82E
# Book Title: Not provided
# Author: Not provided
# Review: "This book has so much you can take out of it to use in your real life. Amazing, and one of my favorite reads of all time.."

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
#
# <b style="font-size:30px; font-family:Arial; color:#00233C;">4.Access Management in Vector Store</b>

# %% [markdown]
# You can manage both **admin** and **user** permissions for users in your vector store. This section shows how to **grant** and **revoke** these permissions to control access effectively.
# **Note Only admin user can view the permissions or grant/revoke user/admin access to Vector Store.**

# %% [markdown]
# ### 👥 Listing User Permissions in the Vector Store
#
# To view the permissions currently assigned to users in the vector store, you can use the `list_user_permissions()` method. This will display a list of all users and the respective access rights they have on the Vector Store.

# %%
updated_vs.list_user_permissions()
# Out:
#       Users Permissions
# 0  jv255027       ADMIN
# 1       dbc       ADMIN

# %% [markdown]
# #### 🔒 Granting and Revoking user Permission from User 'alice'
#
# You can grant or revoke **USER** permission for specific users to control their access level to the vector store.
# Below is how you can handle the **USER** permission for user `alice`.
#
# ##### 🛠 Steps to Grant or Revoke USER Permission for User 'alice'
#
# 1. **Grant USER Permission**
#    - Use the `grant.user()` method to assign **USER** permission to user `alice`.

# %%
updated_vs.grant.user('alice')
# Out:
# USER permission for vector store vs_example_jvg has been granted to user alice.

# %%
# check granted permission
updated_vs.list_user_permissions()
# Out:
#       Users Permissions
# 0  jv255027       ADMIN
# 1       dbc       ADMIN
# 2     alice        USER

# %% [markdown]
# 2. **Revoke USER Permission**
#    - Use the `revoke.user()` method to remove **USER** permission from user `alice`.

# %%
updated_vs.revoke.user('alice')
# Out:
# USER permission for vector store vs_example_jvg has been revoked from user alice.

# %%
# check revoked permission
updated_vs.list_user_permissions()
# Out:
#       Users Permissions
# 0  jv255027       ADMIN
# 1       dbc       ADMIN

# %% [markdown]
# #### 🔒 Granting and Revoking ADMIN Permission from User 'alice'
#
# To manage the **ADMIN** access for a user, such as `alice`, you can use the `grant.admin()` and `revoke.admin()` methods. This allows you to control who can modify the contents of the vector store.
#
# ##### 🛠 Steps to Grant or Revoke ADMIN Permission for User 'alice'
#
# 1. **Grant ADMIN Permission**
#    - Use the `grant.admin()` method to assign **ADMIN** permission to user `alice`.

# %%
updated_vs.grant.admin('alice')
# Out:
# ADMIN permission for vector store vs_example_jvg has been granted to user alice.

# %% [markdown]
# 2. **Revoke ADMIN Permission**
#    - Use the `revoke.admin()` method to remove **ADMIN** permission from user `alice`.

# %%
updated_vs.revoke.admin('alice')
# Out:
# ADMIN permission for vector store vs_example_jvg has been revoked from user alice.

# %%
updated_vs.list_user_permissions()
# Out:
#       Users Permissions
# 0  jv255027       ADMIN
# 1       dbc       ADMIN

# %% [markdown]
# ### 🗑️ Destroying the Vector Store
#
# When a vector store is no longer needed, you can **permanently delete** it to free up resources.
# The **destroy** operation removes the vector store and all associated data.
#
# #### ⚠️ Important Considerations
# - **Irreversible Action**: Once a vector store is destroyed, it **cannot be recovered**.
# - **Does Not Remove Connection**: Destroying a vector store **only deletes the vector store**—it does not remove the underlying database connection. The instance remains active and can be used to create a new vector store.

# %%
updated_vs.destroy()
# Out:
# Vector store vs_example_jvg destroy started.
# Use the 'status()' api to check the status of the operation.

# %%
updated_vs.status()
# Out:
# Vector Store does not exist or it is has been destroyed successfully.

# %%
VSManager.list()
# Out:
#                      vs_name      store_type                                                   description database_name                         vs_status permission
# 0             vs_pdf_emily_1   content-based                                                          None      XZ186023                             READY  NO ACCESS
# 1               ms_marco_mrr   content-based     Collection of datasets focused on deep learning in search           oaf                             READY  NO ACCESS
# 2      cricket_test_example1  metadata-based                                                          None      KS250118                             READY  NO ACCESS
# 3               vs_rodrigo_1   content-based                                                          None      RC255079                             READY  NO ACCESS
# 4             amazon_reviews   content-based  Amazon reviews about the book "The Prophet" by Kahlil Gibran           oaf                             READY  NO ACCESS
# 5     retail_comments_kms_1k   content-based                                                          None      KS250119                             READY  NO ACCESS
# 6                  vs_pdf_fa   content-based                                                          None      FA186006                             READY  NO ACCESS
# 7               vs_pdf1_rc_1   content-based                                                          None      RC255079                             READY  NO ACCESS
# 8    TravelInsurance_chatbot   content-based                                                          None      CH255039                             READY  NO ACCESS
# 9                  pog_slack   content-based                                                          None      mb255142  CREATING (GENERATING EMBEDDINGS)  NO ACCESS
# 10              kms__sql_pdf   content-based                                                          None      KS250119                             READY  NO ACCESS
# 11         vs_Rao_Enablement   content-based                                                          None      RN255043                             READY  NO ACCESS
# 12                realestate   content-based                                                          None      df120645                             READY  NO ACCESS
# 13                vs_ex_ak_1   content-based                                                          None      AK186064                             READY  NO ACCESS
# 14  TravelInsurance_chatbot2   content-based                                                          None      CH255039  CREATING (GENERATING EMBEDDINGS)  NO ACCESS
# 15                   kms_pdf   content-based                                                          None      KS250119                     UPDATE FAILED  NO ACCESS
# 16                vs_ex_us_3   content-based                                                          None      US186007                             READY  NO ACCESS
# 17                   vs_pdf1   content-based                                                          None      FA186006                             READY  NO ACCESS
# 18     cricket_test_examples  metadata-based                                                          None      KA255049                     CREATE FAILED  NO ACCESS
# 19                vs_example   content-based                                                          None      KS250118                             READY  NO ACCESS
# 20               vs_pdf1_kum   content-based                                                          None      KA255049                             READY  NO ACCESS
# 21          TravelInsurance2   content-based                                                          None      CH255039                             READY  NO ACCESS
# 22          TravelInsurance3   content-based                                                          None      CH255039                             READY  NO ACCESS
# 23                 meta_test  metadata-based                                                          None      DF120645                             READY  NO ACCESS
# 24              vs_pdf1_ak_1   content-based                                                          None      AK186064                             READY  NO ACCESS
# 25               update_test   content-based                                      KMeans clustering method      DF120645                             READY  NO ACCESS
# 26                pog_thread   content-based                                                          None      mb255142  CREATING (GENERATING EMBEDDINGS)  NO ACCESS
# 27      cricket_test_example  metadata-based                                                          None      US186007                    DESTROY FAILED  NO ACCESS
# 28             vs_ex_emily_1   content-based                                                          None      XZ186023                             READY  NO ACCESS
# 29                    vs_pdf   content-based                                                          None           oaf                             READY  NO ACCESS
# 30                vs_us_pdf1   content-based                                                          None      US186007                     CREATE FAILED  NO ACCESS
# 31                  vs_japan   content-based                                                          None      HX250007                             READY  NO ACCESS
# 32                tm122469_4   content-based                                                          None      TM122469                             READY  NO ACCESS
# 33             vs_pdf1_kumar   content-based                                                          None      KA255049                             READY  NO ACCESS

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <b style = 'font-size:30px;font-family:Arial;color:#00233C'>5.Building a Vector Store from PDF Documents
#  </b>

# %% [markdown]
# ### 📂 Creating a Vector Store using PDF files.
#
# To create a vector store from a PDF document, follow these steps:
#
# 1. **Create an Instance of Vector Store (`vs_pdf1`)**
#    - First, instantiate a new vector store where the PDF content will be stored.

# %%
pdf_vs = VectorStore('vs_pdf2')
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\jv255027\AppData\Local\miniforge3\envs\vsenv311\Lib\site-packages\requests\models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\jv255027\AppData\Local\miniforge3\envs\vsenv311\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File c:\Users\jv255027\AppData\Local\miniforge3\envs\vsenv311\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File c:\Users\jv255027\AppData\Local\miniforge3\envs\vsenv311\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\jv255027\AppData\Local\miniforge3\envs\vsenv311\Lib\site-packages\teradatagenai\vector_store\vector_store.py:2694, in VectorStore._process_vs_response(api_name, response, success_status_code, raise_error)
#    2693 try:
# -> 2694     data = response.json()
#    2695     # Success status code ranges between 200-300.
#
# File c:\Users\jv255027\AppData\Local\miniforge3\envs\vsenv311\Lib\site-packages\requests\models.py:978, in Response.json(self, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 978     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# TeradataMlException                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 pdf_vs = VectorStore('vs_pdf2')
#
# File c:\Users\jv255027\AppData\Local\miniforge3\envs\vsenv311\Lib\site-packages\teradatagenai\vector_store\vector_store.py:555, in VectorStore.__init__(self, name, log, **kwargs)
#     548 _Validators._check_required_params(arg_value=configure._vector_store_base_url,
#     549                                    arg_name="Auth token",
#     550                                    caller_func_name="VectorStore()",
#     551                                    target_func_name="set_auth_token")
#     553 # Call connect in case of CCP enabled tenant.
#     554 # If non-ccp, connect should be explicitly called passing the required params.
# --> 555 session_header = VSManager._generate_session_id()
#     556 self.__session_id = session_header["vs_session_id"]
#     557 self.__headers = session_header["vs_header"]
#
# File c:\Users\jv255027\AppData\Local\miniforge3\envs\vsenv311\Lib\site-packages\teradatagenai\vector_store\vector_store.py:179, in VSManager._generate_session_id(**kwargs)
#     176 # If the buffer is empty, meaning its the first call to
#     177 # _connect, call _connect to generate the session id.
#     178 if _InternalBuffer.get("vs_session_id") is None and kwargs.get("generate", True):
# --> 179     VSManager._connect()
#     180 # This is for cases when 'vs_session_id' is not stored in the buffer,
#     181 # it should return None instead of returning a dict with None values.
#     182 if _InternalBuffer.get("vs_session_id") is not None:
#
# File c:\Users\jv255027\AppData\Local\miniforge3\envs\vsenv311\Lib\site-packages\teradatagenai\vector_store\vector_store.py:150, in VSManager._connect(**kwargs)
#     147     _InternalBuffer.add(vs_session_id=session_id)
#     148     _InternalBuffer.add(vs_header=headers)
# --> 150 VectorStore._process_vs_response(api_name="connect", response=response)
#
# File c:\Users\jv255027\AppData\Local\miniforge3\envs\vsenv311\Lib\site-packages\teradatagenai\vector_store\vector_store.py:2757, in VectorStore._process_vs_response(api_name, response, success_status_code, raise_error)
#    2753     error_msg = Messages.get_message(MessageCodes.FUNC_EXECUTION_FAILED,
#    2754                                      api_name,
#    2755                                      response.text)
#    2756     if raise_error:
# -> 2757         raise TeradataMlException(error_msg, MessageCodes.FUNC_EXECUTION_FAILED)
#    2758 except Exception as e:
#    2759     if raise_error:
#
# TeradataMlException: [Teradata][teradataml](TDML_2412) Failed to execute connect. <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <HTML><HEAD><META HTTP-EQUIV="Content-Type" CONTENT="text/html; charset=iso-8859-1">
# <TITLE>ERROR: The request could not be satisfied</TITLE>
# </HEAD><BODY>
# <H1>504 ERROR</H1>
# <H2>The request could not be satisfied.</H2>
# <HR noshade size="1px">
# CloudFront attempted to establish a connection with the origin, but either the attempt failed or the origin closed the connection.
# We can't connect to the server for this app or website at this time. There might be too much traffic or a configuration error. Try again later, or contact the app or website owner.
# <BR clear="all">
# If you provide content to customers through CloudFront, you can find steps to troubleshoot and help prevent this error by reviewing the CloudFront documentation.
# <BR clear="all">
# <HR noshade size="1px">
# <PRE>
# Generated by cloudfront (CloudFront)
# Request ID: lfJMFaccxsM30RxMr0zXXhmweO7ituJAUduZoNQWuP9akFAV-rDruQ==
# </PRE>
# <ADDRESS>
# </ADDRESS>
# </BODY></HTML>

# %%
import os
files = [os.path.join(os.getcwd(), "AgenticAIResearch.pdf")]

# %% [markdown]
# 2. **Call the `create` Method**
#    - Using the vector store instance, call the `create()` method and pass the PDF document file(s) as the `document_files` argument to upload and vectorize the content.

# %%
pdf_vs.create(embeddings_model= 'amazon.titan-embed-text-v1',
              search_algorithm= 'VECTORDISTANCE',
              top_k= 10,
              object_names= 'AgenticAIResearch',
              data_columns= ['chunks'],
              vector_column= 'VectorIndex',
              chunk_size= 500,
              optimized_chunking=False,
              document_files=files)
# Out:
# Vector store vs_pdf2 creation started.
# Use the 'status()' api to check the status of the operation.

# %%
pdf_vs.status()
# Out:
#    vs_name status
# 0  vs_pdf2  READY

# %%
VSManager.list()
# Out:
#                      vs_name      store_type                                                   description database_name                         vs_status permission
# 0             vs_pdf_emily_1   content-based                                                          None      XZ186023                             READY  NO ACCESS
# 1               ms_marco_mrr   content-based     Collection of datasets focused on deep learning in search           oaf                             READY  NO ACCESS
# 2      cricket_test_example1  metadata-based                                                          None      KS250118                             READY  NO ACCESS
# 3               vs_rodrigo_1   content-based                                                          None      RC255079                             READY  NO ACCESS
# 4             amazon_reviews   content-based  Amazon reviews about the book "The Prophet" by Kahlil Gibran           oaf                             READY  NO ACCESS
# 5     retail_comments_kms_1k   content-based                                                          None      KS250119                             READY  NO ACCESS
# 6                  vs_pdf_fa   content-based                                                          None      FA186006                             READY  NO ACCESS
# 7               vs_pdf1_rc_1   content-based                                                          None      RC255079                             READY  NO ACCESS
# 8    TravelInsurance_chatbot   content-based                                                          None      CH255039                             READY  NO ACCESS
# 9                 tm122469_1   content-based                                                          None      TM122469                             READY  NO ACCESS
# 10              kms__sql_pdf   content-based                                                          None      KS250119                             READY  NO ACCESS
# 11         vs_Rao_Enablement   content-based                                                          None      RN255043                             READY  NO ACCESS
# 12                realestate   content-based                                                          None      df120645                             READY  NO ACCESS
# 13                vs_ex_ak_1   content-based                                                          None      AK186064                             READY  NO ACCESS
# 14            vs_example_jvg   content-based                                                          None      JV255027                             READY      ADMIN
# 15                   kms_pdf   content-based                                                          None      KS250119                     UPDATE FAILED  NO ACCESS
# 16                 pog_slack   content-based                                                          None      mb255142  CREATING (GENERATING EMBEDDINGS)  NO ACCESS
# 17                vs_ex_us_3   content-based                                                          None      US186007                             READY  NO ACCESS
# 18                   jira_vs   content-based                                                          None      mb255142                     CREATE FAILED  NO ACCESS
# 19     cricket_test_examples  metadata-based                                                          None      KA255049                     CREATE FAILED  NO ACCESS
# 20                vs_example   content-based                                                          None      KS250118                             READY  NO ACCESS
# 21               vs_pdf1_kum   content-based                                                          None      KA255049                             READY  NO ACCESS
# 22  TravelInsurance_chatbot2   content-based                                                          None      CH255039  CREATING (GENERATING EMBEDDINGS)  NO ACCESS
# 23              pdf_test_doc   content-based                                                          None      JV255027                     CREATE FAILED      ADMIN
# 24           vs_example_jess   content-based                                                          None      VJ255014                             READY  NO ACCESS
# 25                   vs_pdf1   content-based                                                          None      FA186006                             READY  NO ACCESS
# 26          TravelInsurance2   content-based                                                          None      CH255039                             READY  NO ACCESS
# 27          TravelInsurance3   content-based                                                          None      CH255039                             READY  NO ACCESS
# 28                 meta_test  metadata-based                                                          None      DF120645                             READY  NO ACCESS
# 29              vs_pdf1_jess   content-based                                                          None      VJ255014                             READY  NO ACCESS
# 30               update_test   content-based                                      KMeans clustering method      DF120645                             READY  NO ACCESS
# 31                   vs_pdf2   content-based                                                          None      JV255027                             READY      ADMIN
# 32                pog_thread   content-based                                                          None      mb255142  CREATING (GENERATING EMBEDDINGS)  NO ACCESS
# 33             vs_ex_emily_1   content-based                                                          None      XZ186023                             READY  NO ACCESS
# 34      cricket_test_example  metadata-based                                                          None      US186007                    DESTROY FAILED  NO ACCESS
# 35              vs_pdf1_ak_1   content-based                                                          None      AK186064                             READY  NO ACCESS
# 36                    vs_pdf   content-based                                                          None           oaf                             READY  NO ACCESS
# 37                vs_us_pdf1   content-based                                                          None      US186007                     CREATE FAILED  NO ACCESS
# 38                  vs_japan   content-based                                                          None      HX250007                             READY  NO ACCESS
# 39                tm122469_4   content-based                                                          None      TM122469                             READY  NO ACCESS
# 40             vs_pdf1_kumar   content-based                                                          None      KA255049                             READY  NO ACCESS

# %% [markdown]
# ### ❓ Asking a Question Based on Uploaded Document to the Vector Store
#
# Once you have uploaded your PDF content into the vector store, you can ask specific questions based on the content stored in the vector store. The vector store will use its similarity search to find the most relevant information and provide a detailed response.
#
# #### 🛠 Steps to Ask a Question from the Vector Store
#
# 1. **Define the Question and Prompt**
#    - Formulate the question you'd like to ask and provide a prompt for context. In this case, the question is about searching for NULL and NOT NULL values in Teradata.
#
# 2. **Use the `ask` Method**
#    - Call the `ask()` method on the vector store instance, passing both the question and prompt. The vector store will then return a response based on the content of the uploaded document.

# %%
question= 'What is Agentic AI?'
prompt= 'Give a brief summary.'
response = pdf_vs.ask(question=question, prompt=prompt)

# %%
print(response)
# Out:
# Based on the summary provided in the data, Agentic AI can be described as follows:
#
# 1. Agentic AI refers to AI systems and models that can act autonomously to achieve goals without the need for constant human guidance. They understand the user's goals and the context of the problem they are trying to solve.
#
# 2. Agentic AI differs from generative AI like ChatGPT in three key ways:
#    a. Focused on making decisions rather than creating content
#    b. Do not rely on human prompts, but rather understand the goals and objectives
#    c. Carry out complex sequences of activities, independently searching databases or triggering workflows to complete activities
#
# 3. Key characteristics of Agentic AI:
#    a. Proactiveness - can act autonomously to achieve goals
#    b. Ability to make decisions and carry out complex tasks without constant human guidance
#    c. Understanding of user goals and context to solve problems
#    d. Potential applications in areas like customer service, manufacturing, sales support, health and social care, etc.
#
# 4. Agentic AI is still in the early stages of development and faces challenges in terms of ensuring security, trust, and alignment with human and brand values as it becomes more advanced.

# %%
pdf_vs.destroy()
# Out:
# Vector store vs_pdf2 destroy started.
# Use the 'status()' api to check the status of the operation.

# %%
pdf_vs.status()
# Out:
# Vector Store does not exist or it is has been destroyed successfully.

# %%
VSManager.disconnect()
# Out:
# Database connection closed.

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <b style = 'font-size:30px;font-family:Arial;color:#00233C'>6. Pattern Management for Vector Store.</b>

# %% [markdown]
# ## 🧩 Creation of Pattern for Metabased Vector Store
#
# To create a pattern and search for matching objects in the Metabased Vector Store, follow these steps:
#
# - **Create an Instance of VSPattern**
#    - Instantiate a VSPattern with the name `cricket_include`.

# %%
ptn = VSPattern(name='cricket_include')
# Out:
# Database connection established in 357.76 milliseconds.

# %%
ptn2 = VSPattern(name='cricket_exclude')

# %% [markdown]
# - **Run `create()`**
#    - Pass the `pattern_string` to the `create()` method to define the pattern for the vector store.

# %%
ptn.create(pattern_string = 'SEMANTIC_DATA.CRICKET%')
# Out:
# Pattern cricket_include created.

# %%
ptn2.create(pattern_string='SEMANTIC_DATA.%Test%')
# Out:
# Pattern cricket_exclude created.

# %% [markdown]
# - **Check Pattern Creation with `list_patterns()`**
#    - Use the `list_patterns()` method to confirm the successful creation of the pattern.

# %%
VSManager.list_patterns()
# Out:
#         PatternName           PatternString
# 0  df120645_include             df120645.%%
# 1   cricket_include  SEMANTIC_DATA.CRICKET%
# 2   cricket_exclude    SEMANTIC_DATA.%Test%

# %% [markdown]
# - **Use `get()` to Fetch Matching Objects**
#    - Retrieve a list of objects that match the

# %%
ptn.get()
# Out:
#                        Object list
# 0  semantic_data.CRICKET_Test_Data
# 1   semantic_data.CRICKET_ODI_Data

# %%
ptn2.get()
# Out:
#                        Object list
# 0  semantic_data.CRICKET_Test_Data

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <b style = 'font-size:30px;font-family:Arial;color:#00233C'>7. Working with metadata-based Vector Store.</b>

# %% [markdown]
# ## 🧩 Creation of Metadata-based Vector Store

# %% [markdown]
# ##**NOTE: Metadata- based vector store is currently not working from the service.**

# %%
vs_meta = VectorStore(name='cricket_test_example')
# Out:
# Vector Store cricket_test_example has status 'CREATE FAILED'. Call create() to create it again.

# %%
# Metabased vector consumes patterns
vs_meta.create(embeddings_model= 'amazon.titan-embed-text-v1',
               search_algorithm= 'VECTORDISTANCE',
               top_k= 10,
               include_patterns = [ptn],
               exclude_patterns = [ptn2])
# Out:
# Vector store cricket_test_example creation started.
# Use the 'status()' api to check the status of the operation.

# %%
vs_meta.status()
# Out:
#                 vs_name status
# 0  cricket_test_example  READY

# %%
VSManager.list()
# Out:
#                 vs_name      store_type                                                   description database_name vs_status permission
# 0          ms_marco_mrr   content-based     Collection of datasets focused on deep learning in search           oaf     READY       USER
# 1                vs_pdf   content-based                                                          None           oaf     READY  NO ACCESS
# 2        amazon_reviews   content-based  Amazon reviews about the book "The Prophet" by Kahlil Gibran           oaf     READY  NO ACCESS
# 3       vs_example_1_ak   content-based                                                          None      AK186064     READY  NO ACCESS
# 4            vs_example   content-based                                                          None      KS250118     READY      ADMIN
# 5  cricket_test_example  metadata-based                                                          None      KS250118     READY      ADMIN

# %% [markdown]
# ### ⚠️ **Notice:** Metabased Vector Store Limitation
# 🚨 The Metabased Vector Store **does not currently support** `prepare_response()` and `ask()` APIs. Only `similarity_search` is supported

# %%
vs_meta.destroy()
# Out:
# Vector store cricket_test_example destroy started.
# Use the 'status()' api to check the status of the operation.

# %% [markdown]
# - **Remove/Delete Patterns**
#    - Use this functionality to remove or delete existing patterns from the vector store.

# %%
ptn.delete()
# Out:
# Pattern cricket_include deleted.

# %%
ptn2.delete()
# Out:
# Pattern cricket_exclude deleted.

# %% [markdown]
# ## 🔌 Disconnect
# - **Terminate All Active Connections**
#    - This operation terminates all active connections to the vector store database.

# %%
VSManager.disconnect()
# Out:
# Database connection closed.
