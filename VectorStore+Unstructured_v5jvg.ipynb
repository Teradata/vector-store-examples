# %% [markdown]
# <header>
#    <p  style='font-size:36px;font-family:Arial; color:#F0F0F0; background-color: #00233c; padding-left: 20pt; padding-top: 20pt;padding-bottom: 10pt; padding-right: 20pt;'>
#        Building a Vector Store from PDF Docs using Unstructured.io
#   <br>
#        <img id="teradata-logo" src="https://storage.googleapis.com/clearscape_analytics_demo_data/DEMO_Logo/teradata.svg" alt="Teradata" style="width: 125px; height: auto; margin-top: 20pt;">
#     </p>
# </header>

# %% [markdown]
# <p style="font-size:24px;font-family:Arial;color:#00233C"><b>Introduction</b></p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# This notebook demonstrates an end-to-end workflow for implementing semantic search capabilities using Teradata's vector database features. We'll transform unstructured PDF documents into searchable knowledge through the Open-Source version of Unstructured.io and leverage Teradata's powerful vector processing capabilities.
# </p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# The workflow covers four key phases: document parsing with Unstructured.io, embedding generation using HuggingFace models through LangChain, vector storage in Teradata, and finally executing semantic similarity searches Vector Distance and K-means functions.
# </p>
#
# ---
#
# <p style="font-size:24px;font-family:Arial;color:#00233C"><b>Workflow Overview</b></p>
#
# <p style="font-size:18px;font-family:Arial;color:#00233C"><b>Document Processing Pipeline</b></p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# We begin by extracting meaningful content from PDF documents using Unstructured.io's intelligent partitioning:
# </p>
#
# <ul style="font-size:16px;font-family:Arial;color:#00233C">
#   <li>Preserves document structure and layout information</li>
#   <li>Handles complex documents with mixed content types</li>
#   <li>Outputs clean, chunked text ready for embedding in a JSON file</li>
# </ul>
#
# <p style="font-size:18px;font-family:Arial;color:#00233C"><b>Embedding Generation</b></p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# Using LangChain's HuggingFace integration, we transform text chunks into high-dimensional vector embeddings:
# </p>
#
# <table style="font-size:16px;font-family:Arial;color:#00233C;border:1px solid black;">
#   <tr>
#     <th style="border:1px solid black;padding:5px;">Component</th>
#     <th style="border:1px solid black;padding:5px;">Technology</th>
#     <th style="border:1px solid black;padding:5px;">Output</th>
#   </tr>
#   <tr>
#     <td style="border:1px solid black;padding:5px;">Embedding Model</td>
#     <td style="border:1px solid black;padding:5px;">HuggingFace Sentence Transformer All MiniLM L6-v2</td>
#     <td style="border:1px solid black;padding:5px;">384-dimension vectors</td>
#   </tr>
#   <tr>
#     <td style="border:1px solid black;padding:5px;">Processing Framework</td>
#     <td style="border:1px solid black;padding:5px;">LangChain</td>
#     <td style="border:1px solid black;padding:5px;">Batch-processed embeddings</td>
#   </tr>
# </table>
#
# <p style="font-size:18px;font-family:Arial;color:#00233C"><b>Teradata Vector Integration</b></p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# The generated embeddings are stored in Teradata's optimized vector column type, enabling:
# </p>
#
# <ul style="font-size:16px;font-family:Arial;color:#00233C">
#   <li>Efficient storage of high-dimensional vectors</li>
#   <li>Native support for vector similarity operations</li>
#   <li>Seamless integration with existing SQL workflows</li>
# </ul>
#
# <p style="font-size:18px;font-family:Arial;color:#00233C"><b>Semantic Search Implementation</b></p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# We implement two complementary search approaches:
# </p>
#
# <table style="font-size:15px; font-family:Arial; color:#00233C; width:100%; border:1px solid #ddd; border-collapse:collapse;">
#   <tr>
#     <th style="padding:10px; text-align:left; border:1px solid #ddd;">Algorithm</th>
#     <th style="padding:10px; text-align:left; border:1px solid #ddd;">Implementation</th>
#     <th style="padding:10px; text-align:left; border:1px solid #ddd;">Use Case</th>
#   </tr>
#   <tr>
#     <td style="padding:10px; border:1px solid #ddd;"><b>Vector Distance</b></td>
#     <td style="padding:10px; border:1px solid #ddd;">Exact nearest neighbor search using euclidean similarity</td>
#     <td style="padding:10px; border:1px solid #ddd;">Precision-focused queries on moderate datasets</td>
#   </tr>
#   <tr>
#     <td style="padding:10px; border:1px solid #ddd;"><b>K-means Clustering</b></td>
#     <td style="padding:10px; border:1px solid #ddd;">Approximate search with cluster pruning</td>
#     <td style="padding:10px; border:1px solid #ddd;">Scalable search on large document collections</td>
#   </tr>
# </table>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# This combination allows for both precise answers and scalable performance across different dataset sizes and query requirements.
# </p>

# %% [markdown]
# <p style="font-size:20px;font-family:Arial;color:#00233C"><b>What You Will Do in This Notebook</b></p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# This notebook provides a complete workflow for processing PDF documents into searchable vector embeddings and implementing semantic search in Teradata. You'll learn how to extract meaningful content from unstructured documents, generate AI-powered embeddings, and leverage Teradata's vector processing capabilities. By the end, you'll be able to:
# </p>
#
# <div style="font-size:16px;font-family:Arial;color:#00233C">
# <ol>
# <li>
# <b>Process PDF documents</b> using Unstructured.io's partitioning function
# </li>
# <li>
# <b>Generate embeddings</b> using HuggingFace models through LangChain
# </li>
# <li>
# <b>Design optimized tables</b> for vector storage in Teradata
# </li>
# <li>
# <b>Implement search functionality</b> using both exact and approximate algorithms
# </li>
# <li>
# <b>Execute semantic queries</b> that understand content meaning rather than just keywords
# </li>
# </ol>
# </div>
#
# ---
#
# <p style="font-size:24px;font-family:Arial;color:#00233C"><b>Notebook Workflow Steps</b></p>
#
# <div style="font-size:16px;font-family:Arial;color:#00233C">
# <ol>
# <li>
# <b>Installation and import of Unstructured.io (Opensource) and Teradata libraries</b>
# <ul>
# <li>Set up the Python environment with required dependencies</li>
# <li>Document processing with Unstructured.io</li>
# <li>Embedding generation with LangChain and HuggingFace</li>
# <li>Teradata GenAI libraries</li>
# </ul>
# </li>
#
# <li>
# <b>Unstructured.io partitioning into JSON</b>
# <ul>
# <li>Load and parse PDF documents</li>
# <li>Extract structured elements (titles, paragraphs, tables)</li>
# <li>Output clean, organized JSON content</li>
# </ul>
# </li>
#
# <li>
# <b>Generate embeddings</b>
# <ul>
# <li>Load the JSON file</li>
# <li>Configure HuggingFace sentence transformer model</li>
# <li>Process each element in the JSON file into vector embeddings</li>
# <li>Add the embeddings to that element as an "embeddings" field and save the new JSON file</li>
# <li>Convert all of the metadata in the JSON file into a CSV flat file with only the text and embeddings field</li>
# </ul>
# </li>
#
# <li>
# <b>Connect to Vantage</b>
# <ul>
# <li>Establish secure connection to Teradata</li>
# <li>Verify vector processing capabilities</li>
# </ul>
# </li>
#
# <li>
# <b>Import Embeddings to a Table</b>
# <ul>
# <li>Read external embeddings and define the clean fucntion</li>
# <li>Create the table</li>
# <li>Insert embeddings into the table</li>
# </ul>
# </li>
#
# <li>
# <b>Normalize the Embeddings</b>
# <ul>
# <li>Apply vector normalization for accurate similarity</li>
# <li>Verify data integrity</li>
# <li>VDrop the table (optional)</li>
# </ul>
# </li>
#
# <li>
# <b>Similarity Search algorithms</b>
# <ul>
# <li>Understand Teradata's vector search options</li>
# <li>Vector distance table example</li>
# <li>K-means table example</li>
# </ul>
# </li>
#
# <li>
# <b>Vector Distance Semantic Similarity Search</b>
# <ul>
# <li>Embed the query with the same model used for the JSON file</li>
# <li>Insert query into a table</li>
# <li>Run a Vector Distance on the query and the embeddings</li>
# <li>Show the text results of the vector distance search</li>
# </ul>
# </li>
# </ol>
# </div>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <b style = 'font-size:30px;font-family:Arial;color:#00233C'>1. Installation and import of libraries needed </b>

# %% [markdown]
# <b style = 'font-size:18px;font-family:Arial;color:#00233C'>Teradata libraries</b>

# %%
# %pip install teradataml-20.0.0.5-py3-none-any.whl
# %pip install teradatagenai-20.0.0.1-py3-none-any.whl
# Out:
# Processing c:\users\jv255027\downloads\vector store\vectorstore-aprildrop\teradataml-20.0.0.5-py3-none-any.whl
# Requirement already satisfied: teradatasql>=20.0.0.19 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml==20.0.0.5) (20.0.0.29)
# Requirement already satisfied: teradatasqlalchemy>=20.0.0.4 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml==20.0.0.5) (20.0.0.4)
# Requirement already satisfied: pandas>=0.22 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml==20.0.0.5) (2.2.3)
# Requirement already satisfied: psutil in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from teradataml==20.0.0.5) (6.0.0)
# Requirement already satisfied: requests>=2.25.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml==20.0.0.5) (2.32.3)
# Requirement already satisfied: scikit-learn>=0.24.2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml==20.0.0.5) (1.6.1)
# Requirement already satisfied: IPython>=8.10.0 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from teradataml==20.0.0.5) (8.26.0)
# Requirement already satisfied: imbalanced-learn>=0.8.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml==20.0.0.5) (0.13.0)
# Requirement already satisfied: pyjwt>=2.8.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml==20.0.0.5) (2.10.1)
# Requirement already satisfied: cryptography>=42.0.5 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml==20.0.0.5) (44.0.2)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml==20.0.0.5) (2.0.40)
# Requirement already satisfied: lightgbm>=3.3.3 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml==20.0.0.5) (4.6.0)
# Requirement already satisfied: python-dotenv in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml==20.0.0.5) (1.1.0)
# Requirement already satisfied: teradatamlwidgets>=20.0.0.5 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml==20.0.0.5) (20.0.0.5)
# Requirement already satisfied: cffi>=1.12 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from cryptography>=42.0.5->teradataml==20.0.0.5) (1.17.1)
# Requirement already satisfied: numpy<3,>=1.24.3 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from imbalanced-learn>=0.8.0->teradataml==20.0.0.5) (1.26.4)
# Requirement already satisfied: scipy<2,>=1.10.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from imbalanced-learn>=0.8.0->teradataml==20.0.0.5) (1.15.2)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from imbalanced-learn>=0.8.0->teradataml==20.0.0.5) (0.1.3)
# Requirement already satisfied: joblib<2,>=1.1.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from imbalanced-learn>=0.8.0->teradataml==20.0.0.5) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from imbalanced-learn>=0.8.0->teradataml==20.0.0.5) (3.6.0)
# Requirement already satisfied: decorator in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from IPython>=8.10.0->teradataml==20.0.0.5) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from IPython>=8.10.0->teradataml==20.0.0.5) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from IPython>=8.10.0->teradataml==20.0.0.5) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from IPython>=8.10.0->teradataml==20.0.0.5) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from IPython>=8.10.0->teradataml==20.0.0.5) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from IPython>=8.10.0->teradataml==20.0.0.5) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from IPython>=8.10.0->teradataml==20.0.0.5) (5.14.3)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from IPython>=8.10.0->teradataml==20.0.0.5) (4.12.2)
# Requirement already satisfied: colorama in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from IPython>=8.10.0->teradataml==20.0.0.5) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from pandas>=0.22->teradataml==20.0.0.5) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from pandas>=0.22->teradataml==20.0.0.5) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from pandas>=0.22->teradataml==20.0.0.5) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from requests>=2.25.1->teradataml==20.0.0.5) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from requests>=2.25.1->teradataml==20.0.0.5) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from requests>=2.25.1->teradataml==20.0.0.5) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from requests>=2.25.1->teradataml==20.0.0.5) (2025.1.31)
# Requirement already satisfied: greenlet>=1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from sqlalchemy>=2.0->teradataml==20.0.0.5) (3.2.1)
# Requirement already satisfied: ipywidgets>=8.1.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (8.1.6)
# Requirement already satisfied: nbconvert in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (7.16.6)
# Requirement already satisfied: nbformat in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (5.10.4)
# Requirement already satisfied: pycryptodome in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradatasql>=20.0.0.19->teradataml==20.0.0.5) (3.22.0)
# Requirement already satisfied: pycparser in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from cffi>=1.12->cryptography>=42.0.5->teradataml==20.0.0.5) (2.22)
# Requirement already satisfied: comm>=0.1.3 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from ipywidgets>=8.1.1->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from ipywidgets>=8.1.1->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.14 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from ipywidgets>=8.1.1->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (3.0.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from jedi>=0.16->IPython>=8.10.0->teradataml==20.0.0.5) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython>=8.10.0->teradataml==20.0.0.5) (0.2.13)
# Requirement already satisfied: six>=1.5 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas>=0.22->teradataml==20.0.0.5) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (3.1.6)
# Requirement already satisfied: jupyter-core>=4.7 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (5.7.2)
# Requirement already satisfied: jupyterlab-pygments in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (0.10.2)
# Requirement already satisfied: packaging in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (24.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nbformat->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nbformat->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (4.23.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from stack-data->IPython>=8.10.0->teradataml==20.0.0.5) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from stack-data->IPython>=8.10.0->teradataml==20.0.0.5) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from stack-data->IPython>=8.10.0->teradataml==20.0.0.5) (0.2.3)
# Requirement already satisfied: webencodings in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from jsonschema>=2.6->nbformat->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from jsonschema>=2.6->nbformat->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from jsonschema>=2.6->nbformat->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from jsonschema>=2.6->nbformat->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (0.24.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from jupyter-core>=4.7->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (4.2.2)
# Requirement already satisfied: pywin32>=300 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from jupyter-core>=4.7->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (306)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from nbclient>=0.5.0->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (8.6.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from beautifulsoup4->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (2.7)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (26.1.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml==20.0.0.5) (6.4.1)
# teradataml is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# Note: you may need to restart the kernel to use updated packages.
# Processing c:\users\jv255027\downloads\vector store\vectorstore-aprildrop\teradatagenai-20.0.0.1-py3-none-any.whl
# Requirement already satisfied: teradataml>=20.00.00.01 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradatagenai==20.0.0.1) (20.0.0.5)
# Requirement already satisfied: torch>=2.5.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradatagenai==20.0.0.1) (2.7.0)
# Requirement already satisfied: transformers>=4.46.2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradatagenai==20.0.0.1) (4.51.3)
# Requirement already satisfied: wikipedia>=1.4.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradatagenai==20.0.0.1) (1.4.0)
# Requirement already satisfied: boto3>=1.34.78 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradatagenai==20.0.0.1) (1.38.1)
# Requirement already satisfied: botocore>=1.34.78 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradatagenai==20.0.0.1) (1.38.1)
# Requirement already satisfied: openai>=0.28 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradatagenai==20.0.0.1) (1.76.0)
# Requirement already satisfied: langchain-community>=0.2.5 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradatagenai==20.0.0.1) (0.3.22)
# Requirement already satisfied: vertexai>=1.49.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradatagenai==20.0.0.1) (1.71.1)
# Requirement already satisfied: langchain-aws>=0.1.6 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradatagenai==20.0.0.1) (0.2.21)
# Requirement already satisfied: aiohttp>=3.9.4 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradatagenai==20.0.0.1) (3.11.18)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from aiohttp>=3.9.4->teradatagenai==20.0.0.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from aiohttp>=3.9.4->teradatagenai==20.0.0.1) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from aiohttp>=3.9.4->teradatagenai==20.0.0.1) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from aiohttp>=3.9.4->teradatagenai==20.0.0.1) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from aiohttp>=3.9.4->teradatagenai==20.0.0.1) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from aiohttp>=3.9.4->teradatagenai==20.0.0.1) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from aiohttp>=3.9.4->teradatagenai==20.0.0.1) (1.20.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from boto3>=1.34.78->teradatagenai==20.0.0.1) (1.0.1)
# Requirement already satisfied: s3transfer<0.13.0,>=0.12.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from boto3>=1.34.78->teradatagenai==20.0.0.1) (0.12.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from botocore>=1.34.78->teradatagenai==20.0.0.1) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from botocore>=1.34.78->teradatagenai==20.0.0.1) (2.4.0)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.53 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain-aws>=0.1.6->teradatagenai==20.0.0.1) (0.3.60)
# Requirement already satisfied: numpy<2,>=1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain-aws>=0.1.6->teradatagenai==20.0.0.1) (1.26.4)
# Requirement already satisfied: pydantic<3,>=2.10.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain-aws>=0.1.6->teradatagenai==20.0.0.1) (2.11.3)
# Requirement already satisfied: langchain<1.0.0,>=0.3.24 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain-community>=0.2.5->teradatagenai==20.0.0.1) (0.3.24)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain-community>=0.2.5->teradatagenai==20.0.0.1) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain-community>=0.2.5->teradatagenai==20.0.0.1) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain-community>=0.2.5->teradatagenai==20.0.0.1) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain-community>=0.2.5->teradatagenai==20.0.0.1) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain-community>=0.2.5->teradatagenai==20.0.0.1) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain-community>=0.2.5->teradatagenai==20.0.0.1) (2.9.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain-community>=0.2.5->teradatagenai==20.0.0.1) (0.3.33)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain-community>=0.2.5->teradatagenai==20.0.0.1) (0.4.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from openai>=0.28->teradatagenai==20.0.0.1) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from openai>=0.28->teradatagenai==20.0.0.1) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from openai>=0.28->teradatagenai==20.0.0.1) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from openai>=0.28->teradatagenai==20.0.0.1) (0.9.0)
# Requirement already satisfied: sniffio in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from openai>=0.28->teradatagenai==20.0.0.1) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from openai>=0.28->teradatagenai==20.0.0.1) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from openai>=0.28->teradatagenai==20.0.0.1) (4.12.2)
# Requirement already satisfied: teradatasql>=20.0.0.19 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (20.0.0.29)
# Requirement already satisfied: teradatasqlalchemy>=20.0.0.4 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (20.0.0.4)
# Requirement already satisfied: pandas>=0.22 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (2.2.3)
# Requirement already satisfied: psutil in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (6.0.0)
# Requirement already satisfied: scikit-learn>=0.24.2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (1.6.1)
# Requirement already satisfied: IPython>=8.10.0 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (8.26.0)
# Requirement already satisfied: imbalanced-learn>=0.8.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (0.13.0)
# Requirement already satisfied: pyjwt>=2.8.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (2.10.1)
# Requirement already satisfied: cryptography>=42.0.5 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (44.0.2)
# Requirement already satisfied: lightgbm>=3.3.3 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (4.6.0)
# Requirement already satisfied: python-dotenv in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (1.1.0)
# Requirement already satisfied: teradatamlwidgets>=20.0.0.5 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (20.0.0.5)
# Requirement already satisfied: filelock in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from torch>=2.5.1->teradatagenai==20.0.0.1) (3.18.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from torch>=2.5.1->teradatagenai==20.0.0.1) (1.13.3)
# Requirement already satisfied: networkx in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from torch>=2.5.1->teradatagenai==20.0.0.1) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from torch>=2.5.1->teradatagenai==20.0.0.1) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from torch>=2.5.1->teradatagenai==20.0.0.1) (2025.3.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from transformers>=4.46.2->teradatagenai==20.0.0.1) (0.30.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from transformers>=4.46.2->teradatagenai==20.0.0.1) (24.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from transformers>=4.46.2->teradatagenai==20.0.0.1) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from transformers>=4.46.2->teradatagenai==20.0.0.1) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from transformers>=4.46.2->teradatagenai==20.0.0.1) (0.5.3)
# Requirement already satisfied: google-cloud-aiplatform==1.71.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (1.71.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (2.25.0rc0)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (2.39.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (5.29.4)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (2.19.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (3.31.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (1.14.2)
# Requirement already satisfied: shapely<3.0.0dev in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (2.1.0)
# Requirement already satisfied: docstring-parser<1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (0.16)
# Requirement already satisfied: beautifulsoup4 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from wikipedia>=1.4.0->teradatagenai==20.0.0.1) (4.13.4)
# Requirement already satisfied: idna>=2.8 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from anyio<5,>=3.5.0->openai>=0.28->teradatagenai==20.0.0.1) (3.10)
# Requirement already satisfied: cffi>=1.12 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from cryptography>=42.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (1.17.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community>=0.2.5->teradatagenai==20.0.0.1) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community>=0.2.5->teradatagenai==20.0.0.1) (0.9.0)
# Requirement already satisfied: certifi in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from httpx<1,>=0.23.0->openai>=0.28->teradatagenai==20.0.0.1) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from httpx<1,>=0.23.0->openai>=0.28->teradatagenai==20.0.0.1) (1.0.8)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=0.28->teradatagenai==20.0.0.1) (0.14.0)
# Requirement already satisfied: scipy<2,>=1.10.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from imbalanced-learn>=0.8.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (1.15.2)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from imbalanced-learn>=0.8.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (0.1.3)
# Requirement already satisfied: joblib<2,>=1.1.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from imbalanced-learn>=0.8.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from imbalanced-learn>=0.8.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (3.6.0)
# Requirement already satisfied: decorator in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from IPython>=8.10.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from IPython>=8.10.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from IPython>=8.10.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from IPython>=8.10.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from IPython>=8.10.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from IPython>=8.10.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from IPython>=8.10.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (5.14.3)
# Requirement already satisfied: colorama in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from IPython>=8.10.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (0.4.6)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain<1.0.0,>=0.3.24->langchain-community>=0.2.5->teradatagenai==20.0.0.1) (0.3.8)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain-core<0.4.0,>=0.3.53->langchain-aws>=0.1.6->teradatagenai==20.0.0.1) (1.33)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community>=0.2.5->teradatagenai==20.0.0.1) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community>=0.2.5->teradatagenai==20.0.0.1) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community>=0.2.5->teradatagenai==20.0.0.1) (0.23.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from pandas>=0.22->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from pandas>=0.22->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from pydantic<3,>=2.10.0->langchain-aws>=0.1.6->teradatagenai==20.0.0.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from pydantic<3,>=2.10.0->langchain-aws>=0.1.6->teradatagenai==20.0.0.1) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from pydantic<3,>=2.10.0->langchain-aws>=0.1.6->teradatagenai==20.0.0.1) (0.4.0)
# Requirement already satisfied: six>=1.5 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from python-dateutil<3.0.0,>=2.1->botocore>=1.34.78->teradatagenai==20.0.0.1) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from requests<3,>=2->langchain-community>=0.2.5->teradatagenai==20.0.0.1) (3.4.1)
# Requirement already satisfied: greenlet>=1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community>=0.2.5->teradatagenai==20.0.0.1) (3.2.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from sympy>=1.13.3->torch>=2.5.1->teradatagenai==20.0.0.1) (1.3.0)
# Requirement already satisfied: ipywidgets>=8.1.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (8.1.6)
# Requirement already satisfied: nbconvert in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (7.16.6)
# Requirement already satisfied: nbformat in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (5.10.4)
# Requirement already satisfied: pycryptodome in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from teradatasql>=20.0.0.19->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (3.22.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from beautifulsoup4->wikipedia>=1.4.0->teradatagenai==20.0.0.1) (2.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from jinja2->torch>=2.5.1->teradatagenai==20.0.0.1) (3.0.2)
# Requirement already satisfied: pycparser in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from cffi>=1.12->cryptography>=42.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (2.22)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (1.70.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (1.71.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (1.71.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (4.9.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (2.4.3)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (2.7.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (0.14.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (1.7.1)
# Requirement already satisfied: comm>=0.1.3 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from ipywidgets>=8.1.1->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from ipywidgets>=8.1.1->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.14 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from ipywidgets>=8.1.1->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (3.0.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from jedi>=0.16->IPython>=8.10.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (0.8.4)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.53->langchain-aws>=0.1.6->teradatagenai==20.0.0.1) (3.0.0)
# Requirement already satisfied: wcwidth in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython>=8.10.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (0.2.13)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community>=0.2.5->teradatagenai==20.0.0.1) (1.1.0)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (0.7.1)
# Requirement already satisfied: jupyter-core>=4.7 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (5.7.2)
# Requirement already satisfied: jupyterlab-pygments in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nbconvert->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nbformat->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nbformat->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (4.23.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from stack-data->IPython>=8.10.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from stack-data->IPython>=8.10.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from stack-data->IPython>=8.10.0->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (0.2.3)
# Requirement already satisfied: webencodings in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (1.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from jsonschema>=2.6->nbformat->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from jsonschema>=2.6->nbformat->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from jsonschema>=2.6->nbformat->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (0.24.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from jupyter-core>=4.7->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (4.2.2)
# Requirement already satisfied: pywin32>=300 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from jupyter-core>=4.7->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (306)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from nbclient>=0.5.0->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (8.6.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai>=1.49.0->teradatagenai==20.0.0.1) (0.6.1)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (26.1.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert->teradatamlwidgets>=20.0.0.5->teradataml>=20.00.00.01->teradatagenai==20.0.0.1) (6.4.1)
# teradatagenai is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# Note: you may need to restart the kernel to use updated packages.
# WARNING: google-cloud-aiplatform 1.71.1 does not provide the extra 'all'

# %% [markdown]
# <b style = 'font-size:18px;font-family:Arial;color:#00233C'>Unstructured.io (Open Source) and Dependencies</b>

# %% [markdown]
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# For PDF processing with Unstructured.io, you may need to configure system dependencies:
# </p>
#
# <div style="font-size:16px;font-family:Arial;color:#00233C;background:#f5f5f5;padding:12px;border-radius:5px;border-left:4px solid #00233C">
# <b>Required Components:</b>
# <ul>
# <li><b>Poppler</b> - PDF rendering library (for text extraction)</li>
# <li><b>Tesseract</b> - OCR engine (for image-based PDFs)</li>
# </ul>
# </div>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C;margin-top:12px">
# <b>Windows Configuration:</b><br>
# Add these paths to your system environment variables:
# </p>
#
# <pre style="font-size:14px;font-family:Consolas;background:#00233C;color:#fff;padding:12px;border-radius:5px">
# # Typical installation paths
# C:\Program Files\poppler-xx\bin
# C:\Program Files\Tesseract-OCR
# </pre>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# <b>Verification:</b> After adding paths, restart your Python environment.
# </p>
#
#
# <div style="font-size:15px;font-family:Arial;color:#00233C;background:#fff8e6;padding:12px;border-radius:5px;border:1px solid #ffd700">
# <b>Note:</b> The exact path may vary based on your installation method (conda, standalone installer, etc.)
# </div>

# %%
# %pip install unstructured
# %pip install "unstructured[pdf]"

# %pip install libmagic 
# %pip install poppler 
# %pip install tesseract
# Out:
# Requirement already satisfied: unstructured in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (0.17.2)
# Requirement already satisfied: chardet in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured) (5.2.0)
# Requirement already satisfied: filetype in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: python-magic in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: lxml in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured) (5.4.0)
# Requirement already satisfied: nltk in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured) (3.9.1)
# Requirement already satisfied: requests in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured) (4.13.4)
# Requirement already satisfied: emoji in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured) (2.14.1)
# Requirement already satisfied: dataclasses-json in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured) (0.6.7)
# Requirement already satisfied: python-iso639 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured) (2025.2.18)
# Requirement already satisfied: langdetect in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: numpy in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured) (1.26.4)
# Requirement already satisfied: rapidfuzz in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured) (3.13.0)
# Requirement already satisfied: backoff in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: typing-extensions in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from unstructured) (4.12.2)
# Requirement already satisfied: unstructured-client in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured) (0.35.0)
# Requirement already satisfied: wrapt in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured) (1.17.2)
# Requirement already satisfied: tqdm in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured) (4.67.1)
# Requirement already satisfied: psutil in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from unstructured) (6.0.0)
# Requirement already satisfied: python-oxmsg in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured) (0.0.2)
# Requirement already satisfied: html5lib in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from beautifulsoup4->unstructured) (2.7)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from dataclasses-json->unstructured) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: six>=1.9 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from html5lib->unstructured) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from html5lib->unstructured) (0.5.1)
# Requirement already satisfied: click in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nltk->unstructured) (8.2.0)
# Requirement already satisfied: joblib in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nltk->unstructured) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nltk->unstructured) (2024.11.6)
# Requirement already satisfied: olefile in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from python-oxmsg->unstructured) (0.47)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from requests->unstructured) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from requests->unstructured) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from requests->unstructured) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from requests->unstructured) (2025.1.31)
# Requirement already satisfied: colorama in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from tqdm->unstructured) (0.4.6)
# Requirement already satisfied: aiofiles>=24.1.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured-client->unstructured) (24.1.0)
# Requirement already satisfied: cryptography>=3.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured-client->unstructured) (44.0.2)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured-client->unstructured) (0.28.1)
# Requirement already satisfied: nest-asyncio>=1.6.0 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from unstructured-client->unstructured) (1.6.0)
# Requirement already satisfied: pydantic>=2.11.2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured-client->unstructured) (2.11.3)
# Requirement already satisfied: pypdf>=4.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured-client->unstructured) (5.5.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from cryptography>=3.1->unstructured-client->unstructured) (1.17.1)
# Requirement already satisfied: anyio in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.0.8)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client->unstructured) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->unstructured) (24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.4.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.1.0)
# Requirement already satisfied: pycparser in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from cffi>=1.12->cryptography>=3.1->unstructured-client->unstructured) (2.22)
# Requirement already satisfied: sniffio>=1.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: unstructured[pdf] in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (0.17.2)
# Requirement already satisfied: chardet in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured[pdf]) (5.2.0)
# Requirement already satisfied: filetype in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured[pdf]) (1.2.0)
# Requirement already satisfied: python-magic in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured[pdf]) (0.4.27)
# Requirement already satisfied: lxml in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured[pdf]) (5.4.0)
# Requirement already satisfied: nltk in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured[pdf]) (3.9.1)
# Requirement already satisfied: requests in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured[pdf]) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured[pdf]) (4.13.4)
# Requirement already satisfied: emoji in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured[pdf]) (2.14.1)
# Requirement already satisfied: dataclasses-json in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured[pdf]) (0.6.7)
# Requirement already satisfied: python-iso639 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured[pdf]) (2025.2.18)
# Requirement already satisfied: langdetect in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured[pdf]) (1.0.9)
# Requirement already satisfied: numpy in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured[pdf]) (1.26.4)
# Requirement already satisfied: rapidfuzz in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured[pdf]) (3.13.0)
# Requirement already satisfied: backoff in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured[pdf]) (2.2.1)
# Requirement already satisfied: typing-extensions in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from unstructured[pdf]) (4.12.2)
# Requirement already satisfied: unstructured-client in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured[pdf]) (0.35.0)
# Requirement already satisfied: wrapt in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured[pdf]) (1.17.2)
# Requirement already satisfied: tqdm in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured[pdf]) (4.67.1)
# Requirement already satisfied: psutil in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from unstructured[pdf]) (6.0.0)
# Requirement already satisfied: python-oxmsg in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured[pdf]) (0.0.2)
# Requirement already satisfied: html5lib in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured[pdf]) (1.1)
# Requirement already satisfied: onnx>=1.17.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured[pdf]) (1.18.0)
# Requirement already satisfied: onnxruntime>=1.19.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured[pdf]) (1.22.0)
# Requirement already satisfied: pdf2image in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured[pdf]) (1.17.0)
# Requirement already satisfied: pdfminer.six in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured[pdf]) (20250506)
# Requirement already satisfied: pikepdf in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured[pdf]) (9.7.0)
# Requirement already satisfied: pi-heif in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured[pdf]) (0.22.0)
# Requirement already satisfied: pypdf in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured[pdf]) (5.5.0)
# Requirement already satisfied: google-cloud-vision in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured[pdf]) (3.10.1)
# Requirement already satisfied: effdet in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured[pdf]) (0.4.1)
# Requirement already satisfied: unstructured-inference>=0.8.10 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured[pdf]) (0.8.10)
# Requirement already satisfied: unstructured.pytesseract>=0.3.12 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured[pdf]) (0.3.15)
# Requirement already satisfied: protobuf>=4.25.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from onnx>=1.17.0->unstructured[pdf]) (5.29.4)
# Requirement already satisfied: coloredlogs in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from onnxruntime>=1.19.0->unstructured[pdf]) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from onnxruntime>=1.19.0->unstructured[pdf]) (25.2.10)
# Requirement already satisfied: packaging in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from onnxruntime>=1.19.0->unstructured[pdf]) (24.2)
# Requirement already satisfied: sympy in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from onnxruntime>=1.19.0->unstructured[pdf]) (1.13.3)
# Requirement already satisfied: python-multipart in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured-inference>=0.8.10->unstructured[pdf]) (0.0.20)
# Requirement already satisfied: huggingface-hub in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured-inference>=0.8.10->unstructured[pdf]) (0.30.2)
# Requirement already satisfied: opencv-python!=4.7.0.68 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured-inference>=0.8.10->unstructured[pdf]) (4.11.0.86)
# Requirement already satisfied: matplotlib in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured-inference>=0.8.10->unstructured[pdf]) (3.10.3)
# Requirement already satisfied: torch in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured-inference>=0.8.10->unstructured[pdf]) (2.7.0)
# Requirement already satisfied: timm in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured-inference>=0.8.10->unstructured[pdf]) (1.0.15)
# Requirement already satisfied: transformers>=4.25.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured-inference>=0.8.10->unstructured[pdf]) (4.51.3)
# Requirement already satisfied: pandas in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured-inference>=0.8.10->unstructured[pdf]) (2.2.3)
# Requirement already satisfied: scipy in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured-inference>=0.8.10->unstructured[pdf]) (1.15.2)
# Requirement already satisfied: pypdfium2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured-inference>=0.8.10->unstructured[pdf]) (4.30.1)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured.pytesseract>=0.3.12->unstructured[pdf]) (11.2.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from beautifulsoup4->unstructured[pdf]) (2.7)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from dataclasses-json->unstructured[pdf]) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from dataclasses-json->unstructured[pdf]) (0.9.0)
# Requirement already satisfied: torchvision in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from effdet->unstructured[pdf]) (0.22.0)
# Requirement already satisfied: pycocotools>=2.0.2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from effdet->unstructured[pdf]) (2.0.8)
# Requirement already satisfied: omegaconf>=2.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from effdet->unstructured[pdf]) (2.3.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[pdf]) (2.25.0rc0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from google-cloud-vision->unstructured[pdf]) (2.39.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from google-cloud-vision->unstructured[pdf]) (1.26.1)
# Requirement already satisfied: six>=1.9 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from html5lib->unstructured[pdf]) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from html5lib->unstructured[pdf]) (0.5.1)
# Requirement already satisfied: click in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nltk->unstructured[pdf]) (8.2.0)
# Requirement already satisfied: joblib in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nltk->unstructured[pdf]) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from nltk->unstructured[pdf]) (2024.11.6)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from pdfminer.six->unstructured[pdf]) (3.4.1)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from pdfminer.six->unstructured[pdf]) (44.0.2)
# Requirement already satisfied: Deprecated in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from pikepdf->unstructured[pdf]) (1.2.18)
# Requirement already satisfied: olefile in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from python-oxmsg->unstructured[pdf]) (0.47)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from requests->unstructured[pdf]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from requests->unstructured[pdf]) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from requests->unstructured[pdf]) (2025.1.31)
# Requirement already satisfied: colorama in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from tqdm->unstructured[pdf]) (0.4.6)
# Requirement already satisfied: aiofiles>=24.1.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured-client->unstructured[pdf]) (24.1.0)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured-client->unstructured[pdf]) (0.28.1)
# Requirement already satisfied: nest-asyncio>=1.6.0 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from unstructured-client->unstructured[pdf]) (1.6.0)
# Requirement already satisfied: pydantic>=2.11.2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured-client->unstructured[pdf]) (2.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from unstructured-client->unstructured[pdf]) (1.0.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[pdf]) (1.17.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[pdf]) (1.70.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[pdf]) (1.71.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[pdf]) (1.71.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[pdf]) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[pdf]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[pdf]) (4.9.1)
# Requirement already satisfied: anyio in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured[pdf]) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured[pdf]) (1.0.8)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client->unstructured[pdf]) (0.14.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from omegaconf>=2.0->effdet->unstructured[pdf]) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from omegaconf>=2.0->effdet->unstructured[pdf]) (6.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from matplotlib->unstructured-inference>=0.8.10->unstructured[pdf]) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from matplotlib->unstructured-inference>=0.8.10->unstructured[pdf]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from matplotlib->unstructured-inference>=0.8.10->unstructured[pdf]) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from matplotlib->unstructured-inference>=0.8.10->unstructured[pdf]) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from matplotlib->unstructured-inference>=0.8.10->unstructured[pdf]) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from matplotlib->unstructured-inference>=0.8.10->unstructured[pdf]) (2.9.0.post0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured[pdf]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured[pdf]) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured[pdf]) (0.4.0)
# Requirement already satisfied: safetensors in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from timm->unstructured-inference>=0.8.10->unstructured[pdf]) (0.5.3)
# Requirement already satisfied: filelock in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from torch->unstructured-inference>=0.8.10->unstructured[pdf]) (3.18.0)
# Requirement already satisfied: networkx in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from torch->unstructured-inference>=0.8.10->unstructured[pdf]) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from torch->unstructured-inference>=0.8.10->unstructured[pdf]) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from torch->unstructured-inference>=0.8.10->unstructured[pdf]) (2025.3.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from sympy->onnxruntime>=1.19.0->unstructured[pdf]) (1.3.0)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from transformers>=4.25.1->unstructured-inference>=0.8.10->unstructured[pdf]) (0.21.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured[pdf]) (1.1.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from coloredlogs->onnxruntime>=1.19.0->unstructured[pdf]) (10.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from pandas->unstructured-inference>=0.8.10->unstructured[pdf]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from pandas->unstructured-inference>=0.8.10->unstructured[pdf]) (2025.2)
# Requirement already satisfied: pycparser in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->unstructured[pdf]) (2.22)
# Requirement already satisfied: pyreadline3 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.19.0->unstructured[pdf]) (3.5.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[pdf]) (0.6.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured[pdf]) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from jinja2->torch->unstructured-inference>=0.8.10->unstructured[pdf]) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: libmagic in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (1.0)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement poppler (from versions: none)
# ERROR: No matching distribution found for poppler
# Requirement already satisfied: tesseract in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (0.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <b style = 'font-size:18px;font-family:Arial;color:#00233C'>Langchain Huggingface models to generate embeddings</b>

# %%
# %pip install langchain
# %pip install langchain-huggingface
# Out:
# Requirement already satisfied: langchain in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (0.3.24)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.55 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain) (0.3.60)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain) (0.3.33)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain) (2.11.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from requests<3,>=2->langchain) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from requests<3,>=2->langchain) (2025.1.31)
# Requirement already satisfied: greenlet>=1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.1)
# Requirement already satisfied: anyio in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.8)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.55->langchain) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain-huggingface in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (0.2.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.59 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain-huggingface) (0.3.60)
# Requirement already satisfied: tokenizers>=0.19.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain-huggingface) (0.21.1)
# Requirement already satisfied: transformers>=4.39.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain-huggingface) (4.51.3)
# Requirement already satisfied: sentence-transformers>=2.6.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain-huggingface) (4.1.0)
# Requirement already satisfied: huggingface-hub>=0.30.2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain-huggingface) (0.30.2)
# Requirement already satisfied: filelock in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (6.0.2)
# Requirement already satisfied: requests in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (4.12.2)
# Requirement already satisfied: langsmith<0.4,>=0.1.126 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (0.3.33)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (1.33)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (2.11.3)
# Requirement already satisfied: torch>=1.11.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (2.7.0)
# Requirement already satisfied: scikit-learn in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (1.6.1)
# Requirement already satisfied: scipy in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (1.15.2)
# Requirement already satisfied: Pillow in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (11.2.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from transformers>=4.39.0->langchain-huggingface) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from transformers>=4.39.0->langchain-huggingface) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from transformers>=4.39.0->langchain-huggingface) (0.5.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from requests->huggingface-hub>=0.30.2->langchain-huggingface) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from requests->huggingface-hub>=0.30.2->langchain-huggingface) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from requests->huggingface-hub>=0.30.2->langchain-huggingface) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from requests->huggingface-hub>=0.30.2->langchain-huggingface) (2025.1.31)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (1.13.3)
# Requirement already satisfied: networkx in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (3.1.6)
# Requirement already satisfied: colorama in c:\users\jv255027\appdata\roaming\python\python311\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.30.2->langchain-huggingface) (0.4.6)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface) (3.6.0)
# Requirement already satisfied: anyio in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (1.0.8)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (0.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (3.0.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\jv255027\appdata\local\miniforge3\envs\vsenv311\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <b style = 'font-size:18px;font-family:Arial;color:#00233C'>Import necessary modules</b>

# %%
# Unstructured libraries
from unstructured.partition.image import partition_image
from unstructured.partition.pdf import partition_pdf

# For the Embeddigns
import sys
from langchain_huggingface.embeddings import HuggingFaceEmbeddings
import pandas as pd
import json

# Teradata Vector Store libraries
from getpass import getpass
from teradatagenai import VSManager, VectorStore, VSPattern, VSApi
from teradataml import create_context, set_auth_token, execute_sql, display, DataFrame
display.max_rows = 100000

import numpy as np
import re

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <b style = 'font-size:30px;font-family:Arial;color:#00233C'>2. Unstructured.io Partitioning into JSON </b>

# %% [markdown]
# ### 🔮 Using Unstructured.io Opensource.
#
# To extract meaningful content from unstructured documents, follow these steps:
#
# 1. **Use the partition function**
#    - First, we especified the path of the PDF.
#    - And then choose the partition strategy

# %%
pdfpath = r"DensePassageRetrieval.pdf"

# Partition the PDF document
elements = partition_pdf(
    filename=pdfpath,                  # mandatory
    strategy="hi_res",                                     # mandatory to use ``hi_res`` strategy
    extract_images_in_pdf=True,                            # mandatory to set as ``True``          
    extract_image_block_to_payload=False,                  # optional
    )

# %% [markdown]
# 2. **Convert the the list of returned elements into a list of dictionaries.**
#    - This saves the file locally.

# %%
element_dicts = [element.to_dict() for element in elements]

# save the list locally:
file = r"UnstructuredDemoJSON.json"
with open(file, "w") as file:
    json.dump(element_dicts, file, indent=2)

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <b style = 'font-size:30px;font-family:Arial;color:#00233C'>3. Generate Embeddings </b>

# %% [markdown]
# ### 🧩 Adding embeddings to the JSON file.
#
# 1. **Load the JSON file and add embeddings to each element.**
#    - Process each element in the JSON file..
#    - Save the updated JSON back into the original file.

# %%
if __name__ == "__main__":
    embeddings = HuggingFaceEmbeddings(
        model_name="sentence-transformers/all-MiniLM-L6-v2"
    )
    
    # Get the JSON file's path.
    if len(sys.argv) < 2:
        print("Error: Specify the path to the input JSON file.")
        print("For example, 'python embeddings.py myfile.json'")
        sys.exit(1)

    file_path = r"UnstructuredDemoJSON.json"
    
    try:
        # Get the JSON file's contents.
        with open(file_path, 'r') as file:
            file_elements = json.load(file)

        for element in file_elements:
            # Get the element's "text" field.
            text = element["text"]
            # Generate the embeddings for that "text" field.
            query_result = embeddings.embed_query(text)
            # Add the embeddings to that element as an "embeddings" field.
            element["embeddings"] = query_result


        # Save the updated JSON back into the original file.
        with open(file_path, 'w') as file:
            json.dump(file_elements, file, indent=2)

        print(f"Done! Updated JSON saved to '{file_path}'.")

    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
    except IOError:
        print(f"Error: Unable to access file '{file_path}'.")
# Out:
# Done! Updated JSON saved to 'UnstructuredDemoJSON.json'.

# %% [markdown]
# 2. **Convert all of the metadata in the JSON file into a CSV flat file.**
#
# <div style="font-size:15px;font-family:Arial;color:#00233C;background:#fff8e6;padding:12px;border-radius:5px;border:1px solid #ffd700">
# <b>Note:</b> We can save all of the metadata (first cell), but for this notebook we will only convert the text and the embeddings field (second cell).
# </div>

# %%
def flatten_json(item):
    """Flatten a nested JSON object."""
    flattened = {}
    for key, value in item.items():
        if isinstance(value, dict):
            # Recursively flatten nested dictionaries
            for sub_key, sub_value in flatten_json(value).items():
                flattened[f"{key}.{sub_key}"] = sub_value
        elif isinstance(value, list):
            # Convert lists to comma-separated strings
            flattened[key] = ",".join(map(str, value))
        else:
            flattened[key] = value
    return flattened

def process_json_to_csv(input_json_path, output_csv_path):
    """Process JSON file and export to CSV with flattened structure."""
    # Load your JSON data
    with open(input_json_path) as f:
        data = json.load(f)
    
    # Flatten each JSON object
    flattened_data = [flatten_json(item) for item in data]
    
    # Create a DataFrame and export to CSV
    df = pd.DataFrame(flattened_data)
    df.to_csv(
        output_csv_path,
        index=False,
        sep=',',  # Use pipe delimiter
        quotechar='"',
        encoding='utf-8'
    )
    print(f"Successfully exported to {output_csv_path}")

# Example usage
process_json_to_csv(
    input_json_path='UnstructuredDemoJSON.json',
    output_csv_path='UnstructuredDemo2CSV.csv'
)
# Out:
# Successfully exported to UnstructuredDemo2CSV.csv

# %% [markdown]
# Second cell that only converts the 'text' and 'embeddings' field into a CSV flat file.

# %%
def process_json_to_csv(input_json_path, output_csv_path):

    # Load your JSON data
    with open(input_json_path) as f:
        data = json.load(f)
    
    # Prepare data for export
    rows = []
    for item in data:
        row = {
            'text': item.get('text', None),
            'embedding': ",".join(map(str, item.get('embeddings', [])))  # Convert array to comma-separated string
        }
        rows.append(row)
    
    # Create DataFrame and export to CSV
    df = pd.DataFrame(rows)
    
    # Export to CSV with pipe delimiter 
    df.to_csv(
        output_csv_path,
        index=False,
        sep=',',
        quotechar='"',
        encoding='utf-8'
    )
    print(f"Successfully exported to {output_csv_path}")

# Example usage
process_json_to_csv(
    input_json_path='UnstructuredDemoJSON.json',
    output_csv_path='CSV10p.csv'
)
# Out:
# Successfully exported to CSV10p.csv

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <b style = 'font-size:30px;font-family:Arial;color:#00233C'>4. Connections </b>

# %% [markdown]
# #### Connection to Vantage

# %%
# Connect to Vantage using create_context.
hostname = getpass(prompt = 'hostname: ')
username = getpass(prompt = 'username: ')
password = getpass(prompt = 'password: ')

context=create_context(host=hostname, username=username, password=password)
# Out:
# c:\Users\jv255027\AppData\Local\miniforge3\envs\vsenv311\Lib\site-packages\teradatasqlalchemy\telemetry\queryband.py:382: UserWarning: [Teradata][teradataml](TDML_2002) Overwriting an existing context associated with Teradata Vantage Connection. Most of the operations on any teradataml DataFrames created before this will not work.
#   return exposed_func(*args, **kwargs)
# Exception closing connection TeradataConnection uConnHandle=1
# Traceback (most recent call last):
#   File "c:\Users\jv255027\AppData\Local\miniforge3\envs\vsenv311\Lib\site-packages\sqlalchemy\pool\base.py", line 376, in _close_connection
#     self._dialect.do_close(connection)
#   File "c:\Users\jv255027\AppData\Local\miniforge3\envs\vsenv311\Lib\site-packages\sqlalchemy\engine\default.py", line 712, in do_close
#     dbapi_connection.close()
#   File "c:\Users\jv255027\AppData\Local\miniforge3\envs\vsenv311\Lib\site-packages\teradatasql\__init__.py", line 217, in close
#     raise OperationalError(sErr)
# teradatasql.OperationalError: [Version 20.0.0.29] [Session 42848] [Teradata SQL Driver] Failure sending Logoff Request message
#  at gosqldriver/teradatasql.formatError ErrorUtil.go:85
#  at gosqldriver/teradatasql.(*teradataConnection).makeDriverError ErrorUtil.go:176
#  at gosqldriver/teradatasql.(*teradataConnection).socketSendMessage NetworkIO.go:291
#  at gosqldriver/teradatasql.(*teradataConnection).socketSendAndReceiveContext NetworkIO.go:70
#  at gosqldriver/teradatasql.(*teradataConnection).sendAndReceive NetworkIO.go:26
#  at gosqldriver/teradatasql.(*teradataConnection).Close TeradataConnection.go:1134
#  at database/sql.(*driverConn).finalClose.func2 sql.go:695
#  at database/sql.withLock sql.go:3574
#  at database/sql.(*driverConn).finalClose sql.go:693
#  at database/sql.(*DB).Close sql.go:945
#  at main.goCloseConnection goside.go:481
#  at _cgoexp_ff5e33a08e40_goCloseConnection _cgo_gotypes.go:299
#  at runtime.cgocallbackg1 cgocall.go:444
#  at runtime.cgocallbackg cgocall.go:350
#  at runtime.cgocallback asm_amd64.s:1084
#  at runtime.goexit asm_amd64.s:1700
# Caused by write tcp 172.20.82.155:63051->100.20.240.249:443: wsasend: An existing connection was forcibly closed by the remote host.

# %% [markdown]
# #### Connection to the Vector Store

# %%
# Connect to Vector Store using VSManager
base_url = 'https://vectorstoreaws.staging.innovationlabs.teradata.com/api/accounts/45bc9b91-8bbf-4646-ba9c-cda9b9c8a77d'
#https://vectorstoreaws.staging.innovationlabs.teradata.com/api/accounts/45bc9b91-8bbf-4646-ba9c-cda9b9c8a77d/open-analytics
pat = getpass("Enter pat token: ")
set_auth_token(base_url=base_url, pat_token=pat, pem_file='VectorStorePEM.pem')
# Out:
# Authentication token is generated, authenticated and set for the session.
# True

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <b style = 'font-size:30px;font-family:Arial;color:#00233C'>5. Import Embeddings to a Table </b>

# %% [markdown]
# ### 🚚 Read in external embeddings and clean the input data.
#
# 1. **Load the processed embeddings and text from the CSV file into a DataFrame.**
#    - Show sample of the data.

# %%
df = pd.read_csv("CSV10p.csv")

embed_df = pd.DataFrame(df)

#View the dataframe
embed_df.head(5)
# Out:
#    text                                          embedding
# 0     0  0.03920780494809151,0.058651152998209,-0.09762...
# 1  2020  -0.05756828933954239,0.07082386314868927,0.058...
# 2     2  -0.02816479280591011,-0.024786563590168953,-0....
# 3     0  0.03920780494809151,0.058651152998209,-0.09762...
# 4     2  -0.02816479280591011,-0.024786563590168953,-0....

# %% [markdown]
# 2. **Define function to clean the input data**

# %%
#Clean data function
import re
def clean_data(data):
    # Remove non-ASCII characters
    return re.sub(r'[^\x00-\x7F]+', '', data)

# %% [markdown]
# ### ⛏️ Create the table to store the embeddings

# %%
#Create a multiset table to store the vector data
create_normalized_table_query = '''
CREATE MULTISET TABLE manual_vector_table_normalized, FALLBACK,
    NO BEFORE JOURNAL,
    NO AFTER JOURNAL,
    CHECKSUM = DEFAULT,
    DEFAULT MERGEBLOCKRATIO,
    MAP = TD_MAP2
    (
        TD_ID INTEGER GENERATED ALWAYS AS IDENTITY (START WITH 1 INCREMENT BY 1),
        TD_FILENAME VARCHAR(1024) CHARACTER SET LATIN NOT CASESPECIFIC,
        CHUNKS VARCHAR(32000) CHARACTER SET LATIN NOT CASESPECIFIC,
        Embedding VECTOR,
        Message VARCHAR(32000) CHARACTER SET LATIN NOT CASESPECIFIC)
    PRIMARY INDEX (TD_ID);
'''

#Execute the query to create the table
execute_sql(create_normalized_table_query)
# Out:
# TeradataCursor uRowsHandle=55 bClosed=False

# %% [markdown]
# ### ⛳ Insert embeddings into the table

# %%
#Insert data into the normalized table

for index, row in embed_df.iterrows():
    # Convert the text and embedding to string format
    text = clean_data(str(row['text'])).replace("'", "''")
    embedding = clean_data(str(row['embedding'])).replace("'", "''")
    #embeddingSplit = embedding.split(',')
    #newEmbedding = [float(value) for value in embeddingSplit]
    #newEmbeddingStr = ','.join(map(str, newEmbedding))
    # Print the index, text, and embedding for debugging
    print(index, embedding)
    # Insert the data into the table
    insert_query = f'''
    INSERT INTO manual_vector_table_normalized (TD_FILENAME, CHUNKS, Embedding, Message)
    VALUES ('DensePassageRetrieval', '{text}', '{embedding}', 'Message to describe the data.');
    '''
    execute_sql(insert_query)
# Out:
0427713468670845,0.027399690821766853,0.03118123672902584,0.10205980390310287,0.028248952701687813,0.0212930329144001,-0.05433542653918266,-0.0011537250829860568,-0.06484511494636536,0.030889544636011124,0.0006535203428938985,-0.008275879546999931,-0.020482879132032394,3.1572896642323526e-33,0.03488213196396828,-0.014005608856678009,0.042114563286304474,-0.08591512590646744,-0.03613371402025223,0.031918708235025406,-0.006665998604148626,0.05247317627072334,-0.06304014474153519,-0.045600973069667816,-0.029018793255090714,0.014689530245959759,-0.007569089997559786,0.04466646537184715,-0.027382880449295044,0.0345597080886364,-0.147322416305542,0.0596357136964798,-0.08881677687168121,0.07143642008304596,0.07843489199876785,-0.016471825540065765,-0.03667861968278885,-0.10768362134695053,-0.006772277876734734,0.03355478122830391,-0.016928697004914284,-0.004206446465104818,-0.07598292082548141,-0.029345499351620674,-0.15472310781478882,-0.026363883167505264,-0.03566879779100418,-0.0034747037570923567,0.04255920648574829,-0.027895048260688782,0.11707089096307755,0.02268606796860695,-0.026120765134692192,-0.08576076477766037,-0.017905863001942635,0.06600800156593323,0.06263983994722366,-0.08389148116111755,-0.0683082789182663,-0.07300475984811783,-0.05627549812197685,-0.04111196845769882,0.00736249191686511,0.013655402697622776,0.04862572252750397,-0.02803017944097519,-0.11192429810762405,-0.06162845715880394,0.0378861241042614,-0.04417842626571655,0.0641942173242569,0.05126764252781868,0.017368003726005554,0.08652427047491074,0.016093820333480835,-0.001047730096615851,0.014200298115611076,-0.06207728 ...

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <b style = 'font-size:30px;font-family:Arial;color:#00233C'>6. Normalize the embeddings </b>

# %% [markdown]
# ### 🎚️ Apply the vector normalization function from Teradata

# %%
#Normalize the embeddings
normalize_query = '''
SELECT *
FROM TD_Vectornormalize(
    ON manual_vector_table_normalized AS InputTable
        USING
        IDColumns('TD_ID')
        TargetColumns('Embedding')
        Approach('UNITVECTOR')
        EmbeddingSize(384)
) AS DT;
'''

#The Accumulate argument in the above query requires the pdf name and the message. Not sure what to put here.

#Execute the query to normalize the embeddings
execute_sql(normalize_query)
# Out:
# TeradataCursor uRowsHandle=257 bClosed=False

# %% [markdown]
# ### 🔎 Inspect the normalized embedding table

# %%
#View the normalized data
view_normalized_query = '''
SELECT TOP 20 *
FROM manual_vector_table_normalized;
'''
#Execute the query to view the normalized data
#Test dataframe
test_df = DataFrame.from_query(view_normalized_query)
test_df.head(5)
# Out:
#    TD_ID TD_FILENAME                                                                                                                                                                                                                                                                                                      CHUNKS                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Embedding                 Message
# 0     38    test.txt  3The ideal size and boundary of a text passage are func- tions of both the retriever and reader. We also experimented with natural paragraphs in our preliminary trials and found that using xed-length passages performs better in both retrieval and nal QA accuracy, as observed by Wang et al. (2019).  -0.0346288,0.0486938,0.020013,-0.0218376,-0.0645149,0.00435138,-0.0211648,0.022073,0.0888339,0.000378763,-0.0138585,0.0403812,0.00334833,0.066205,-0.0133377,-0.0525756,0.0576954,0.0511013,-0.0711867,-0.0443287,0.0284265,0.0539299,0.0732988,-0.0149601,-0.0867288,-0.00353228,-0.157543,-0.0522634,0.0906647,-0.0423455,-0
# %% [markdown]
# ### 🔧 Drop table if it exists (Optional)

# %%
#Drop the normalized table
drop_normalized_table_query = '''
DROP TABLE manual_vector_table_normalized;
'''
#Execute the query to drop the normalized table
execute_sql(drop_normalized_table_query)
# Out:
# TeradataCursor uRowsHandle=54 bClosed=False

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <b style = 'font-size:30px;font-family:Arial;color:#00233C'>7. Similarity search algorithms </b>

# %% [markdown]
# ### ↔️ Vector Distance algorithm example
#
# The vector distance algorithm measures similarity between vectors using mathematical operations like cosine similarity or Euclidean distance. It calculates how "close" two vectors are in the embedding space to find semantically related content.
#
# #### ⚠️ Considerations
# - Just for the example we used the same table with the **normalized vectors** as the **Target** and **Reference** tables to see the distance between all of the embeddings on the PDF.
# - The distance measures used are **euclidean**, **cosine**, **manhattan**.

# %%
VectorDistance_query = '''
SELECT target_id, reference_id, distancetype, cast(distance as decimal(36,15)) as distance FROM TD_VECTORDISTANCE (
ON manual_vector_table_normalized as TargetTable
ON manual_vector_table_normalized as ReferenceTable Dimension
USING
TargetIDColumn('TD_ID')
TargetFeatureColumns('Embedding')
RefIDColumn('TD_ID')
RefFeatureColumns('Embedding')
DistanceMeasure('euclidean', 'cosine', 'manhattan')
topk(2)
EmbeddingSize(384)
) as dt
WHERE distance > 0;
'''

#execute_sql(VectorDistance_query)

test_df2 = DataFrame.from_query(VectorDistance_query)
test_df2.head(20)
# Out:
#     target_id  reference_id distancetype  distance
# 0           2             7    manhattan    17.892
# 1           6             6       cosine     0.000
# 2           6           113    euclidean     1.151
# 3           6           113       cosine     0.663
# 4           7            10    manhattan    14.777
# 5           7             9       cosine     0.448
# 6           7             9    euclidean     0.947
# 7           8            11    manhattan    16.997
# 8           8            11       cosine     0.609
# 9           8            11    euclidean     1.103
# 10          9             7    manhattan    14.907
# 11          9             7    euclidean     0.947
# 12         10             7       cosine     0.458
# 13         10             7    manhattan    14.777
# 14         10             7    euclidean     0.958
# 15          9             7       cosine     0.448
# 16          6           113    manhattan    17.329
# 17          2             7       cosine     0.649
# 18          2             7    euclidean     1.140
# 19          2             2       cosine     0.000

# %% [markdown]
# ### 🎯 Kmeans algorithm
#
# The K-means algorithm groups vectors into clusters by iteratively minimizing distances between points and cluster centroids. It enables efficient approximate similarity search by comparing vectors only to nearby cluster centers rather than all data points.
#
# 1. **Create the initial centroids tables**
#    - Execute the query to create the initial centroids table.

# %%
create_centroids_table_query = '''
CREATE TABLE kmeans_centroids AS (SELECT * FROM manual_vector_table_normalized WHERE TD_ID in (4,5,10,150)) WITH DATA;
'''

#execute_sql(create_centroids_table_query)

# %% [markdown]
# 2. **Start with Kmeans function**

# %%
#Start with Kmeans function
#Kmeans query
kmeans_query = '''
CREATE TABLE kmeans_centroids AS (
    SELECT * FROM TD_KMeans (
        ON manual_vector_table_normalized AS InputTable
            USING
            IDColumn('TD_ID')
            TargetColumns('Embedding')
            NumClusters(5)
            Seed(1234)
            StopThreshold(0.0395)
            MaxIterNum(3)
            OutputClusterAssignment('true')
    ) AS DT) WITH DATA;
'''
#Execute the query to run Kmeans
execute_sql(kmeans_query)
# Out:
# Test 1
#        td_clusterid_kmeans
# TD_ID
# 3                        4
# 5                        4
# 4                        4
# 2                        4
# 1                        4

# %% [markdown]
# 3. **Select from the centroids table and view the Kmeans query**

# %%
select_centroids_query = '''
SELECT *
FROM kmeans_centroids;
'''

#Run and view the Kmeans query
print('Test 1')
test_kmeans = DataFrame.from_query(select_centroids_query)
test_kmeans.head(5)

# %% [markdown]
# 4. **Drop table if it exists (Optional)**

# %%
#Optional drop table kmeans_centroids
execute_sql('DROP TABLE kmeans_centroids;')
# Out:
# TeradataCursor uRowsHandle=291 bClosed=False

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <b style = 'font-size:30px;font-family:Arial;color:#00233C'>8. Vector Distance Semantic Similarity Search </b>

# %% [markdown]
# ### Embed the query

# %%
# Load the Hugging Face model (same as original embeddings) 
model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# Generate query embedding 
query_text = "What is Open-domain Question Answering?"  
query_embedding = model.embed_query(query_text)

# Convert embedding to SQL-compatible string
query_embedding_str = clean_data(str(query_embedding).replace("'", "''").replace("[", "").replace("]", ""))
print(query_embedding_str)
# Out:
# -0.02913535200059414, -0.07232124358415604, -0.02071591280400753, 0.022982321679592133, 0.035644520074129105, -0.05671808868646622, 0.005359720904380083, 0.07470639795064926, 0.02206711657345295, -0.02198302373290062, -0.03440426290035248, -0.024723464623093605, -0.016810951754450798, -0.03769907355308533, 0.04363245889544487, 0.05810769274830818, 0.04422583431005478, -0.06664694845676422, -0.08862367272377014, -0.041543442755937576, 0.059815045446157455, 0.060225702822208405, 0.032384488731622696, -0.038301896303892136, -0.020658783614635468, -0.04165913537144661, 0.056156836450099945, 0.00886167399585247, 0.007824202999472618, 0.015311909839510918, 0.005620834417641163, 0.05555342510342598, 0.005099212285131216, 0.05733099579811096, -0.010123617015779018, 0.10796690732240677, -0.030071770772337914, 0.029345761984586716, -0.1418522298336029, -0.06508573889732361, -0.018289729952812195, -0.10410381853580475, 0.046699441969394684, -0.005192675162106752, 0.028051605448126793, 0.00037265566061250865, -0.06697122007608414, -0.011046400293707848, 0.046418532729148865, -0.037733446806669235, -0.028778601437807083, -0.04080866277217865, -0.05009356141090393, 0.03353132680058479, -0.0022711411584168673, -0.028351210057735443, -0.05971621349453926, 0.021390868350863457, -0.03231330215930939, -0.05443210527300835, 0.0010618282249197364, -0.08080335706472397, -0.07285693287849426, 0.1257898509502411, 0.04148988425731659, -0.1302485466003418, -0.05679662153124809, -0.019403204321861267, -0.0942128598690033, -0.10677672922611237, -0.021652964875102043, 0.042999912053346634, 0.0387735441327095, 0.0547589510679245, 0.05160476267337799, 0.001377698383294046, 0.013233591802418232, -0.030838701874017715, 0.041925154626369476, -0.007692847866564989, 0.07254619896411896, -0.05979723110795021, 0.052595846354961395, 0.04251527041196823, 0.038650378584861755, 0.07128249108791351, 0.03202999755740166, 0.04365520551800728, -0.021698715165257454, 0.024116266518831253, -0.04314089193940163, -0.06430231034755707, 0.02026849240064621, -0.012791427783668041, -0.005105537828058004, -0.05889929458498955, 0.0562400184571743, -0.028464626520872116, -0.05628896504640579, 0.0655120238661766, 0.06626145541667938, 0.06072980910539627, 0.029228869825601578, -0.025268804281949997, -0.05837984010577202, 0.013104484416544437, -0.021674003452062607, 0.10297641158103943, 0.05578894540667534, -0.10089977085590363, -0.011308914050459862, -0.04425860568881035, 0.10208530724048615, -0.07363180816173553, -0.04133446887135506, -0.09863101691007614, -0.04768479987978935, 0.013033870607614517, 0.005788183771073818, -0.10217416286468506, -0.04691749066114426, 0.06231040135025978, -0.03871048241853714, -0.07702317088842392, 0.03166133537888527, -0.018887363374233246, 0.0013586647110059857, -4.800627093262064e-33, 0.07338167726993561, -0.0021965601481497288, 0.014506294392049313, -0.00603643199428916, -0.03782206028699875, 0.0221101026982069, -0.0724823921918869, 0.06172414869070053, -0.03472970053553581, 0.07726634293794632, 0.06039724498987198, 0.06216738373041153, 0.02826503850519657, 0.024405818432569504, 0.13839313387870789, 0.0676591694355011, -0.09761159867048264, 0.06167071685194969, 0.03614908829331398, -0.0020266424398869276, 0.036397527903318405, 0.0786265879869461, 0.005962603259831667, 0.0807575136423111, 0.01943432167172432, -0.055836521089076996, 0.004745552781969309, -0.08701015263795853, 0.013635433278977871, 0.010943872854113579, -0.051426373422145844, -0.01621388830244541, -0.11512697488069534, 0.03720155358314514, 0.08184941858053207, 0.05972200259566307, 0.06063395366072655, -0.06549692153930664, 0.017204759642481804, -0.028651785105466843, -0.051994819194078445, -0.03702632710337639, 0.03842660412192345, 0.06508545577526093, -0.055564962327480316, -0.04482923820614815, -0.04076698049902916, -0.009997716173529625, -0.035278890281915665, 0.014039934612810612, 0.037005193531513214, -0.021098310127854347, -0.08559685945510864, 0.0009447874617762864, 0.05981057137 ...

# %% [markdown]
# ### Create a table to store the query

# %%
# Create the table to hold the query embedding
create_query_embedding_table = '''
CREATE MULTISET TABLE query_table, FALLBACK,
    NO BEFORE JOURNAL,
    NO AFTER JOURNAL,
    CHECKSUM = DEFAULT,
    DEFAULT MERGEBLOCKRATIO,
    MAP = TD_MAP2
    (
        TD_ID INTEGER GENERATED ALWAYS AS IDENTITY (START WITH 1 INCREMENT BY 1),
        TD_FILENAME VARCHAR(1024) CHARACTER SET LATIN NOT CASESPECIFIC,
        CHUNKS VARCHAR(32000) CHARACTER SET LATIN NOT CASESPECIFIC,
        Embedding VECTOR,
        Message VARCHAR(32000) CHARACTER SET LATIN NOT CASESPECIFIC)
    PRIMARY INDEX (TD_ID);
'''

#Execute the query to create the table
execute_sql(create_query_embedding_table)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[70], line 19
#       2 create_query_embedding_table = '''
#       3 CREATE MULTISET TABLE query_table, FALLBACK,
#       4     NO BEFORE JOURNAL,
#    (...)
#      15     PRIMARY INDEX (TD_ID);
#      16 '''
#      18 #Execute the query to create the table
# ---> 19 execute_sql(create_query_embedding_table)
#
# File c:\Users\jv255027\AppData\Local\miniforge3\envs\vsenv311\Lib\site-packages\teradataml\utils\utils.py:83, in execute_sql(statement, parameters)
#      81     tdsql_con = get_context().raw_connection().driver_connection
#      82     cursor = tdsql_con.cursor()
# ---> 83     return cursor.execute(statement, parameters)
#      84 else:
#      85     raise TeradataMlException(Messages.get_message(MessageCodes.INVALID_CONTEXT_CONNECTION),
#      86                               MessageCodes.INVALID_CONTEXT_CONNECTION)
#
# File c:\Users\jv255027\AppData\Local\miniforge3\envs\vsenv311\Lib\site-packages\teradatasql\__init__.py:755, in TeradataCursor.execute(self, sOperation, params, ignoreErrors)
#     752     raise TypeError ("params unexpected type {}".format (type (params)))
#     754 if not params:
# --> 755     self.executemany (sOperation, None, ignoreErrors)
#     757 elif type (params [0]) in [list, tuple]:
#     758     # Excerpt from PEP 249 DBAPI documentation:
#     759     #  The parameters may also be specified as list of tuples to e.g. insert multiple rows in a single
#     760     #  operation, but this kind of usage is deprecated: .executemany() should be used instead.
#     761     self.executemany (sOperation, params, ignoreErrors)
#
# File c:\Users\jv255027\AppData\Local\miniforge3\envs\vsenv311\Lib\site-packages\teradatasql\__init__.py:1010, in TeradataCursor.executemany(self, sOperation, seqOfParams, ignoreErrors)
#    1007     if bIgnore:
#    1008         return
# -> 1010     raise OperationalError (sErr)
#    1012 if self.connection.bTimingLog:
#    1013     timingLog ("executemany call to goCreateRows took {} ms".format ((time.time () - dStartTime) * 1000.0))
#
# OperationalError: [Version 20.0.0.29] [Session 42991] [Teradata Database] [Error 3803] Table 'query_table' already exists.
#  at gosqldriver/teradatasql.formatError ErrorUtil.go:85
#  at gosqldriver/teradatasql.(*teradataConnection).formatDatabaseError ErrorUtil.go:223
#  at gosqldriver/teradatasql.(*teradataConnection).makeChainedDatabaseError ErrorUtil.go:239
#  at gosqldriver/teradatasql.(*teradataConnection).processErrorParcel TeradataConnection.go:815
#  at gosqldriver/teradatasql.(*TeradataRows).processResponseBundle TeradataRows.go:2412
#  at gosqldriver/teradatasql.(*TeradataRows).executeSQLRequest TeradataRows.go:898
#  at gosqldriver/teradatasql.newTeradataRows TeradataRows.go:744
#  at gosqldriver/teradatasql.(*teradataStatement).QueryContext TeradataStatement.go:122
#  at gosqldriver/teradatasql.(*teradataConnection).QueryContext TeradataConnection.go:1334
#  at database/sql.ctxDriverQuery ctxutil.go:48
#  at database/sql.(*DB).queryDC.func1 sql.go:1786
#  at database/sql.withLock sql.go:3574
#  at database/sql.(*DB).queryDC sql.go:1781
#  at database/sql.(*Conn).QueryContext sql.go:2037
#  at main.createRows goside.go:1080
#  at main.goCreateRows goside.go:959
#  at _cgoexp_ff5e33a08e40_goCreateRows _cgo_gotypes.go:417
#  at runtime.cgocallbackg1 cgocall.go:444
#  at runtime.cgocallbackg cgocall.go:350
#  at runtime.cgocallback asm_amd64.s:1084
#  at runtime.goexit asm_amd64.s:1700

# %% [markdown]
# #### Option drop table if the table already exists

# %%
#Drop the table if it exists
drop_query_embedding_table = '''
DROP TABLE query_table;
'''
#Execute the query to drop the table
execute_sql(drop_query_embedding_table)

# %% [markdown]
# ### Insert the query into the table

# %%
#Fill the table with the query embedding
insert_query = f'''
INSERT INTO query_table (TD_FILENAME, CHUNKS, Embedding, Message)
VALUES ('test.txt', 'This is a test message', '{query_embedding_str}', 'This is a test message');
'''
#Execute the query to insert the data
execute_sql(insert_query)
# Out:
# TeradataCursor uRowsHandle=588 bClosed=False

# %% [markdown]
# ### Run a Vector Distance on the query and the embeddings

# %%
#Run semantic similarity search using vector distance
VectorDistance_query_search = '''
SELECT target_id, reference_id, distancetype, cast(distance as decimal(36,15)) as distance FROM TD_VECTORDISTANCE (
ON query_table as TargetTable
ON manual_vector_table_normalized as ReferenceTable Dimension
USING
TargetIDColumn('TD_ID')
TargetFeatureColumns('Embedding')
RefIDColumn('TD_ID')
RefFeatureColumns('Embedding')
DistanceMeasure('euclidean')
topk(5)
EmbeddingSize(384)
) as dt;
'''

#execute_sql(VectorDistance_query)

test_df2 = DataFrame.from_query(VectorDistance_query_search)
test_df2.head(20)
# Out:
#    target_id  reference_id distancetype  distance
# 0          1             8    euclidean     1.228
# 1          1           113    euclidean     1.234
# 2          2            20    euclidean     0.882
# 3          2            13    euclidean     0.886
# 4          2           162    euclidean     0.823
# 5          2           182    euclidean     0.828
# 6          2           159    euclidean     0.876
# 7          1            64    euclidean     1.142
# 8          1           132    euclidean     1.221
# 9          1           130    euclidean     1.209

# %% [markdown]
# ### Show the text results of the vector distance search

# %%
#Query the table to get the results
query_results = '''
SELECT TD_ID, CHUNKS
FROM manual_vector_table_normalized
WHERE TD_ID IN (20, 13, 162, 182, 159);
'''
#Execute the query to get the results
getResults = DataFrame.from_query(query_results)
getResults.head(5)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   CHUNKS
# TD_ID
# 159                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Kenton Lee, Ming-Wei Chang, and Kristina Toutanova. 2019. Latent retrieval for weakly supervised open domain question answering. In Association for Com- putational Linguistics (ACL), pages 60866096.
# 182                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Wei Yang, Yuqing Xie, Aileen Lin, Xingyu Li, Luchen Tan, Kun Xiong, Ming Li, and Jimmy Lin. 2019a. End-to-end open-domain question answering with bertserini. In North American Association for Com- putational Linguistics (NAACL), pages 7277.
# 162                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Yankai Lin, Haozhe Ji, Zhiyuan Liu, and Maosong Sun. 2018. Denoising distantly supervised open-domain question answering. In Association for Computa- tional Linguistics (ACL), pages 17361745.
# 20     Open-domain question answering (QA) (Voorhees, 1999) is a task that answers factoid questions us- ing a large collection of documents. While early QA systems are often complicated and consist of multiple components (Ferrucci (2012); Moldovan et al. (2003), inter alia), the advances of reading comprehension models suggest a much simplied two-stage framework: (1) a context retriever rst selects a small subset of passages where some of them contain the answer to the question, and then (2) a machine reader can thoroughly exam- ine the retrieved contexts and identify the correct answer (Chen et al., 2017). Although reducing open-domain QA to machine reading is a very rea- sonable strategy, a huge performance degradation is often observed in practice2, indicating the needs of improving retrieval.
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Dense Passage Retrieval for Open-Domain Question Answering

# %% [markdown]
# ### Drop tables

# %%
#Drop the manual_vector_table_normalized table
drop_manual_vector_table_query = '''
DROP TABLE manual_vector_table_normalized;
'''

#Drop the query_table
drop_query_table = '''
DROP TABLE query_table;
'''

#Execute the query to drop the table
execute_sql(drop_manual_vector_table_query)
execute_sql(drop_query_table)
